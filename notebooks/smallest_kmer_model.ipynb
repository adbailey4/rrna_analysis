# %% [markdown]
# ## Create Model
# * Create 5mer, 6mer and 7mer models

# %%
from signalalign.hiddenMarkovModel import HmmModel
import os 

def create_rrna_model(original_rna_model, output_dir, noise=0, new_variants = "abc",
                     replacement_bases = "AAA"):
    alphabet = "ACGT"
    if noise > 0:  
        tmp_rna_model = os.path.join(output_dir, "rna_r94_5mer_{}_noise_"+str(noise)+".model")
    else:
        tmp_rna_model = os.path.join(output_dir, "rna_r94_5mer_{}.model")

    current_model_path = original_rna_model
    for i, (variant, rep_base) in enumerate(zip(new_variants, replacement_bases)):
        alphabet += variant
        rna_model = HmmModel(current_model_path, rna=True)
        print(alphabet)
        rna_model.write_new_model(tmp_rna_model.format(alphabet), alphabet, rep_base,  noise=noise)
        if i > 0:
            os.remove(current_model_path)
        current_model_path = tmp_rna_model.format(alphabet)

# %%
original_rna_model = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/models/testModelR9p4_5mer_acgt_RNA_180mv.model"
output_dir = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/small_models/small_5mer"
create_rrna_model(original_rna_model, output_dir, noise=0, new_variants = "abc", replacement_bases = "AAA")
# Out:
# ACGTa
# ACGTab
# ACGTabc
# /Users/andrewbailey/CLionProjects/signalAlign/src/signalalign/hiddenMarkovModel.py:211: RuntimeWarning: invalid value encountered in double_scalars
#   self.transitions_expectations[i + to_state] = self.transitions_expectations[i + to_state] / j

# %% [markdown]
# ## Create 6mer and 7mer model

# %%
from py3helpers.utils import all_string_permutations
from signalalign.hiddenMarkovModel import HmmModel
import os 
import numpy as np

def write_increased_kmer_len_model(standard_model, output_path, kmer_length):
    rna_model = HmmModel(standard_model, rna=True)
    og_len = rna_model.kmer_length
    alphabet = rna_model.alphabet
    alphabet_size = rna_model.alphabet_size
    new_kmers = [x for x in all_string_permutations(alphabet, length=kmer_length)]
    state_number = rna_model.state_number
    transition_probs = rna_model.transitions
    likelihood = 0
    noise = 0
    with open(output_path, 'w') as f:

        # line 0
        f.write("{stateNumber}\t{alphabetSize}\t{alphabet}\t{kmerLength}\n"
                "".format(stateNumber=state_number, alphabetSize=alphabet_size,
                          alphabet=alphabet, kmerLength=kmer_length))
        # line 1 transitions
        for i in range(state_number * state_number):
            f.write("{transition}\t".format(transition=str(transition_probs[i])))
        # likelihood
        f.write("{}\n".format(str(likelihood)))

        # line 2 Event Model
        for kmer in new_kmers:
            k = rna_model._get_kmer_index(kmer[:-1], alphabet, og_len, alphabet_size)
            f.write("{level_mean}\t{level_sd}\t{noise_mean}\t{noise_sd}\t{noise_lambda}\t"
                    "".format(level_mean=rna_model.event_model["means"][k]+np.random.uniform(-noise, noise),
                              level_sd=rna_model.event_model["SDs"][k],
                              noise_mean=rna_model.event_model["noise_means"][k],
                              noise_sd=rna_model.event_model["noise_SDs"][k],
                              noise_lambda=rna_model.event_model["noise_lambdas"][k]))
        f.write("\n")

# %%
# 6mer
standard_model = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/small_models/small_5mer/rna_r94_5mer_ACGTabc.model"  
output_path = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/small_models/small_6mer/rna_r94_6mer_ACGTabc.model"
kmer_length = 6
write_increased_kmer_len_model(standard_model, output_path, kmer_length)

# %%
# 7mer 
standard_model = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/small_models/small_6mer/rna_r94_6mer_ACGTabc.model"  
output_path = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/small_models/small_7mer/rna_r94_7mer_ACGTabc.model"
kmer_length = 7
write_increased_kmer_len_model(standard_model, output_path, kmer_length)

# %% [markdown]
# ## Smallest Model
#
# Using the same modification for each distribution creates some overlapping kmer distributions which, in aggregate may give us a better picture of the underlying expected current signal. However, when there are only a few kmers contributing, it usually gives bimodal distributions that do not model any of the position's kmer distributions well. So, I want to create a model, specific to the 18S and 25S S.cer rRNA's that has the smallest alphabet so that each position has a set of unique kmers covering that position.
#
# Hopefully this is smaller than the 21 letter alphabet I am using now
#
# 1) Get kmers for each position
# 2) Find overlapping kmers
# 3) the max set of overlapping kmers is the max number of extra characters I need

# %%
import numpy as np
import pandas as pd
from rrna_analysis.kmer_pos_mapping import KmerPosMapping, get_kmers_from_seq, get_covered_kmers, get_kmer_permutations
from py3helpers.seq_tools import ReferenceHandler
from collections import namedtuple, defaultdict
from signalalign.utils.sequenceTools import CustomAmbiguityPositions, reverse_complement
import itertools
import operator
from itertools import zip_longest

# %%
mods_csv = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/mod_files/mod_file.csv"
reference = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/yeast_25S_18S.fa"
alt_c_positions = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/alt_canonical_distribution/yeast_18S_25S_variants.positions"
# positions = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/mod_files/yeast_18S_25S_variants.positions"
kpm = KmerPosMapping(reference, alt_c_positions, mods_csv)
rh = ReferenceHandler(reference)

# %%
positions_data = CustomAmbiguityPositions.parseAmbiguityFile(alt_c_positions)

# %%
def get_mod_positions(mods_csv, k=5):
    mods_data = KmerPosMapping.read_in_mod_data(mods_csv)
    mod_positions = {}
    grouped_positions = {}
    for i, data in mods_data.groupby(["contig", "strand"]):
        contig = i[0]
        strand = i[1]
    #     print(data)
        mod_positions[contig+strand] = data["reference_index"].values
        values = sorted(data["reference_index"].values)
        recent = values[0]
        groups = []
        group = [recent]
        for x in values[1:]:
            if x - recent <= k:
                group.append(x)
            else:
                groups.append(group)
                group = [x]
            recent = x
        grouped_positions[contig+strand] = groups
    return mod_positions, grouped_positions

# %%
def get_list_full_sequence(rh, positions_data, edit=True):
    full_sequence = {}
    for i, data in positions_data.groupby(["contig", "strand"]):
        contig = i[0]
        strand = i[1]
        sequence = rh.get_sequence(contig, None, None)
    #     sequence = self.ref_handler.get_sequence(contig, None, None)
        if strand == "-":
            sequence = rc.complement(sequence)
        list_seq = list(sequence)
        if edit:
            for i, row in data.iterrows():
                assert list_seq[row.position] == row.change_from, f"ref base:{list_seq[row.position]} != position change_from:{row.change_from}"             
                list_seq[row.position] = row.change_to
        full_sequence[contig+strand] = list_seq
    return full_sequence

# %%
def get_kmers_from_list(sequence, index, k, rna):
    sub_seq = sequence[index-k+1:index+k]
    if rna:
        sub_seq = sub_seq[::-1]
    kmers = get_kmer_permutations(sub_seq)
    all_kmers = []
    for x in kmers:
        all_kmers.append(get_kmers_from_seq(x, k))
    all_kmers = [set(x) for x in zip(*all_kmers)]
    if rna:
        all_kmers = all_kmers[::-1]
    return all_kmers

# %%
def get_kmers_from_full_sequence(full_sequence, mod_positions, k=5, rna=True):
    contig_strand_position_kmers = {}
    for contig_strand, ref_indices in mod_positions.items():
        position_kmers = {}
        contig_sequence = full_sequence[contig_strand]
        for index in ref_indices:
            all_kmers = get_kmers_from_list(contig_sequence, index, k, rna)
            position_kmers[str(index)] = all_kmers
        contig_strand_position_kmers[contig_strand] = position_kmers
    return contig_strand_position_kmers

# %%
def get_expected_total(group, k=5):
    total = 0
    curr_window = []
    prev_min = group[0]
    for index in range(group[0]-k+1, group[-1]+1):
        if index+(k-1) in group:
            curr_window.append(index+(k-1))
        if len(curr_window) > 0 and index > curr_window[0]:
            curr_window.pop(0)
        kmers = 2**len(curr_window)
        total += kmers
#         print(index, kmers, curr_window)
    return total

# %%
def get_contig_strand_group_kmers(contig_strand_position_kmers, grouped_positions, k=5):
    contig_strand_group_kmers = {}
    seen_kmers = {}
    for contig_strand, position_kmers in contig_strand_position_kmers.items():
        gp = grouped_positions[contig_strand]
        group_kmers_list = []
        for group in gp:
    #         print("NEW GROUP", group)
            group_kmers = []
    #         total = 0
            for index in group:
    #             list_of_pos = list(itertools.chain.from_iterable([list(x) for x in position_kmers[str(index)]]))
    #             total += len(list_of_pos)
                group_kmers.extend(set.union(*position_kmers[str(index)]))
            group_kmers = set(group_kmers)
            expected_total = get_expected_total(group, k=k)
    #         print(len(group), group)
    #         print(expected_total, len(group_kmers), len(set(group_kmers)))
    #             print(group_kmers)
            assert expected_total == len(group_kmers), f"expected_total != len(group_kmers), {expected_total} != {len(group_kmers)}"
            group_kmers_list.append(group_kmers)
        contig_strand_group_kmers[contig_strand] = group_kmers_list
    return contig_strand_group_kmers

# %%
def get_fix_positions(contig_strand_group_kmers):
    all_kmers_set = set()
    for cstrand in contig_strand_group_kmers.keys():
        all_kmers_set |= set.union(*contig_strand_group_kmers[cstrand])
    all_kmers_dict = { key : [] for key in all_kmers_set }
    fix_positions = defaultdict(list)
    for cstrand in contig_strand_group_kmers.keys():
        for i, group in enumerate(contig_strand_group_kmers[cstrand]):
            for kmer in group:
                all_kmers_dict[kmer].append(cstrand+str(i))
                if len(all_kmers_dict[kmer]) > 1:
                    fix_positions[cstrand+str(i)] += [kmer]
    return fix_positions

# %%
def get_max_pos_max_len(fix_positions, skip=0):
    max_pos = -1
    max_len = -1
    prev_bests = []
    for pos, k_list in fix_positions.items():
        k_list_len = len(k_list)
        if k_list_len > max_len:
            max_len = k_list_len
            max_pos = pos
            prev_bests.insert(0, [max_pos, max_len])
    if skip >= len(prev_bests):
        max_pos = prev_bests[-1][0]
        max_len = prev_bests[-1][1]
        over = True
    else:
        max_pos = prev_bests[skip][0]
        max_len = prev_bests[skip][1]
        over = False

    return max_pos, max_len, over

# %%
def get_change_base_index(max_pos, fix_positions, grouped_positions, contig_strand_position_kmers, rna=True, k=5, skip=0):
    contig_strand = max_pos[:8]
    pos = int(max_pos[8:])
    kmers = set(fix_positions[max_pos])
#     print(grouped_positions)
#     print(contig_strand)
#     print(grouped_positions[contig_strand])
#     print(max_pos, pos, len(grouped_positions[contig_strand]))
    target_positions = grouped_positions[contig_strand][pos]
    best_pos = None
    best_pos_index = None
    best_kmers = None
    curr_max = 0
    for x in target_positions:
        kmer_sets = contig_strand_position_kmers[contig_strand][str(x)]
        for i, kmer_set in enumerate(kmer_sets):
            overlap_kmers = kmers & kmer_set
            n_kmers = len(overlap_kmers)
            if n_kmers > curr_max:
                curr_max = n_kmers
                best_pos = x
                best_pos_index = i
                best_kmers = overlap_kmers
#     print(best_pos, best_pos_index, best_kmers)
    sub_pos = None
    canonical = {"A", "T", "G", "C"}
    sub_pos_list = []
    for i, x in enumerate(zip_longest(*best_kmers)):
        bases = set(x)
        canonical & bases
        n_bases = len(set(x))
        if n_bases == 1 and len(canonical & bases) == 1:
            sub_pos = i
            sub_pos_list.insert(0, sub_pos)
    
    if skip >= len(sub_pos_list):
        sub_pos = sub_pos_list[-1]
        over = True
    else:
        sub_pos = sub_pos_list[skip]
        over = False
    if rna:
        sub_index = k-sub_pos-1
    change_base_index = (best_pos - k+1) + best_pos_index + sub_index
    return change_base_index, over

# %%
def get_kmer_mapping(og_sequence, contig_strand_position_kmers, k=5, rna=True):
    kmer_mapping = []
    for contig_strand, pos_kmer_map in contig_strand_position_kmers.items():
        for pos, kmer_list in pos_kmer_map.items():
    #         print(contig_strand, pos, kmer_list)
            index = int(pos)
            curr_kmers = get_kmers_from_list(og_sequence[contig_strand], index, k, rna)
    #         print(curr_kmers)
            for kmer_pair in zip(curr_kmers, kmer_list):
                k1 = list(kmer_pair[0])[0]
                k2 = list(kmer_pair[1])
    #             print(k1, k2)
                kmer_mapping.append([k1, k2])
    return kmer_mapping

# %%
def create_efficient_positions_file(reference, ambig_positions, mods_csv, output_path, k=5, rna=True):
    rh = ReferenceHandler(reference)
    mod_positions, grouped_positions = get_mod_positions(mods_csv, k=k)
    positions_data = CustomAmbiguityPositions.parseAmbiguityFile(ambig_positions)
    positions_data.loc[:, "change_to"] = "ab"
    # positions_data = CustomAmbiguityPositions.parseAmbiguityFile(path)
    full_sequence = get_list_full_sequence(rh, positions_data)

    fix_positions = [1, 1]
    iterration = 0
    kmer_mapping = []

    pos_skip = 0
    base_skip = 0
    while len(fix_positions) > 0 and iterration < 1000:
        print("ANOTHER ITER", len(fix_positions))
        contig_strand_position_kmers = get_kmers_from_full_sequence(full_sequence, mod_positions, k=k, rna=rna)
        contig_strand_group_kmers = get_contig_strand_group_kmers(contig_strand_position_kmers, grouped_positions=grouped_positions, k=k)
        fix_positions = get_fix_positions(contig_strand_group_kmers)
        if len(fix_positions) == 0:
            break
        max_pos, max_len, pos_over = get_max_pos_max_len(fix_positions, skip=pos_skip)
        change_base_index, base_over = get_change_base_index(max_pos, fix_positions, grouped_positions, contig_strand_position_kmers, k=k, rna=rna, skip=base_skip)            


        contig_strand = max_pos[:8]
        contig = max_pos[:7]
        position = change_base_index
        strand = max_pos[7]
        change_from = full_sequence[contig_strand][change_base_index]
        change_to = "c"

        try:
            full_sequence[contig_strand][change_base_index] = change_to
            contig_strand_position_kmers = get_kmers_from_full_sequence(full_sequence, mod_positions, k=k, rna=rna)
            contig_strand_group_kmers = get_contig_strand_group_kmers(contig_strand_position_kmers, grouped_positions=grouped_positions, k=k)
    #  will not run if causes error

            new_row = {"contig": max_pos[:7],
               "position": change_base_index,
               "strand": max_pos[7],
               "change_from": change_from,
               "change_to": change_to}
            positions_data = positions_data.append(new_row, ignore_index=True)
            print("PASS", max_pos, change_base_index, pos_skip, base_skip)
            fix_positions = get_fix_positions(contig_strand_group_kmers)
            if len(fix_positions) == 0:
                print("DONE")


        except AssertionError:
            full_sequence[contig_strand][change_base_index] = change_from
            if pos_over:
                base_skip += 1
            if not pos_over:
                pos_skip += 1
            if pos_over and base_over:
                raise AssertionError("ERROR", contig_strand, change_base_index, pos_skip, base_skip)            
            print("SKIPPING", contig_strand, change_base_index, pos_skip, base_skip)


        iterration += 1
    positions_data.to_csv(output_path, sep="\t", header=False, index=False)
    #     get kmer mapping
    og_sequence = get_list_full_sequence(rh, positions_data, edit=False)
    kmer_mapping = get_kmer_mapping(og_sequence, contig_strand_position_kmers, k=k, rna=rna)

    return kmer_mapping

# %%
def edit_model_with_kmer_mapping(model, kmer_mapping, rna=True):
    rna_model = HmmModel(model, rna=rna)
    for k, change in kmer_mapping:
        normal_mean, normal_sd = rna_model.get_event_mean_gaussian_parameters(k)
        for k2 in change:
            rna_model.set_kmer_event_mean_params(k2, normal_mean, normal_sd)
    rna_model.normalized = True
    rna_model.write(model)

# %%
mods_csv = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/mod_files/mod_file.csv"
reference = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/yeast_25S_18S.fa"
alt_c_positions = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/alt_canonical_distribution/yeast_18S_25S_variants.positions"
output_path = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/small_models/small_5mer/yeast_18S_25S_variants.positions"
k=5
rna=True
kmer_mapping = create_efficient_positions_file(reference, alt_c_positions, mods_csv, output_path, k=k, rna=rna)
rna_model = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/small_models/small_5mer/rna_r94_5mer_ACGTabc.model"
edit_model_with_kmer_mapping(rna_model, kmer_mapping, rna=rna)
# Out:
# ANOTHER ITER 2
# PASS RDN25-1+45 2944 0 0
# ANOTHER ITER 39
# PASS RDN25-1+21 2129 0 0
# ANOTHER ITER 39
# PASS RDN25-1+26 2260 0 0
# ANOTHER ITER 39
# PASS RDN25-1+45 2946 0 0
# ANOTHER ITER 39
# PASS RDN25-1+21 2130 0 0
# ANOTHER ITER 39
# PASS RDN25-1+22 2137 0 0
# ANOTHER ITER 39
# PASS RDN25-1+32 2417 0 0
# ANOTHER ITER 39
# PASS RDN25-1+32 2418 0 0
# ANOTHER ITER 39
# PASS RDN25-1+34 2629 0 0
# ANOTHER ITER 39
# PASS RDN18-1+4 206 0 0
# ANOTHER ITER 39
# PASS RDN18-1+27 1410 0 0
# ANOTHER ITER 39
# PASS RDN18-1+29 1573 0 0
# ANOTHER ITER 39
# PASS RDN25-1+2 774 0 0
# ANOTHER ITER 39
# PASS RDN25-1+11 982 0 0
# ANOTHER ITER 39
# PASS RDN25-1+14 1049 0 0
# ANOTHER ITER 39
# PASS RDN25-1+21 2131 0 0
# ANOTHER ITER 38
# PASS RDN25-1+22 2139 0 0
# ANOTHER ITER 38
# PASS RDN25-1+22 2140 0 0
# ANOTHER ITER 37
# PASS RDN25-1+31 2347 0 0
# ANOTHER ITER 36
# PASS RDN25-1+33 2617 0 0
# ANOTHER ITER 36
# PASS RDN25-1+34 2632 0 0
# ANOTHER ITER 36
# PASS RDN25-1+34 2634 0 0
# ANOTHER ITER 35
# PASS RDN25-1+37 2730 0 0
# ANOTHER ITER 35
# PASS RDN25-1+39 2811 0 0
# ANOTHER ITER 35
# PASS RDN25-1+40 2821 0 0
# ANOTHER ITER 35
# PASS RDN25-1+43 2875 0 0
# ANOTHER ITER 35
# PASS RDN25-1+43 2876 0 0
# ANOTHER ITER 35
# PASS RDN25-1+45 2939 0 0
# ANOTHER ITER 35
# PASS RDN25-1+46 2955 0 0
# ANOTHER ITER 35
# PASS RDN18-1+4 207 0 0
# ANOTHER ITER 34
# PASS RDN18-1+10 537 0 0
# ANOTHER ITER 33
# PASS RDN18-1+12 578 0 0
# ANOTHER ITER 32
# PASS RDN18-1+14 627 0 0
# ANOTHER ITER 31
# PASS RDN18-1+19 997 0 0
# ANOTHER ITER 29
# PASS RDN18-1+23 1183 0 0
# ANOTHER ITER 28
# PASS RDN18-1+24 1269 0 0
# ANOTHER ITER 27
# PASS RDN25-1+45 2948 0 0
# ANOTHER ITER 26
# PASS RDN18-1+27 1412 0 0
# ANOTHER ITER 25
# PASS RDN18-1+29 1575 0 0
# ANOTHER ITER 25
# PASS RDN18-1+29 1576 0 0
# ANOTHER ITER 24
# PASS RDN25-1+2 776 0 0
# ANOTHER ITER 23
# PASS RDN25-1+6 871 0 0
# ANOTHER ITER 22
# PASS RDN25-1+7 895 0 0
# ANOTHER ITER 21
# PASS RDN25-1+8 904 0 0
# ANOTHER ITER 20
# PASS RDN25-1+39 2810 0 0
# ANOTHER ITER 20
# PASS RDN25-1+39 2812 0 0
# ANOTHER ITER 19
# PASS RDN25-1+11 990 0 0
# ANOTHER ITER 18
# PASS RDN25-1+14 1050 0 0
# ANOTHER ITER 18
# PASS RDN25-1+22 2142 0 0
# ANOTHER ITER 18
# PASS RDN25-1+34 2635 0 0
# ANOTHER ITER 18
# PASS RDN25-1+16 1122 0 0
# ANOTHER ITER 17
# PASS RDN25-1+19 1444 0 0
# ANOTHER ITER 16
# PASS RDN25-1+20 1888 0 0
# ANOTHER ITER 15
# PASS RDN25-1+21 2133 0 0
# ANOTHER ITER 14
# PASS RDN25-1+25 2215 0 0
# ANOTHER ITER 13
# PASS RDN25-1+26 2252 0 0
# ANOTHER ITER 12
# PASS RDN25-1+27 2281 0 0
# ANOTHER ITER 11
# PASS RDN25-1+28 2284 0 0
# ANOTHER ITER 10
# PASS RDN25-1+29 2310 0 0
# ANOTHER ITER 9
# PASS RDN25-1+33 2619 0 0
# ANOTHER ITER 8
# PASS RDN25-1+35 2640 0 0
# ANOTHER ITER 8
# PASS RDN25-1+45 2940 0 0
# ANOTHER ITER 7
# PASS RDN25-1+35 2641 0 0
# ANOTHER ITER 7
# PASS RDN25-1+35 2642 0 0
# ANOTHER ITER 6
# PASS RDN25-1+36 2719 0 0
# ANOTHER ITER 5
# PASS RDN25-1+37 2735 0 0
# ANOTHER ITER 4
# PASS RDN25-1+40 2822 0 0
# ANOTHER ITER 3
# PASS RDN25-1+43 2877 0 0
# ANOTHER ITER 3
# PASS RDN25-1+43 2878 0 0
# ANOTHER ITER 2
# PASS RDN25-1+42 2867 0 0
# ANOTHER ITER 2
# PASS RDN25-1+42 2868 0 0
# ANOTHER ITER 1
# PASS RDN25-1+46 2956 0 0
# DONE

# %%
kmer_mapping
# Out:
# [['ATACT', ['aTACT', 'bTACT']],
#  ['TATAC', ['TbTAC', 'TaTAC']],
#  ['GTATA', ['GTbTA', 'GTaTA']],
#  ['CGTAT', ['CGTaT', 'CGTbT']],
#  ['TCGTA', ['TCGTb', 'TCGTa']],
#  ['ACTCG', ['bCTCG', 'aCTCG']],
#  ['TACTC', ['TbCTC', 'TaCTC']],
#  ['TTACT', ['TTbCT', 'TTaCT']],
#  ['ATTAC', ['ATTbC', 'ATTaC']],
#  ['AATTA', ['AATTa', 'AATTb']],
#  ['TAAAT', ['bAAAT', 'aAAAT']],
#  ['CTAAA', ['CbAAA', 'CaAAA']],
#  ['ACTAA', ['ACaAA', 'ACbAA']],
#  ['GACTA', ['GACbA', 'GACaA']],
#  ['TGACT', ['TGACb', 'TGACa']],
#  ['TATTT', ['bATTT', 'aATTT']],
#  ['TTATT', ['TaATT', 'TbATT']],
#  ['TTTAT', ['TTbAT', 'TTaAT']],
#  ['GTTTA', ['GTTbA', 'GTTaA']],
#  ['AGTTT', ['AGTTb', 'AGTTa']],
#  ['TATTT', ['bATcc', 'aATcc']],
#  ['TTATT', ['TaATc', 'TbATc']],
#  ['ATTAT', ['ATbAT', 'ATaAT']],
#  ['GATTA', ['GATaA', 'GATbA']],
#  ['AGATT', ['AGATa', 'AGATb']],
#  ['TAAAC', ['bAAAC', 'aAAAC']],
#  ['TTAAA', ['TaAAA', 'TbAAA']],
#  ['TTTAA', ['TTaAA', 'TTbAA']],
#  ['CTTTA', ['CTTbA', 'CTTaA']],
#  ['TCTTT', ['TCTTa', 'TCTTb']],
#  ['CTACA', ['bTACA', 'aTACA']],
#  ['CCTAC', ['CaTAC', 'CbTAC']],
#  ['ACCTA', ['ACbTA', 'ACaTA']],
#  ['AACCT', ['AACbT', 'AACaT']],
#  ['GAACC', ['GAACb', 'GAACa']],
#  ['AGGAA', ['aGGAA', 'bGGAA']],
#  ['AAGGA', ['AbGGA', 'AaGGA']],
#  ['GAAGG', ['GAbGG', 'GAaGG']],
#  ['GGAAG', ['GGAaG', 'GGAbG']],
#  ['CGGAA', ['CGGAb', 'CGGAa']],
#  ['ACGCG', ['bCGCG', 'aCGCG']],
#  ['AACGC', ['AbCGC', 'AaCGC']],
#  ['AAACG', ['AAaCG', 'AAbCG']],
#  ['TAAAC', ['TAAbC', 'TAAaC']],
#  ['TTAAA', ['TTAAb', 'TTAAa']],
#  ['TGATG', ['bGATG', 'aGATG']],
#  ['GTGAT', ['GbGAT', 'GaGAT']],
#  ['AGTGA', ['AGbGA', 'AGaGA']],
#  ['CAGTG', ['CAGbG', 'CAGaG']],
#  ['ACAGT', ['ACAGa', 'ACAGb']],
#  ['AGGAG', ['bGGcG', 'aGGcG']],
#  ['AAGGA', ['AbGGc', 'AaGGc']],
#  ['CAAGG', ['CAbGG', 'CAaGG']],
#  ['ACAAG', ['ACAbG', 'ACAaG']],
#  ['AACAA', ['AACAa', 'AACAb']],
#  ['GGTCT', ['bGTCT', 'aGTCT']],
#  ['TGGTC', ['TaGTC', 'TbGTC']],
#  ['GTGGT', ['GTbGT', 'GTaGT']],
#  ['CGTGG', ['CGTbG', 'CGTaG']],
#  ['CCGTG', ['CCGTb', 'CCGTa']],
#  ['TGGCG', ['bGGCG', 'aGGCG']],
#  ['ATGGC', ['cbGGC', 'caGGC']],
#  ['AATGG', ['AcbGG', 'AcaGG']],
#  ['TAATG', ['TAcbG', 'TAcaG']],
#  ['TTAAT', ['TTAcb', 'TTAca']],
#  ['ATTGA', ['aTTGA', 'bTTGA']],
#  ['AATTG', ['AaTTG', 'AbTTG']],
#  ['AAATT', ['AAbTT', 'AAaTT']],
#  ['AAAAT', ['AAAbT', 'AAAaT']],
#  ['AAAAA', ['AAAAb', 'AAAAa']],
#  ['TGATG', ['bGATc', 'aGATc']],
#  ['TTGAT', ['TbGAT', 'TaGAT']],
#  ['GTTGA', ['GTbGA', 'GTaGA']],
#  ['AGTTG', ['AGTaG', 'AGTbG']],
#  ['AAGTT', ['AAGTa', 'AAGTb']],
#  ['TTAAA', ['aTAAA', 'bTAAA']],
#  ['ATTAA', ['AbTAA', 'AaTAA']],
#  ['GATTA', ['GAaTA', 'GAbTA']],
#  ['AGATT', ['AGAbT', 'AGAaT']],
#  ['GAGAT', ['GAGAa', 'GAGAb']],
#  ['TGTGA', ['bGTGA', 'aGTGA']],
#  ['TTGTG', ['TbGTG', 'TaGTG']],
#  ['CTTGT', ['CTbGT', 'CTaGT']],
#  ['ACTTG', ['ACTbG', 'ACTaG']],
#  ['AACTT', ['AACTb', 'AACTa']],
#  ['ATTAT', ['aTTAT', 'bTTAT']],
#  ['GATTA', ['GbTTA', 'GaTTA']],
#  ['CGATT', ['CGbTT', 'CGaTT']],
#  ['ACGAT', ['ACGaT', 'ACGbT']],
#  ['TACGA', ['TACGb', 'TACGa']],
#  ['AAGAA', ['bAGAA', 'aAGAA']],
#  ['CAAGA', ['CbAGA', 'CaAGA']],
#  ['GCAAG', ['GCaAG', 'GCbAG']],
#  ['AGCAA', ['AGCbA', 'AGCaA']],
#  ['AAGCA', ['AAGCa', 'AAGCb']],
#  ['TAGTA', ['acGTA', 'bcGTA']],
#  ['CTAGT', ['CacGT', 'CbcGT']],
#  ['ACTAG', ['ACacG', 'ACbcG']],
#  ['GACTA', ['GACac', 'GACbc']],
#  ['AGACT', ['AGACa', 'AGACb']],
#  ['CCATA', ['aCATA', 'bCATA']],
#  ['GCCAT', ['GbCAT', 'GaCAT']],
#  ['TGCCA', ['TGaCA', 'TGbCA']],
#  ['CTGCC', ['CTGbC', 'CTGaC']],
#  ['GCTGC', ['GCTGa', 'GCTGb']],
#  ['GAACG', ['aAACG', 'bAACG']],
#  ['GGAAC', ['GbAAC', 'GaAAC']],
#  ['CGGAA', ['CGbAA', 'CGaAA']],
#  ['TCGGA', ['TCGaA', 'TCGbA']],
#  ['GTCGG', ['GTCGa', 'GTCGb']],
#  ['TCGGC', ['aCGGC', 'bCGGC']],
#  ['TTCGG', ['TbCGG', 'TaCGG']],
#  ['ATTCG', ['ATaCG', 'ATbCG']],
#  ['AATTC', ['cATaC', 'cATbC']],
#  ['TAATT', ['TcATa', 'TcATb']],
#  ['TTTAA', ['aTTcA', 'bTTcA']],
#  ['GTTTA', ['GbTTc', 'GaTTc']],
#  ['AGTTT', ['AGaTT', 'AGbTT']],
#  ['CAGTT', ['CAGbT', 'CAGaT']],
#  ['TCAGT', ['bCAGb', 'aCAGb', 'bCAGa', 'aCAGa']],
#  ['TCAGT', ['bCAGb', 'aCAGb', 'bCAGa', 'aCAGa']],
#  ['CTCAG', ['CbCAG', 'CaCAG']],
#  ['ACTCA', ['ACbCA', 'ACaCA']],
#  ['AACTC', ['AACbC', 'AACaC']],
#  ['CAACT', ['CAACa', 'CAACb']],
#  ['TGGTG', ['bGGTG', 'aGGTG']],
#  ['GTGGT', ['cbGGT', 'caGGT']],
#  ['GGTGG', ['acaGG', 'acbGG', 'bcbGG', 'bcaGG']],
#  ['TGGTG', ['TacbG', 'TbcaG', 'TacaG', 'TbcbG']],
#  ['GTGGT', ['GTbcb', 'GTacb', 'GTbca', 'GTaca']],
#  ['GGTGG', ['acaGG', 'acbGG', 'bcbGG', 'bcaGG']],
#  ['TGGTG', ['TacbG', 'TbcaG', 'TacaG', 'TbcbG']],
#  ['GTGGT', ['GTbcb', 'GTacb', 'GTbca', 'GTaca']],
#  ['CGTGG', ['CGTbc', 'CGTac']],
#  ['ACGTG', ['ACGTb', 'ACGTa']],
#  ['CCGGT', ['bCGGT', 'aCGGT']],
#  ['GCCGG', ['GbCGG', 'GaCGG']],
#  ['TGCCG', ['TGbCG', 'TGaCG']],
#  ['TTGCC', ['TTGbC', 'TTGaC']],
#  ['CTTGC', ['CTTGa', 'CTTGb']],
#  ['TTGAT', ['aTGAT', 'bTGAT']],
#  ['GTTGA', ['GbTGA', 'GaTGA']],
#  ['GGTTG', ['GGbTG', 'GGaTG']],
#  ['TGGTT', ['TGGbT', 'TGGaT']],
#  ['GTGGT', ['GTGGa', 'GTGGb']],
#  ['TTTGA', ['aTcGc', 'bTcGc']],
#  ['GTTTG', ['GaTcG', 'GbTcG']],
#  ['AGTTT', ['AGaTc', 'AGbTc']],
#  ['GAGTT', ['GAGbT', 'GAGaT']],
#  ['GGAGT', ['GGAGb', 'GGAGa']],
#  ['GACAA', ['aACAA', 'bACAA']],
#  ['GGACA', ['GaACA', 'GbACA']],
#  ['TGGAC', ['TGbAC', 'TGaAC']],
#  ['CTGGA', ['CTGaA', 'CTGbA']],
#  ['TCTGG', ['TCTGa', 'TCTGb']],
#  ['GCAAC', ['bCAAC', 'aCAAC']],
#  ['AGCAA', ['AbCAA', 'AaCAA']],
#  ['GAGCA', ['cAaCA', 'cAbCA']],
#  ['GGAGC', ['acAbC', 'bcAaC', 'bcAbC', 'acAaC']],
#  ['AGGAG', ['cacAb', 'cbcAa', 'cacAa', 'cbcAb']],
#  ['GGAGC', ['acAbC', 'bcAaC', 'bcAbC', 'acAaC']],
#  ['AGGAG', ['cacAb', 'cbcAa', 'cacAa', 'cbcAb']],
#  ['AAGGA', ['ccbcA', 'ccacA']],
#  ['TAAGG', ['Tccbc', 'Tccac']],
#  ['TTAAG', ['TTcca', 'TTccb']],
#  ['CGCCA', ['bGCCA', 'aGCCA']],
#  ['CCGCC', ['CbGCC', 'CaGCC']],
#  ['CCCGC', ['CCbGC', 'CCaGC']],
#  ['GCCCG', ['GCCbG', 'GCCaG']],
#  ['TGCCC', ['TGCCb', 'TGCCa']],
#  ['CCTTT', ['aCTTT', 'bCTTT']],
#  ['GCCTT', ['GbCTT', 'GaCTT']],
#  ['TGCCT', ['TGbCT', 'TGaCT']],
#  ['ATGCC', ['ATGaC', 'ATGbC']],
#  ['GATGC', ['GATGb', 'GATGa']],
#  ['AGTGG', ['bGTGG', 'aGTGG']],
#  ['AAGTG', ['bbGTG', 'abGTG', 'aaGTG', 'baGTG']],
#  ['CAAGT', ['CaaGT', 'CabGT', 'CbaGT', 'CbbGT']],
#  ['CCAAG', ['CCbaG', 'CCabG', 'CCaaG', 'CCbbG']],
#  ['TCCAA', ['TCCba', 'TCCab', 'TCCbb', 'TCCaa']],
#  ['AAGTG', ['bbGTG', 'abGTG', 'aaGTG', 'baGTG']],
#  ['CAAGT', ['CaaGT', 'CabGT', 'CbaGT', 'CbbGT']],
#  ['CCAAG', ['CCbaG', 'CCabG', 'CCaaG', 'CCbbG']],
#  ['TCCAA', ['TCCba', 'TCCab', 'TCCbb', 'TCCaa']],
#  ['GTCCA', ['GTCCb', 'GTCCa']],
#  ['AGTTC', ['aGTTC', 'bGTTC']],
#  ['AAGTT', ['AbGTT', 'AaGTT']],
#  ['AAAGT', ['AAaGT', 'AAbGT']],
#  ['CAAAG', ['CAAbG', 'CAAaG']],
#  ['ACAAA', ['aCAAb', 'bCAAa', 'bCAAb', 'aCAAa']],
#  ['ACAAA', ['aCAAb', 'bCAAa', 'bCAAb', 'aCAAa']],
#  ['CACAA', ['bbCAA', 'aaCAA', 'abCAA', 'baCAA']],
#  ['GCACA', ['GbbCA', 'GaaCA', 'GabCA', 'GbaCA']],
#  ['GGCAC', ['GGbaC', 'GGabC', 'GGbbC', 'GGaaC']],
#  ['AGGCA', ['AGGbb', 'AGGaa', 'AGGba', 'AGGab']],
#  ['CACAA', ['bbCAA', 'aaCAA', 'abCAA', 'baCAA']],
#  ['GCACA', ['GbbCA', 'GaaCA', 'GabCA', 'GbaCA']],
#  ['GGCAC', ['GGbaC', 'GGabC', 'GGbbC', 'GGaaC']],
#  ['AGGCA', ['AGGbb', 'AGGaa', 'AGGba', 'AGGab']],
#  ['CAGGC', ['CAGGb', 'CAGGa']],
#  ['CTGAG', ['bTGAG', 'aTGAG']],
#  ['TCTGA', ['TaTGA', 'TbTGA']],
#  ['ATCTG', ['ATaTG', 'ATbTG']],
#  ['AATCT', ['AATbT', 'AATaT']],
#  ['CAATC', ['CAATb', 'CAATa']],
#  ['TAGGT', ['bcGGT', 'acGGT']],
#  ['TTAGG', ['cacGG', 'cbcGG']],
#  ['TTTAG', ['TcbcG', 'TcacG']],
#  ['GTTTA', ['GTcac', 'GTcbc']],
#  ['AGTTT', ['AGTca', 'AGTcb']],
#  ['GCCCA', ['aCCCA', 'bCCCA']],
#  ['AGCCC', ['AbCCC', 'AaCCC']],
#  ['AAGCC', ['bAbCC', 'bAaCC', 'aAaCC', 'aAbCC']],
#  ['AAAGC', ['AbAbC', 'AaAbC', 'AaAaC', 'AbAaC']],
#  ['GAAAG', ['GAaAa', 'GAbAa', 'GAaAb', 'GAbAb']],
#  ['AAGCC', ['bAbCC', 'bAaCC', 'aAaCC', 'aAbCC']],
#  ['AAAGC', ['AbAbC', 'AaAbC', 'AaAaC', 'AbAaC']],
#  ['GAAAG', ['GAaAa', 'GAbAa', 'GAaAb', 'GAbAb']],
#  ['AGAAA', ['AGAaA', 'AGAbA']],
#  ['TAGAA', ['TAGAb', 'TAGAa']],
#  ['AAGTG', ['bAGTG', 'aAGTG']],
#  ['CAAGT', ['CaAGT', 'CbAGT']],
#  ['TCAAG', ['TCaAG', 'TCbAG']],
#  ['ATCAA', ['ATCbA', 'ATCaA']],
#  ['TATCA', ['TATCa', 'TATCb']],
#  ['GATGC', ['bATGC', 'aATGC']],
#  ['CGATG', ['CbATG', 'CaATG']],
#  ['GCGAT', ['GCbAT', 'GCaAT']],
#  ['GGCGA', ['GGCaA', 'GGCbA']],
#  ['TGGCG', ['TGGCa', 'TGGCb']],
#  ['AGTCT', ['bGTCc', 'aGTCc']],
#  ['CAGTC', ['CbGTC', 'CaGTC']],
#  ['GCAGT', ['GCbGT', 'GCaGT']],
#  ['TGCAG', ['TGCaG', 'TGCbG']],
#  ['GTGCA', ['GTGCb', 'GTGCa']],
#  ['TTAAG', ['aTcAG', 'bTcAG']],
#  ['TTTAA', ['TbTcA', 'TaTcA']],
#  ['GTTTA', ['GTaTc', 'GTbTc']],
#  ['GGTTT', ['GGTbT', 'GGTaT']],
#  ['GGGTT', ['GGGTb', 'GGGTa']],
#  ['GGATA', ['aGAcA', 'bGAcA']],
#  ['GGGAT', ['GbGAc', 'GaGAc']],
#  ['GGGGA', ['GGbGA', 'GGaGA']],
#  ['CGGGG', ['CGGbG', 'CGGaG']],
#  ['GCGGG', ['GCGGb', 'GCGGa']],
#  ['TCCCT', ['bCCCT', 'aCCCT']],
#  ['CTCCC', ['CbCCC', 'CaCCC']],
#  ['ACTCC', ['ACbCC', 'ACaCC']],
#  ['GACTC', ['GACbC', 'GACaC']],
#  ['GGACT', ['GGACb', 'GGACa']],
#  ['TAGGA', ['bAGGA', 'aAGGA']],
#  ['ATAGG', ['AaAGG', 'AbAGG']],
#  ['GATAG', ['GAaAG', 'GAbAG']],
#  ['CGATA', ['CGAaA', 'CGAbA']],
#  ['ACGAT', ['ACGAa', 'ACGAb']],
#  ['TTGAC', ['bTGcC', 'aTGcC']],
#  ['TTTGA', ['TaTGc', 'TbTGc']],
#  ['TTTTG', ['TTbTG', 'TTaTG']],
#  ['ATTTT', ['ATTaT', 'ATTbT']],
#  ['TATTT', ['aATTb', 'aATTa', 'bATTb', 'bATTa']],
#  ['TATTT', ['aATTb', 'aATTa', 'bATTb', 'bATTa']],
#  ['GTATT', ['cbATT', 'caATT']],
#  ['AGTAT', ['AcbAT', 'AcaAT']],
#  ['GAGTA', ['GAcbA', 'GAcaA']],
#  ['GGAGT', ['GGAca', 'GGAcb']],
#  ['TAAGC', ['bAAGC', 'aAAGC']],
#  ['GTAAG', ['GaAAG', 'GbAAG']],
#  ['AGTAA', ['AGaAA', 'AGbAA']],
#  ['TAGTA', ['TAGaA', 'TAGbA']],
#  ['TTAGT', ['TTAGa', 'TTAGb']],
#  ['TTATC', ['bTATC', 'aTATC']],
#  ['CTTAT', ['CaTAT', 'CbTAT']],
#  ['TCTTA', ['TCaTA', 'TCbTA']],
#  ['CTCTT', ['CTCaT', 'CTCbT']],
#  ['ACTCT', ['ACTCa', 'ACTCb']],
#  ['TTTCA', ['accCA', 'bccCA']],
#  ['ATTTC', ['AbccC', 'AaccC']],
#  ['AATTT', ['AAacc', 'AAbcc']],
#  ['AAATT', ['AAAbc', 'AAAac']],
#  ['TAAAT', ['aAAAa', 'bAAAa', 'bAAAb', 'aAAAb']],
#  ['TAAAT', ['aAAAa', 'bAAAa', 'bAAAb', 'aAAAb']],
#  ['ATAAA', ['AaAAA', 'AbAAA']],
#  ['TATAA', ['TAbAA', 'TAaAA']],
#  ['GTATA', ['GTAaA', 'GTAbA']],
#  ['TGTAT', ['TGTAb', 'TGTAa']],
#  ['TTTCG', ['aTTCG', 'bTTCG']],
#  ['TTTTC', ['TaTTC', 'TbTTC']],
#  ['ATTTT', ['ATaTT', 'ATbTT']],
#  ['GATTT', ['GATbT', 'GATaT']],
#  ['TGATT', ['TGATa', 'TGATb']],
#  ['TTTTA', ['acTTA', 'bcTTA']],
#  ['TTTTT', ['TbcTT', 'TacTT']],
#  ['GTTTT', ['GTacT', 'GTbcT']],
#  ['GGTTT', ['GGTbc', 'GGTac']],
#  ['TGGTT', ['TGGTa', 'TGGTb']],
#  ['ACGAA', ['aCGAA', 'bCGAA']],
#  ['GACGA', ['GbCGA', 'GaCGA']],
#  ['AGACG', ['AGaCG', 'AGbCG']],
#  ['AAGAC', ['AAGbC', 'AAGaC']],
#  ['CAAGA', ['CAAGa', 'CAAGb']],
#  ['CTAGA', ['aTAGA', 'bTAGA']],
#  ['TCTAG', ['TaTAG', 'TbTAG']],
#  ['TTCTA', ['TTbTA', 'TTaTA']],
#  ['GTTCT', ['GTTbT', 'GTTaT']],
#  ['GGTTC', ['GGTTa', 'GGTTb']],
#  ['ATGAT', ['bTGAc', 'aTGAc']],
#  ['GATGA', ['bbTGA', 'baTGA', 'abTGA', 'aaTGA']],
#  ['CGATG', ['CaaTG', 'CbaTG', 'CabTG', 'CbbTG']],
#  ['ACGAT', ['ACabT', 'ACbaT', 'ACaaT', 'ACbbT']],
#  ['AACGA', ['AACaa', 'AACbb', 'AACba', 'AACab']],
#  ['GATGA', ['bbTGA', 'baTGA', 'abTGA', 'aaTGA']],
#  ['CGATG', ['CaaTG', 'CbaTG', 'CabTG', 'CbbTG']],
#  ['ACGAT', ['ACabT', 'ACbaT', 'ACaaT', 'ACbbT']],
#  ['AACGA', ['AACaa', 'AACbb', 'AACba', 'AACab']],
#  ['AAACG', ['AAACb', 'AAACa']],
#  ['TAATA', ['bAATA', 'aAATA']],
#  ['GTAAT', ['cbAAT', 'caAAT']],
#  ['TGTAA', ['TcaAA', 'TcbAA']],
#  ['ATGTA', ['ATcbA', 'ATcaA']],
#  ['GATGT', ['GATca', 'GATcb']],
#  ['TCTAA', ['bCTAA', 'aCTAA']],
#  ['GTCTA', ['cbCTA', 'caCTA']],
#  ['AGTCT', ['ccaCT', 'ccbCT']],
#  ['CAGTC', ['cccaC', 'cccbC']],
#  ['TCAGT', ['accca', 'bcccb', 'acccb', 'bccca']],
#  ['TCAGT', ['accca', 'bcccb', 'acccb', 'bccca']],
#  ['GTCAG', ['cbccc', 'caccc']],
#  ['TGTCA', ['Tcbcc', 'Tcacc']],
#  ['CTGTC', ['CTcac', 'CTcbc']],
#  ['TCTGT', ['TCTcb', 'TCTca']],
#  ['ATTAA', ['bccAc', 'accAc']],
#  ['AATTA', ['cbccA', 'caccA']],
#  ['AAATT', ['Acbcc', 'Acacc']],
#  ['AAAAT', ['AAcac', 'AAcbc']],
#  ['CAAAA', ['CAAcb', 'CAAca']],
#  ['TTTAG', ['aTTAG', 'bTTAG']],
#  ['CTTTA', ['CbTTA', 'CaTTA']],
#  ['TCTTT', ['TCbTT', 'TCaTT']],
#  ['GTCTT', ['GTCbT', 'GTCaT']],
#  ['CGTCT', ['CGTCa', 'CGTCb']],
#  ['CCCGT', ['aCCGT', 'bCCGT']],
#  ['ACCCG', ['AbCCG', 'AaCCG']],
#  ['GACCC', ['GAaCC', 'GAbCC']],
#  ['TGACC', ['TGAbC', 'TGAaC']],
#  ['GTGAC', ['GTGAa', 'GTGAb']],
#  ['AAGTG', ['aAGTc', 'bAGTc']],
#  ['GAAGT', ['GaAGT', 'GbAGT']],
#  ['AGAAG', ['AGbAG', 'AGaAG']],
#  ['AAGAA', ['AAGbA', 'AAGaA']],
#  ['AAAGA', ['AAAGb', 'AAAGa']],
#  ['AATGA', ['aATcA', 'bATcA']],
#  ['CAATG', ['CbATc', 'CaATc']],
#  ['TCAAT', ['aCbAT', 'bCaAT', 'aCaAT', 'bCbAT']],
#  ['ATCAA', ['AaCbA', 'AaCaA', 'AbCaA', 'AbCbA']],
#  ['TATCA',
#   ['aAaCa', 'aAbCb', 'aAbCa', 'bAaCb', 'bAaCa', 'bAbCa', 'aAaCb', 'bAbCb']],
#  ['TCAAT', ['aCbAT', 'bCaAT', 'aCaAT', 'bCbAT']],
#  ['ATCAA', ['AaCbA', 'AaCaA', 'AbCaA', 'AbCbA']],
#  ['TATCA',
#   ['aAaCa', 'aAbCb', 'aAbCa', 'bAaCb', 'bAaCa', 'bAbCa', 'aAaCb', 'bAbCb']],
#  ['GTATC', ['caAbC', 'cbAbC', 'cbAaC', 'caAaC']],
#  ['AGTAT', ['AcbAa', 'AcaAa', 'AcbAb', 'AcaAb']],
#  ['TATCA',
#   ['aAaCa', 'aAbCb', 'aAbCa', 'bAaCb', 'bAaCa', 'bAbCa', 'aAaCb', 'bAbCb']],
#  ['GTATC', ['caAbC', 'cbAbC', 'cbAaC', 'caAaC']],
#  ['AGTAT', ['AcbAa', 'AcaAa', 'AcbAb', 'AcaAb']],
#  ['CAGTA', ['CAcaA', 'CAcbA']],
#  ['TCAGT', ['aCAca', 'aCAcb', 'bCAca', 'bCAcb']],
#  ['TCAGT', ['aCAca', 'aCAcb', 'bCAca', 'bCAcb']],
#  ['CTCAG', ['CaCAc', 'CbCAc']],
#  ['TCTCA', ['bCbCA', 'aCbCA', 'aCaCA', 'bCaCA']],
#  ['CTCTC', ['CaCaC', 'CaCbC', 'CbCaC', 'CbCbC']],
#  ['TCTCT', ['TCbCa', 'TCbCb', 'TCaCa', 'TCaCb']],
#  ['TCTCA', ['bCbCA', 'aCbCA', 'aCaCA', 'bCaCA']],
#  ['CTCTC', ['CaCaC', 'CaCbC', 'CbCaC', 'CbCbC']],
#  ['TCTCT', ['TCbCa', 'TCbCb', 'TCaCa', 'TCaCb']],
#  ['TTCTC', ['TTCaC', 'TTCbC']],
#  ['ATTCT', ['ATTCb', 'ATTCa']],
#  ['CCGAT', ['bCGAT', 'aCGAT']],
#  ['ACCGA', ['AaCGA', 'AbCGA']],
#  ['AACCG', ['aAaCG', 'bAaCG', 'aAbCG', 'bAbCG']],
#  ['AAACC',
#   ['bbAbC', 'bbAaC', 'abAaC', 'baAaC', 'baAbC', 'abAbC', 'aaAbC', 'aaAaC']],
#  ['TAAAC',
#   ['cbbAa', 'caaAb', 'caaAa', 'cabAb', 'cbaAb', 'cbaAa', 'cabAa', 'cbbAb']],
#  ['AACCG', ['aAaCG', 'bAaCG', 'aAbCG', 'bAbCG']],
#  ['AAACC',
#   ['bbAbC', 'bbAaC', 'abAaC', 'baAaC', 'baAbC', 'abAbC', 'aaAbC', 'aaAaC']],
#  ['TAAAC',
#   ['cbbAa', 'caaAb', 'caaAa', 'cabAb', 'cbaAb', 'cbaAa', 'cabAa', 'cbbAb']],
#  ['GTAAA', ['GcaaA', 'GcbaA', 'GcabA', 'GcbbA']],
#  ['CGTAA', ['CGcba', 'CGcab', 'CGcbb', 'CGcaa']],
#  ['AAACC',
#   ['bbAbC', 'bbAaC', 'abAaC', 'baAaC', 'baAbC', 'abAbC', 'aaAbC', 'aaAaC']],
#  ['TAAAC',
#   ['cbbAa', 'caaAb', 'caaAa', 'cabAb', 'cbaAb', 'cbaAa', 'cabAa', 'cbbAb']],
#  ['GTAAA', ['GcaaA', 'GcbaA', 'GcabA', 'GcbbA']],
#  ['CGTAA', ['CGcba', 'CGcab', 'CGcbb', 'CGcaa']],
#  ['CCGTA', ['cCGcb', 'cCGca']],
#  ['GCTCC', ['aCTcC', 'bCTcC']],
#  ['TGCTC', ['TaCTc', 'TbCTc']],
#  ['CTGCT', ['CTaCT', 'CTbCT']],
#  ['ACTGC', ['ACTaC', 'ACTbC']],
#  ['TACTG', ['TACTa', 'TACTb']],
#  ['TAAGT', ['bAAcT', 'aAAcT']],
#  ['GTAAG', ['GaAAc', 'GbAAc']],
#  ['GGTAA', ['GGbAA', 'GGaAA']],
#  ['AGGTA', ['AGGaA', 'AGGbA']],
#  ['TAGGT', ['TAGGb', 'TAGGa']],
#  ['CTGTC', ['bTGTC', 'aTGTC']],
#  ['CCTGT', ['CbTGT', 'CaTGT']],
#  ['CCCTG', ['CCbTG', 'CCaTG']],
#  ['TCCCT', ['aCCaT', 'aCCbT', 'bCCbT', 'bCCaT']],
#  ['ATCCC', ['AbCCa', 'AbCCb', 'AaCCa', 'AaCCb']],
#  ['TCCCT', ['aCCaT', 'aCCbT', 'bCCbT', 'bCCaT']],
#  ['ATCCC', ['AbCCa', 'AbCCb', 'AaCCa', 'AaCCb']],
#  ['TATCC', ['TAaCC', 'TAbCC']],
#  ['CTATC', ['CTAbC', 'CTAaC']],
#  ['TCTAT', ['TCTAb', 'TCTAa']],
#  ['TCATC', ['aCATC', 'bCATC']],
#  ['ATCAT', ['caCAT', 'cbCAT']],
#  ['TATCA', ['acaCA', 'bcbCA', 'acbCA', 'bcaCA']],
#  ['CTATC', ['CacbC', 'CbcbC', 'CbcaC', 'CacaC']],
#  ['TCTAT',
#   ['bCbcb', 'aCbca', 'bCbca', 'aCaca', 'aCacb', 'bCaca', 'aCbcb', 'bCacb']],
#  ['TATCA', ['acaCA', 'bcbCA', 'acbCA', 'bcaCA']],
#  ['CTATC', ['CacbC', 'CbcbC', 'CbcaC', 'CacaC']],
#  ['TCTAT',
#   ['bCbcb', 'aCbca', 'bCbca', 'aCaca', 'aCacb', 'bCaca', 'aCbcb', 'bCacb']],
#  ['ATCTA', ['AbCbc', 'AaCbc', 'AaCac', 'AbCac']],
#  ['GATCT', ['GAbCa', 'GAaCa', 'GAbCb', 'GAaCb']],
#  ['TCTAT',
#   ['bCbcb', 'aCbca', 'bCbca', 'aCaca', 'aCacb', 'bCaca', 'aCbcb', 'bCacb']],
#  ['ATCTA', ['AbCbc', 'AaCbc', 'AaCac', 'AbCac']],
#  ['GATCT', ['GAbCa', 'GAaCa', 'GAbCb', 'GAaCb']],
#  ['CGATC', ['CGAaC', 'CGAbC']],
#  ['GCGAT', ['GCGAb', 'GCGAa']],
#  ['TCGAG', ['aCGAG', 'bCGAG']],
#  ['TTCGA', ['baCGA', 'abCGA', 'aaCGA', 'bbCGA']],
#  ['GTTCG', ['cbaCG', 'cabCG', 'cbbCG', 'caaCG']],
#  ['AGTTC', ['ccaaC', 'ccabC', 'ccbbC', 'ccbaC']],
#  ['CAGTT', ['Cccba', 'Cccaa', 'Cccbb', 'Cccab']],
#  ['TTCGA', ['baCGA', 'abCGA', 'aaCGA', 'bbCGA']],
#  ['GTTCG', ['cbaCG', 'cabCG', 'cbbCG', 'caaCG']],
#  ['AGTTC', ['ccaaC', 'ccabC', 'ccbbC', 'ccbaC']],
#  ['CAGTT', ['Cccba', 'Cccaa', 'Cccbb', 'Cccab']],
#  ['TCAGT', ['bCcca', 'aCcca', 'aCccb', 'bCccb']],
#  ['TCAGT', ['bCcca', 'aCcca', 'aCccb', 'bCccb']],
#  ['CTCAG', ['CbCcc', 'CaCcc']],
#  ['TCTCA', ['TCbCc', 'TCaCc']],
#  ['ATCTC', ['ATCaC', 'ATCbC']],
#  ['GATCT', ['GATCb', 'GATCa']],
#  ['GGTCG', ['bcTCG', 'acTCG']],
#  ['GGGTC', ['cbcTC', 'cacTC']],
#  ['GGGGT', ['GcbcT', 'GcacT']],
#  ['CGGGG', ['CGcac', 'CGcbc']],
#  ['GCGGG', ['GCGcb', 'GCGca']],
#  ['TTGTC', ['acGTc', 'bcGTc']],
#  ['ATTGT', ['cbcGT', 'cacGT']],
#  ['AATTG', ['ccacG', 'ccbcG']],
#  ['AAATT', ['Accac', 'Accbc']],
#  ['CAAAT', ['CAcca', 'CAccb']],
#  ['AGCAA', ['bGCAc', 'aGCAc']],
#  ['TAGCA', ['caGCA', 'cbGCA']],
#  ['ATAGC', ['ccaGC', 'ccbGC']],
#  ['AATAG', ['cccaG', 'cccbG']],
#  ['CAATA', ['Ccccb', 'Cccca']],
#  ['TTTAG', ['bTTAc', 'aTTAc']],
#  ['TTTTA', ['TbTTA', 'TaTTA']],
#  ['CTTTT', ['CTaTT', 'CTbTT']],
#  ['ACTTT', ['ACTaT', 'ACTbT']],
#  ['GACTT', ['GACTb', 'GACTa']],
#  ['TGACT', ['bGACT', 'aGACT']],
#  ['GTGAC', ['GbGAC', 'GaGAC']],
#  ['TGTGA', ['cGbGA', 'cGaGA']],
#  ['GTGTG', ['GcGbG', 'GcGaG']],
#  ['AGTGT', ['AGcGb', 'AGcGa']],
#  ['TAAGT', ['aAAGc', 'bAAGc']],
#  ['ATAAG', ['caAAG', 'cbAAG']],
#  ['CATAA', ['CcbAA', 'CcaAA']],
#  ['ACATA', ['ACcbA', 'ACcaA']],
#  ['AACAT', ['AACca', 'AACcb']],
#  ['GATCG', ['aATCG', 'bATCG']],
#  ['AGATC', ['AbATC', 'AaATC']],
#  ['GAGAT', ['aAaAT', 'aAbAT', 'bAaAT', 'bAbAT']],
#  ['GGAGA', ['GaAaA', 'GbAaA', 'GaAbA', 'GbAbA']],
#  ['TGGAG', ['TGaAb', 'TGbAb', 'TGaAa', 'TGbAa']],
#  ['GAGAT', ['aAaAT', 'aAbAT', 'bAaAT', 'bAbAT']],
#  ['GGAGA', ['GaAaA', 'GbAaA', 'GaAbA', 'GbAbA']],
#  ['TGGAG', ['TGaAb', 'TGbAb', 'TGaAa', 'TGbAa']],
#  ['GTGGA', ['GTGaA', 'GTGbA']],
#  ['CGTGG', ['CGTGa', 'CGTGb']],
#  ['GGACA', ['bGccc', 'aGccc']],
#  ['GGGAC', ['GaGcc', 'GbGcc']],
#  ['AGGGA', ['AGaGc', 'AGbGc']],
#  ['TAGGG', ['TAGaG', 'TAGbG']],
#  ['ATAGG', ['ATAGa', 'ATAGb']],
#  ['TCGGT', ['aCGcc', 'bCGcc']],
#  ['TTCGG', ['TaCGc', 'TbCGc']],
#  ['GTTCG', ['GTaCG', 'GTbCG']],
#  ['TGTTC', ['TGTaC', 'TGTbC']],
#  ['GTGTT', ['GTGTb', 'GTGTa']],
#  ['TTGCG', ['aTGCG', 'bTGCG']],
#  ['CTTGC', ['CaTGC', 'CbTGC']],
#  ['ACTTG', ['ACbTG', 'ACaTG']],
#  ['TACTT', ['TACbT', 'TACaT']],
#  ['ATACT', ['ATACb', 'ATACa']],
#  ['TAGTT', ['bAGTT', 'aAGTT']],
#  ['TTAGT', ['TbAGT', 'TaAGT']],
#  ['CTTAG', ['CTaAG', 'CTbAG']],
#  ['TCTTA', ['cCTbA', 'cCTaA']],
#  ['TTCTT', ['ccCTb', 'ccCTa']],
#  ['CTTCT', ['bccCT', 'accCT']],
#  ['GCTTC', ['GbccC', 'GaccC']],
#  ['AGCTT', ['AGacc', 'AGbcc']],
#  ['TAGCT', ['TAGac', 'TAGbc']],
#  ['GTAGC', ['GTAGb', 'GTAGa']],
#  ['TCGGC', ['bcccc', 'acccc']],
#  ['CTCGG', ['Caccc', 'Cbccc']],
#  ['TCTCG', ['TCbcc', 'TCacc']],
#  ['TTCTC', ['TTCac', 'TTCbc']],
#  ['CTTCT', ['CTTCb', 'CTTCa']],
#  ['TTAGG', ['bTAGG', 'aTAGG']],
#  ['GTTAG', ['bbTAG', 'aaTAG', 'baTAG', 'abTAG']],
#  ['TGTTA',
#   ['abbTA', 'babTA', 'baaTA', 'bbbTA', 'abaTA', 'bbaTA', 'aabTA', 'aaaTA']],
#  ['TTGTT',
#   ['TbbbT', 'TabbT', 'TbbaT', 'TaabT', 'TbabT', 'TbaaT', 'TaaaT', 'TabaT']],
#  ['CTTGT',
#   ['CTbba', 'CTaaa', 'CTbaa', 'CTaab', 'CTbab', 'CTbbb', 'CTaba', 'CTabb']],
#  ['GTTAG', ['bbTAG', 'aaTAG', 'baTAG', 'abTAG']],
#  ['TGTTA',
#   ['abbTA', 'babTA', 'baaTA', 'bbbTA', 'abaTA', 'bbaTA', 'aabTA', 'aaaTA']],
#  ['TTGTT',
#   ['TbbbT', 'TabbT', 'TbbaT', 'TaabT', 'TbabT', 'TbaaT', 'TaaaT', 'TabaT']],
#  ['CTTGT',
#   ['CTbba', 'CTaaa', 'CTbaa', 'CTaab', 'CTbab', 'CTbbb', 'CTaba', 'CTabb']],
#  ['ACTTG', ['ACTaa', 'ACTbb', 'ACTba', 'ACTab']],
#  ['TGTTA',
#   ['abbTA', 'babTA', 'baaTA', 'bbbTA', 'abaTA', 'bbaTA', 'aabTA', 'aaaTA']],
#  ['TTGTT',
#   ['TbbbT', 'TabbT', 'TbbaT', 'TaabT', 'TbabT', 'TbaaT', 'TaaaT', 'TabaT']],
#  ['CTTGT',
#   ['CTbba', 'CTaaa', 'CTbaa', 'CTaab', 'CTbab', 'CTbbb', 'CTaba', 'CTabb']],
#  ['ACTTG', ['ACTaa', 'ACTbb', 'ACTba', 'ACTab']],
#  ['CACTT', ['CACTb', 'CACTa']],
#  ['TGCAA', ['bGCcc', 'aGCcc']],
#  ['GTGCA', ['cbGCc', 'caGCc']],
#  ['AGTGC', ['bcaGC', 'acbGC', 'acaGC', 'bcbGC']],
#  ['GAGTG', ['cbcaG', 'cacaG', 'cacbG', 'cbcbG']],
#  ['CGAGT',
#   ['bcacb', 'acaca', 'acbcb', 'bcbca', 'bcaca', 'bcbcb', 'acbca', 'acacb']],
#  ['AGTGC', ['bcaGC', 'acbGC', 'acaGC', 'bcbGC']],
#  ['GAGTG', ['cbcaG', 'cacaG', 'cacbG', 'cbcbG']],
#  ['CGAGT',
#   ['bcacb', 'acaca', 'acbcb', 'bcbca', 'bcaca', 'bcbcb', 'acbca', 'acacb']],
#  ['TCGAG', ['cacac', 'cacbc', 'cbcac', 'cbcbc']],
#  ['GTCGA', ['Gcbcb', 'Gcaca', 'Gcbca', 'Gcacb']],
#  ['CGAGT',
#   ['bcacb', 'acaca', 'acbcb', 'bcbca', 'bcaca', 'bcbcb', 'acbca', 'acacb']],
#  ['TCGAG', ['cacac', 'cacbc', 'cbcac', 'cbcbc']],
#  ['GTCGA', ['Gcbcb', 'Gcaca', 'Gcbca', 'Gcacb']],
#  ['GGTCG', ['GGcac', 'GGcbc']],
#  ['GGGTC', ['GGGcb', 'GGGca']],
#  ['CAGAT', ['aAccT', 'bAccT']],
#  ['CCAGA', ['CbAcc', 'CaAcc']],
#  ['GCCAG', ['GCbAc', 'GCaAc']],
#  ['TGCCA', ['TGCaA', 'TGCbA']],
#  ['CTGCC', ['CTGCa', 'CTGCb']],
#  ['TTGGA', ['aTGGA', 'bTGGA']],
#  ['ATTGG', ['AbTGG', 'AaTGG']],
#  ['GATTG', ['GAaTG', 'GAbTG']],
#  ['TGATT', ['TGAaT', 'TGAbT']],
#  ['TTGAT', ['TTGAb', 'TTGAa']]]

# %%
mods_csv = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/mod_files/mod_file.csv"
reference = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/yeast_25S_18S.fa"
alt_c_positions = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/alt_canonical_distribution/yeast_18S_25S_variants.positions"
output_path = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/small_models/small_6mer/yeast_18S_25S_variants.positions"
k=6
rna=True
ambig_positions = alt_c_positions
kmer_mapping = create_efficient_positions_file(reference, ambig_positions, mods_csv, output_path, k=k, rna=rna)
rna_model = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/small_models/small_6mer/rna_r94_6mer_ACGTabc.model"
edit_model_with_kmer_mapping(rna_model, kmer_mapping, rna=rna)
# Out:
# ANOTHER ITER 2
# PASS RDN25-1+41 2944 0 0
# ANOTHER ITER 13
# PASS RDN18-1+26 1573 0 0
# ANOTHER ITER 13
# PASS RDN25-1+21 2136 0 0
# ANOTHER ITER 13
# PASS RDN25-1+24 2260 0 0
# ANOTHER ITER 12
# PASS RDN25-1+30 2417 0 0
# ANOTHER ITER 12
# PASS RDN25-1+30 2418 0 0
# ANOTHER ITER 11
# PASS RDN25-1+32 2632 0 0
# ANOTHER ITER 11
# PASS RDN18-1+3 206 0 0
# ANOTHER ITER 10
# PASS RDN18-1+26 1575 0 0
# ANOTHER ITER 9
# PASS RDN25-1+2 774 0 0
# ANOTHER ITER 8
# PASS RDN25-1+13 1049 0 0
# ANOTHER ITER 7
# PASS RDN25-1+20 2130 0 0
# ANOTHER ITER 6
# PASS RDN25-1+21 2139 0 0
# ANOTHER ITER 6
# PASS RDN25-1+21 2140 0 0
# ANOTHER ITER 5
# PASS RDN25-1+32 2634 0 0
# ANOTHER ITER 5
# PASS RDN25-1+31 2617 0 0
# ANOTHER ITER 4
# SKIPPING RDN25-1+ 2640 1 0
# ANOTHER ITER 4
# SKIPPING RDN25-1+ 2640 1 1
# ANOTHER ITER 4
# PASS RDN25-1+32 2641 1 1
# ANOTHER ITER 3
# PASS RDN25-1+33 2719 1 1
# ANOTHER ITER 2
# PASS RDN25-1+41 2949 1 1
# ANOTHER ITER 1
# PASS RDN25-1+42 2956 1 1
# DONE

# %%
kmer_mapping
# Out:
# [['ATACTG', ['aTACTG', 'bTACTG']],
#  ['TATACT', ['TaTACT', 'TbTACT']],
#  ['GTATAC', ['GTbTAC', 'GTaTAC']],
#  ['CGTATA', ['CGTaTA', 'CGTbTA']],
#  ['TCGTAT', ['TCGTaT', 'TCGTbT']],
#  ['TTCGTA', ['TTCGTb', 'TTCGTa']],
#  ['ACTCGG', ['aCTCGG', 'bCTCGG']],
#  ['TACTCG', ['TbCTCG', 'TaCTCG']],
#  ['TTACTC', ['TTbCTC', 'TTaCTC']],
#  ['ATTACT', ['ATTbCT', 'ATTaCT']],
#  ['AATTAC', ['AATTaC', 'AATTbC']],
#  ['AAATTA', ['AAATTa', 'AAATTb']],
#  ['TAAATT', ['aAAATT', 'bAAATT']],
#  ['CTAAAT', ['CbAAAT', 'CaAAAT']],
#  ['ACTAAA', ['ACbAAA', 'ACaAAA']],
#  ['GACTAA', ['GACbAA', 'GACaAA']],
#  ['TGACTA', ['TGACbA', 'TGACaA']],
#  ['TTGACT', ['TTGACa', 'TTGACb']],
#  ['TATTTG', ['aATTTG', 'bATTTG']],
#  ['TTATTT', ['TbATTT', 'TaATTT']],
#  ['TTTATT', ['TTaATT', 'TTbATT']],
#  ['GTTTAT', ['GTTbAT', 'GTTaAT']],
#  ['AGTTTA', ['AGTTaA', 'AGTTbA']],
#  ['TAGTTT', ['TAGTTb', 'TAGTTa']],
#  ['TATTTA', ['bATTcA', 'aATTcA']],
#  ['TTATTT', ['TaATTc', 'TbATTc']],
#  ['ATTATT', ['ATaATT', 'ATbATT']],
#  ['GATTAT', ['GATaAT', 'GATbAT']],
#  ['AGATTA', ['AGATaA', 'AGATbA']],
#  ['TAGATT', ['TAGATb', 'TAGATa']],
#  ['TAAACT', ['aAAACT', 'bAAACT']],
#  ['TTAAAC', ['TaAAAC', 'TbAAAC']],
#  ['TTTAAA', ['TTaAAA', 'TTbAAA']],
#  ['CTTTAA', ['CTTaAA', 'CTTbAA']],
#  ['TCTTTA', ['TCTTbA', 'TCTTaA']],
#  ['GTCTTT', ['GTCTTa', 'GTCTTb']],
#  ['CTACAC', ['aTACAC', 'bTACAC']],
#  ['CCTACA', ['CaTACA', 'CbTACA']],
#  ['ACCTAC', ['ACbTAC', 'ACaTAC']],
#  ['AACCTA', ['AACaTA', 'AACbTA']],
#  ['GAACCT', ['GAACbT', 'GAACaT']],
#  ['GGAACC', ['GGAACb', 'GGAACa']],
#  ['AGGAAC', ['bGGAAC', 'aGGAAC']],
#  ['AAGGAA', ['AaGGAA', 'AbGGAA']],
#  ['GAAGGA', ['GAbGGA', 'GAaGGA']],
#  ['GGAAGG', ['GGAbGG', 'GGAaGG']],
#  ['CGGAAG', ['CGGAaG', 'CGGAbG']],
#  ['ACGGAA', ['ACGGAb', 'ACGGAa']],
#  ['ACGCGC', ['bCGCGC', 'aCGCGC']],
#  ['AACGCG', ['AbCGCG', 'AaCGCG']],
#  ['AAACGC', ['AAbCGC', 'AAaCGC']],
#  ['TAAACG', ['TAAaCG', 'TAAbCG']],
#  ['TTAAAC', ['TTAAaC', 'TTAAbC']],
#  ['ATTAAA', ['ATTAAa', 'ATTAAb']],
#  ['TGATGG', ['aGATGG', 'bGATGG']],
#  ['GTGATG', ['GaGATG', 'GbGATG']],
#  ['AGTGAT', ['AGaGAT', 'AGbGAT']],
#  ['CAGTGA', ['CAGbGA', 'CAGaGA']],
#  ['ACAGTG', ['ACAGbG', 'ACAGaG']],
#  ['AACAGT', ['AACAGa', 'AACAGb']],
#  ['AGGAGC', ['bGGAGC', 'aGGAGC']],
#  ['AAGGAG', ['AbGGAG', 'AaGGAG']],
#  ['CAAGGA', ['CAbGGA', 'CAaGGA']],
#  ['ACAAGG', ['ACAaGG', 'ACAbGG']],
#  ['AACAAG', ['AACAbG', 'AACAaG']],
#  ['TAACAA', ['TAACAb', 'TAACAa']],
#  ['GGTCTG', ['bGTCTG', 'aGTCTG']],
#  ['TGGTCT', ['TaGTCT', 'TbGTCT']],
#  ['GTGGTC', ['GTaGTC', 'GTbGTC']],
#  ['CGTGGT', ['CGTbGT', 'CGTaGT']],
#  ['CCGTGG', ['CCGTaG', 'CCGTbG']],
#  ['ACCGTG', ['ACCGTb', 'ACCGTa']],
#  ['TGGCGC', ['bGGCGC', 'aGGCGC']],
#  ['ATGGCG', ['AaGGCG', 'AbGGCG']],
#  ['AATGGC', ['AAaGGC', 'AAbGGC']],
#  ['TAATGG', ['TAAbGG', 'TAAaGG']],
#  ['TTAATG', ['TTAAaG', 'TTAAbG']],
#  ['CTTAAT', ['CTTAAb', 'CTTAAa']],
#  ['ATTGAC', ['bTTGAC', 'aTTGAC']],
#  ['AATTGA', ['AaTTGA', 'AbTTGA']],
#  ['AAATTG', ['AAaTTG', 'AAbTTG']],
#  ['AAAATT', ['AAAbTT', 'AAAaTT']],
#  ['AAAAAT', ['AAAAbT', 'AAAAaT']],
#  ['GAAAAA', ['GAAAAa', 'GAAAAb']],
#  ['TGATGC', ['aGATGC', 'bGATGC']],
#  ['TTGATG', ['TbGATG', 'TaGATG']],
#  ['GTTGAT', ['GTbGAT', 'GTaGAT']],
#  ['AGTTGA', ['AGTbGA', 'AGTaGA']],
#  ['AAGTTG', ['AAGTbG', 'AAGTaG']],
#  ['CAAGTT', ['CAAGTb', 'CAAGTa']],
#  ['TTAAAA', ['bTAAAA', 'aTAAAA']],
#  ['ATTAAA', ['AbTAAA', 'AaTAAA']],
#  ['GATTAA', ['GAaTAA', 'GAbTAA']],
#  ['AGATTA', ['AGAaTA', 'AGAbTA']],
#  ['GAGATT', ['GAGAaT', 'GAGAbT']],
#  ['TGAGAT', ['TGAGAb', 'TGAGAa']],
#  ['TGTGAG', ['bGTGAG', 'aGTGAG']],
#  ['TTGTGA', ['TbGTGA', 'TaGTGA']],
#  ['CTTGTG', ['CTbGTG', 'CTaGTG']],
#  ['ACTTGT', ['ACTbGT', 'ACTaGT']],
#  ['AACTTG', ['AACTaG', 'AACTbG']],
#  ['AAACTT', ['AAACTa', 'AAACTb']],
#  ['ATTATA', ['bTTATA', 'aTTATA']],
#  ['GATTAT', ['GaTTAT', 'GbTTAT']],
#  ['CGATTA', ['CGaTTA', 'CGbTTA']],
#  ['ACGATT', ['ACGbTT', 'ACGaTT']],
#  ['TACGAT', ['TACGbT', 'TACGaT']],
#  ['GTACGA', ['GTACGb', 'GTACGa']],
#  ['AAGAAC', ['aAGAAC', 'bAGAAC']],
#  ['CAAGAA', ['CbAGAA', 'CaAGAA']],
#  ['GCAAGA', ['GCaAGA', 'GCbAGA']],
#  ['AGCAAG', ['AGCbAG', 'AGCaAG']],
#  ['AAGCAA', ['AAGCaA', 'AAGCbA']],
#  ['AAAGCA', ['AAAGCb', 'AAAGCa']],
#  ['TAGTAG', ['bAGTAG', 'aAGTAG']],
#  ['CTAGTA', ['CbAGTA', 'CaAGTA']],
#  ['ACTAGT', ['ACaAGT', 'ACbAGT']],
#  ['GACTAG', ['GACaAG', 'GACbAG']],
#  ['AGACTA', ['AGACbA', 'AGACaA']],
#  ['TAGACT', ['TAGACb', 'TAGACa']],
#  ['CCATAG', ['bCATAG', 'aCATAG']],
#  ['GCCATA', ['GaCATA', 'GbCATA']],
#  ['TGCCAT', ['TGbCAT', 'TGaCAT']],
#  ['CTGCCA', ['CTGaCA', 'CTGbCA']],
#  ['GCTGCC', ['GCTGaC', 'GCTGbC']],
#  ['TGCTGC', ['TGCTGa', 'TGCTGb']],
#  ['GAACGC', ['bAACGC', 'aAACGC']],
#  ['GGAACG', ['GaAACG', 'GbAACG']],
#  ['CGGAAC', ['CGbAAC', 'CGaAAC']],
#  ['TCGGAA', ['TCGaAA', 'TCGbAA']],
#  ['GTCGGA', ['GTCGbA', 'GTCGaA']],
#  ['AGTCGG', ['AGTCGa', 'AGTCGb']],
#  ['TCGGCG', ['aCGGCG', 'bCGGCG']],
#  ['TTCGGC', ['TbCGGC', 'TaCGGC']],
#  ['ATTCGG', ['ATbCGG', 'ATaCGG']],
#  ['AATTCG', ['AATaCG', 'AATbCG']],
#  ['TAATTC', ['TAATbC', 'TAATaC']],
#  ['TTAATT', ['TTAATa', 'TTAATb']],
#  ['TTTAAT', ['aTTAAT', 'bTTAAT']],
#  ['GTTTAA', ['GaTTAA', 'GbTTAA']],
#  ['AGTTTA', ['AGbTTA', 'AGaTTA']],
#  ['CAGTTT', ['CAGaTT', 'CAGbTT']],
#  ['TCAGTT', ['aCAGbT', 'bCAGbT', 'aCAGaT', 'bCAGaT']],
#  ['CTCAGT', ['CaCAGb', 'CbCAGa', 'CaCAGa', 'CbCAGb']],
#  ['TCAGTT', ['aCAGbT', 'bCAGbT', 'aCAGaT', 'bCAGaT']],
#  ['CTCAGT', ['CaCAGb', 'CbCAGa', 'CaCAGa', 'CbCAGb']],
#  ['ACTCAG', ['ACbCAG', 'ACaCAG']],
#  ['AACTCA', ['AACaCA', 'AACbCA']],
#  ['CAACTC', ['CAACaC', 'CAACbC']],
#  ['ACAACT', ['ACAACa', 'ACAACb']],
#  ['TGGTGG', ['bGGTGG', 'aGGTGG']],
#  ['GTGGTG', ['GbGGTG', 'GaGGTG']],
#  ['GGTGGT', ['aGbGGT', 'bGaGGT', 'bGbGGT', 'aGaGGT']],
#  ['TGGTGG', ['TbGaGG', 'TbGbGG', 'TaGbGG', 'TaGaGG']],
#  ['GTGGTG', ['GTbGbG', 'GTaGbG', 'GTbGaG', 'GTaGaG']],
#  ['CGTGGT', ['CGTbGb', 'CGTaGa', 'CGTaGb', 'CGTbGa']],
#  ['GGTGGT', ['aGbGGT', 'bGaGGT', 'bGbGGT', 'aGaGGT']],
#  ['TGGTGG', ['TbGaGG', 'TbGbGG', 'TaGbGG', 'TaGaGG']],
#  ['GTGGTG', ['GTbGbG', 'GTaGbG', 'GTbGaG', 'GTaGaG']],
#  ['CGTGGT', ['CGTbGb', 'CGTaGa', 'CGTaGb', 'CGTbGa']],
#  ['ACGTGG', ['ACGTaG', 'ACGTbG']],
#  ['TACGTG', ['TACGTa', 'TACGTb']],
#  ['CCGGTA', ['aCGGTA', 'bCGGTA']],
#  ['GCCGGT', ['GbCGGT', 'GaCGGT']],
#  ['TGCCGG', ['TGbCGG', 'TGaCGG']],
#  ['TTGCCG', ['TTGbCG', 'TTGaCG']],
#  ['CTTGCC', ['CTTGaC', 'CTTGbC']],
#  ['TCTTGC', ['TCTTGb', 'TCTTGa']],
#  ['TTGATT', ['bTGATT', 'aTGATT']],
#  ['GTTGAT', ['GaTGAT', 'GbTGAT']],
#  ['GGTTGA', ['GGaTGA', 'GGbTGA']],
#  ['TGGTTG', ['TGGbTG', 'TGGaTG']],
#  ['GTGGTT', ['GTGGbT', 'GTGGaT']],
#  ['GGTGGT', ['GGTGGb', 'GGTGGa']],
#  ['TTTGAA', ['aTTGAA', 'bTTGAA']],
#  ['GTTTGA', ['GbTTGA', 'GaTTGA']],
#  ['AGTTTG', ['AGbTTG', 'AGaTTG']],
#  ['GAGTTT', ['GAGaTT', 'GAGbTT']],
#  ['GGAGTT', ['GGAGbT', 'GGAGaT']],
#  ['CGGAGT', ['CGGAGb', 'CGGAGa']],
#  ['GACAAT', ['aACAAT', 'bACAAT']],
#  ['GGACAA', ['GaACAA', 'GbACAA']],
#  ['TGGACA', ['TGbACA', 'TGaACA']],
#  ['CTGGAC', ['CTGbAC', 'CTGaAC']],
#  ['TCTGGA', ['TCTGbA', 'TCTGaA']],
#  ['GTCTGG', ['GTCTGb', 'GTCTGa']],
#  ['GCAACT', ['bCAACT', 'aCAACT']],
#  ['AGCAAC', ['AbCAAC', 'AaCAAC']],
#  ['GAGCAA', ['cAbCAA', 'cAaCAA']],
#  ['GGAGCA', ['acAbCA', 'acAaCA', 'bcAaCA', 'bcAbCA']],
#  ['AGGAGC', ['cbcAaC', 'cbcAbC', 'cacAaC', 'cacAbC']],
#  ['AAGGAG', ['AcbcAb', 'AcacAb', 'AcbcAa', 'AcacAa']],
#  ['GGAGCA', ['acAbCA', 'acAaCA', 'bcAaCA', 'bcAbCA']],
#  ['AGGAGC', ['cbcAaC', 'cbcAbC', 'cacAaC', 'cacAbC']],
#  ['AAGGAG', ['AcbcAb', 'AcacAb', 'AcbcAa', 'AcacAa']],
#  ['TAAGGA', ['TAcbcA', 'TAcacA']],
#  ['TTAAGG', ['TTAcbc', 'TTAcac']],
#  ['CTTAAG', ['CTTAcb', 'CTTAca']],
#  ['CGCCAC', ['aGCCAC', 'bGCCAC']],
#  ['CCGCCA', ['CbGCCA', 'CaGCCA']],
#  ['CCCGCC', ['CCaGCC', 'CCbGCC']],
#  ['GCCCGC', ['GCCaGC', 'GCCbGC']],
#  ['TGCCCG', ['TGCCbG', 'TGCCaG']],
#  ['CTGCCC', ['CTGCCa', 'CTGCCb']],
#  ['CCTTTG', ['bCTTTG', 'aCTTTG']],
#  ['GCCTTT', ['GbCTTT', 'GaCTTT']],
#  ['TGCCTT', ['TGaCTT', 'TGbCTT']],
#  ['ATGCCT', ['ATGaCT', 'ATGbCT']],
#  ['GATGCC', ['GATGbC', 'GATGaC']],
#  ['GGATGC', ['GGATGa', 'GGATGb']],
#  ['AGTGGA', ['aGTGGA', 'bGTGGA']],
#  ['AAGTGG', ['abGTGG', 'bbGTGG', 'baGTGG', 'aaGTGG']],
#  ['CAAGTG', ['CaaGTG', 'CbaGTG', 'CabGTG', 'CbbGTG']],
#  ['CCAAGT', ['CCbbGT', 'CCaaGT', 'CCbaGT', 'CCabGT']],
#  ['TCCAAG', ['TCCabG', 'TCCbaG', 'TCCaaG', 'TCCbbG']],
#  ['GTCCAA', ['GTCCab', 'GTCCba', 'GTCCbb', 'GTCCaa']],
#  ['AAGTGG', ['abGTGG', 'bbGTGG', 'baGTGG', 'aaGTGG']],
#  ['CAAGTG', ['CaaGTG', 'CbaGTG', 'CabGTG', 'CbbGTG']],
#  ['CCAAGT', ['CCbbGT', 'CCaaGT', 'CCbaGT', 'CCabGT']],
#  ['TCCAAG', ['TCCabG', 'TCCbaG', 'TCCaaG', 'TCCbbG']],
#  ['GTCCAA', ['GTCCab', 'GTCCba', 'GTCCbb', 'GTCCaa']],
#  ['CGTCCA', ['CGTCCb', 'CGTCCa']],
#  ['AGTTCT', ['aGTTCT', 'bGTTCT']],
#  ['AAGTTC', ['AaGTTC', 'AbGTTC']],
#  ['AAAGTT', ['AAaGTT', 'AAbGTT']],
#  ['CAAAGT', ['CAAaGT', 'CAAbGT']],
#  ['ACAAAG', ['aCAAbG', 'bCAAaG', 'bCAAbG', 'aCAAaG']],
#  ['CACAAA',
#   ['bbCAAb',
#    'aaCAAa',
#    'baCAAa',
#    'abCAAb',
#    'baCAAb',
#    'aaCAAb',
#    'bbCAAa',
#    'abCAAa']],
#  ['ACAAAG', ['aCAAbG', 'bCAAaG', 'bCAAbG', 'aCAAaG']],
#  ['CACAAA',
#   ['bbCAAb',
#    'aaCAAa',
#    'baCAAa',
#    'abCAAb',
#    'baCAAb',
#    'aaCAAb',
#    'bbCAAa',
#    'abCAAa']],
#  ['GCACAA', ['GbbCAA', 'GbaCAA', 'GabCAA', 'GaaCAA']],
#  ['GGCACA', ['GGaaCA', 'GGbbCA', 'GGbaCA', 'GGabCA']],
#  ['AGGCAC', ['AGGbaC', 'AGGaaC', 'AGGabC', 'AGGbbC']],
#  ['CAGGCA', ['CAGGab', 'CAGGbb', 'CAGGaa', 'CAGGba']],
#  ['CACAAA',
#   ['bbCAAb',
#    'aaCAAa',
#    'baCAAa',
#    'abCAAb',
#    'baCAAb',
#    'aaCAAb',
#    'bbCAAa',
#    'abCAAa']],
#  ['GCACAA', ['GbbCAA', 'GbaCAA', 'GabCAA', 'GaaCAA']],
#  ['GGCACA', ['GGaaCA', 'GGbbCA', 'GGbaCA', 'GGabCA']],
#  ['AGGCAC', ['AGGbaC', 'AGGaaC', 'AGGabC', 'AGGbbC']],
#  ['CAGGCA', ['CAGGab', 'CAGGbb', 'CAGGaa', 'CAGGba']],
#  ['CCAGGC', ['CCAGGb', 'CCAGGa']],
#  ['CTGAGG', ['bTGAGG', 'aTGAGG']],
#  ['TCTGAG', ['TbTGAG', 'TaTGAG']],
#  ['ATCTGA', ['ATaTGA', 'ATbTGA']],
#  ['AATCTG', ['AATbTG', 'AATaTG']],
#  ['CAATCT', ['CAATbT', 'CAATaT']],
#  ['GCAATC', ['GCAATb', 'GCAATa']],
#  ['TAGGTA', ['bcGGTA', 'acGGTA']],
#  ['TTAGGT', ['TbcGGT', 'TacGGT']],
#  ['TTTAGG', ['TTacGG', 'TTbcGG']],
#  ['GTTTAG', ['GTTbcG', 'GTTacG']],
#  ['AGTTTA', ['AGTTac', 'AGTTbc']],
#  ['GAGTTT', ['GAGTTa', 'GAGTTb']],
#  ['GCCCAG', ['aCCCAG', 'bCCCAG']],
#  ['AGCCCA', ['AbCCCA', 'AaCCCA']],
#  ['AAGCCC', ['bAaCCC', 'bAbCCC', 'aAaCCC', 'aAbCCC']],
#  ['AAAGCC', ['AbAaCC', 'AaAbCC', 'AbAbCC', 'AaAaCC']],
#  ['GAAAGC', ['GAbAaC', 'GAaAaC', 'GAbAbC', 'GAaAbC']],
#  ['AGAAAG', ['AGAaAa', 'AGAbAa', 'AGAbAb', 'AGAaAb']],
#  ['AAGCCC', ['bAaCCC', 'bAbCCC', 'aAaCCC', 'aAbCCC']],
#  ['AAAGCC', ['AbAaCC', 'AaAbCC', 'AbAbCC', 'AaAaCC']],
#  ['GAAAGC', ['GAbAaC', 'GAaAaC', 'GAbAbC', 'GAaAbC']],
#  ['AGAAAG', ['AGAaAa', 'AGAbAa', 'AGAbAb', 'AGAaAb']],
#  ['TAGAAA', ['TAGAbA', 'TAGAaA']],
#  ['GTAGAA', ['GTAGAa', 'GTAGAb']],
#  ['AAGTGG', ['bAGTGG', 'aAGTGG']],
#  ['CAAGTG', ['CaAGTG', 'CbAGTG']],
#  ['TCAAGT', ['TCbAGT', 'TCaAGT']],
#  ['ATCAAG', ['ATCbAG', 'ATCaAG']],
#  ['TATCAA', ['TATCaA', 'TATCbA']],
#  ['GTATCA', ['GTATCb', 'GTATCa']],
#  ['GATGCT', ['bATGCT', 'aATGCT']],
#  ['CGATGC', ['CbATGC', 'CaATGC']],
#  ['GCGATG', ['GCbATG', 'GCaATG']],
#  ['GGCGAT', ['GGCaAT', 'GGCbAT']],
#  ['TGGCGA', ['TGGCaA', 'TGGCbA']],
#  ['TTGGCG', ['TTGGCa', 'TTGGCb']],
#  ['AGTCTT', ['aGTCTT', 'bGTCTT']],
#  ['CAGTCT', ['CaGTCT', 'CbGTCT']],
#  ['GCAGTC', ['GCaGTC', 'GCbGTC']],
#  ['TGCAGT', ['TGCbGT', 'TGCaGT']],
#  ['GTGCAG', ['GTGCbG', 'GTGCaG']],
#  ['CGTGCA', ['CGTGCa', 'CGTGCb']],
#  ['TTAAGC', ['aTAAGC', 'bTAAGC']],
#  ['TTTAAG', ['TbTAAG', 'TaTAAG']],
#  ['GTTTAA', ['GTaTAA', 'GTbTAA']],
#  ['GGTTTA', ['GGTaTA', 'GGTbTA']],
#  ['GGGTTT', ['GGGTaT', 'GGGTbT']],
#  ['TGGGTT', ['TGGGTb', 'TGGGTa']],
#  ['GGATAT', ['bGATAT', 'aGATAT']],
#  ['GGGATA', ['GbGATA', 'GaGATA']],
#  ['GGGGAT', ['GGaGAT', 'GGbGAT']],
#  ['CGGGGA', ['CGGaGA', 'CGGbGA']],
#  ['GCGGGG', ['GCGGaG', 'GCGGbG']],
#  ['AGCGGG', ['AGCGGa', 'AGCGGb']],
#  ['TCCCTT', ['bCCCTT', 'aCCCTT']],
#  ['CTCCCT', ['CaCCCT', 'CbCCCT']],
#  ['ACTCCC', ['ACaCCC', 'ACbCCC']],
#  ['GACTCC', ['GACaCC', 'GACbCC']],
#  ['GGACTC', ['GGACbC', 'GGACaC']],
#  ['AGGACT', ['AGGACa', 'AGGACb']],
#  ['TAGGAC', ['aAGGAC', 'bAGGAC']],
#  ['ATAGGA', ['AbAGGA', 'AaAGGA']],
#  ['GATAGG', ['GAaAGG', 'GAbAGG']],
#  ['CGATAG', ['CGAaAG', 'CGAbAG']],
#  ['ACGATA', ['ACGAbA', 'ACGAaA']],
#  ['GACGAT', ['GACGAb', 'GACGAa']],
#  ['TTGACT', ['bTGACT', 'aTGACT']],
#  ['TTTGAC', ['TaTGAC', 'TbTGAC']],
#  ['TTTTGA', ['TTbTGA', 'TTaTGA']],
#  ['ATTTTG', ['ATTbTG', 'ATTaTG']],
#  ['TATTTT', ['aATTaT', 'bATTbT', 'aATTbT', 'bATTaT']],
#  ['GTATTT', ['GbATTa', 'GbATTb', 'GaATTa', 'GaATTb']],
#  ['TATTTT', ['aATTaT', 'bATTbT', 'aATTbT', 'bATTaT']],
#  ['GTATTT', ['GbATTa', 'GbATTb', 'GaATTa', 'GaATTb']],
#  ['AGTATT', ['AGbATT', 'AGaATT']],
#  ['GAGTAT', ['GAGaAT', 'GAGbAT']],
#  ['GGAGTA', ['GGAGaA', 'GGAGbA']],
#  ['TGGAGT', ['TGGAGa', 'TGGAGb']],
#  ['TAAGCG', ['bAAGCG', 'aAAGCG']],
#  ['GTAAGC', ['GbAAGC', 'GaAAGC']],
#  ['AGTAAG', ['AGaAAG', 'AGbAAG']],
#  ['TAGTAA', ['TAGaAA', 'TAGbAA']],
#  ['TTAGTA', ['TTAGbA', 'TTAGaA']],
#  ['ATTAGT', ['ATTAGb', 'ATTAGa']],
#  ['TTATCC', ['bTATCC', 'aTATCC']],
#  ['CTTATC', ['CbTATC', 'CaTATC']],
#  ['TCTTAT', ['TCaTAT', 'TCbTAT']],
#  ['CTCTTA', ['CTCbTA', 'CTCaTA']],
#  ['ACTCTT', ['ACTCaT', 'ACTCbT']],
#  ['AACTCT', ['AACTCa', 'AACTCb']],
#  ['TTTCAA', ['aTcCAA', 'bTcCAA']],
#  ['ATTTCA', ['AaTcCA', 'AbTcCA']],
#  ['AATTTC', ['AAaTcC', 'AAbTcC']],
#  ['AAATTT', ['AAAaTc', 'AAAbTc']],
#  ['TAAATT', ['bAAAbT', 'aAAAaT', 'aAAAbT', 'bAAAaT']],
#  ['ATAAAT', ['AaAAAa', 'AbAAAa', 'AbAAAb', 'AaAAAb']],
#  ['TAAATT', ['bAAAbT', 'aAAAaT', 'aAAAbT', 'bAAAaT']],
#  ['ATAAAT', ['AaAAAa', 'AbAAAa', 'AbAAAb', 'AaAAAb']],
#  ['TATAAA', ['TAaAAA', 'TAbAAA']],
#  ['GTATAA', ['GTAbAA', 'GTAaAA']],
#  ['TGTATA', ['TGTAbA', 'TGTAaA']],
#  ['ATGTAT', ['ATGTAb', 'ATGTAa']],
#  ['TTTCGA', ['aTTCGA', 'bTTCGA']],
#  ['TTTTCG', ['TbTTCG', 'TaTTCG']],
#  ['ATTTTC', ['ATaTTC', 'ATbTTC']],
#  ['GATTTT', ['GATaTT', 'GATbTT']],
#  ['TGATTT', ['TGATaT', 'TGATbT']],
#  ['GTGATT', ['GTGATb', 'GTGATa']],
#  ['TTTTAC', ['aTTTAC', 'bTTTAC']],
#  ['TTTTTA', ['TaTTTA', 'TbTTTA']],
#  ['GTTTTT', ['GTaTTT', 'GTbTTT']],
#  ['GGTTTT', ['GGTaTT', 'GGTbTT']],
#  ['TGGTTT', ['TGGTbT', 'TGGTaT']],
#  ['ATGGTT', ['ATGGTb', 'ATGGTa']],
#  ['ACGAAT', ['aCGAAT', 'bCGAAT']],
#  ['GACGAA', ['GbCGAA', 'GaCGAA']],
#  ['AGACGA', ['AGbCGA', 'AGaCGA']],
#  ['AAGACG', ['AAGaCG', 'AAGbCG']],
#  ['CAAGAC', ['CAAGbC', 'CAAGaC']],
#  ['TCAAGA', ['TCAAGb', 'TCAAGa']],
#  ['CTAGAC', ['bTAGAC', 'aTAGAC']],
#  ['TCTAGA', ['TbTAGA', 'TaTAGA']],
#  ['TTCTAG', ['TTbTAG', 'TTaTAG']],
#  ['GTTCTA', ['GTTaTA', 'GTTbTA']],
#  ['GGTTCT', ['GGTTbT', 'GGTTaT']],
#  ['TGGTTC', ['TGGTTa', 'TGGTTb']],
#  ['ATGATG', ['aTGATG', 'bTGATG']],
#  ['GATGAT', ['baTGAT', 'abTGAT', 'aaTGAT', 'bbTGAT']],
#  ['CGATGA', ['CbbTGA', 'CabTGA', 'CbaTGA', 'CaaTGA']],
#  ['ACGATG', ['ACbaTG', 'ACbbTG', 'ACaaTG', 'ACabTG']],
#  ['AACGAT', ['AACabT', 'AACbbT', 'AACaaT', 'AACbaT']],
#  ['AAACGA', ['AAACab', 'AAACba', 'AAACaa', 'AAACbb']],
#  ['GATGAT', ['baTGAT', 'abTGAT', 'aaTGAT', 'bbTGAT']],
#  ['CGATGA', ['CbbTGA', 'CabTGA', 'CbaTGA', 'CaaTGA']],
#  ['ACGATG', ['ACbaTG', 'ACbbTG', 'ACaaTG', 'ACabTG']],
#  ['AACGAT', ['AACabT', 'AACbbT', 'AACaaT', 'AACbaT']],
#  ['AAACGA', ['AAACab', 'AAACba', 'AAACaa', 'AAACbb']],
#  ['TAAACG', ['TAAACb', 'TAAACa']],
#  ['TAATAA', ['bAATAA', 'aAATAA']],
#  ['GTAATA', ['GaAATA', 'GbAATA']],
#  ['TGTAAT', ['TGbAAT', 'TGaAAT']],
#  ['ATGTAA', ['ATGbAA', 'ATGaAA']],
#  ['GATGTA', ['GATGaA', 'GATGbA']],
#  ['AGATGT', ['AGATGb', 'AGATGa']],
#  ['TCTAAG', ['aCTAAG', 'bCTAAG']],
#  ['GTCTAA', ['GbCTAA', 'GaCTAA']],
#  ['AGTCTA', ['cGbCTA', 'cGaCTA']],
#  ['CAGTCT', ['CcGaCT', 'CcGbCT']],
#  ['TCAGTC', ['bCcGbC', 'bCcGaC', 'aCcGaC', 'aCcGbC']],
#  ['GTCAGT', ['GaCcGb', 'GaCcGa', 'GbCcGa', 'GbCcGb']],
#  ['TCAGTC', ['bCcGbC', 'bCcGaC', 'aCcGaC', 'aCcGbC']],
#  ['GTCAGT', ['GaCcGb', 'GaCcGa', 'GbCcGa', 'GbCcGb']],
#  ['TGTCAG', ['TGbCcG', 'TGaCcG']],
#  ['CTGTCA', ['CTGbCc', 'CTGaCc']],
#  ['TCTGTC', ['cCTGaC', 'cCTGbC']],
#  ['ATCTGT', ['AcCTGa', 'AcCTGb']],
#  ['ATTAAT', ['accAAc', 'bccAAc']],
#  ['AATTAA', ['AaccAA', 'AbccAA']],
#  ['AAATTA', ['AAaccA', 'AAbccA']],
#  ['AAAATT', ['AAAbcc', 'AAAacc']],
#  ['CAAAAT', ['CAAAbc', 'CAAAac']],
#  ['ACAAAA', ['ACAAAb', 'ACAAAa']],
#  ['TTTAGT', ['aTTAGT', 'bTTAGT']],
#  ['CTTTAG', ['CbTTAG', 'CaTTAG']],
#  ['TCTTTA', ['TCaTTA', 'TCbTTA']],
#  ['GTCTTT', ['GTCbTT', 'GTCaTT']],
#  ['CGTCTT', ['CGTCaT', 'CGTCbT']],
#  ['CCGTCT', ['CCGTCa', 'CCGTCb']],
#  ['CCCGTC', ['bCCGTC', 'aCCGTC']],
#  ['ACCCGT', ['AbCCGT', 'AaCCGT']],
#  ['GACCCG', ['GAaCCG', 'GAbCCG']],
#  ['TGACCC', ['TGAaCC', 'TGAbCC']],
#  ['GTGACC', ['GTGAbC', 'GTGAaC']],
#  ['CGTGAC', ['CGTGAa', 'CGTGAb']],
#  ['AAGTGA', ['bAGTGA', 'aAGTGA']],
#  ['GAAGTG', ['GbAGTG', 'GaAGTG']],
#  ['AGAAGT', ['AGaAGT', 'AGbAGT']],
#  ['AAGAAG', ['AAGbAG', 'AAGaAG']],
#  ['AAAGAA', ['AAAGbA', 'AAAGaA']],
#  ['TAAAGA', ['TAAAGa', 'TAAAGb']],
#  ['AATGAG', ['aATGAG', 'bATGAG']],
#  ['CAATGA', ['CaATGA', 'CbATGA']],
#  ['TCAATG', ['aCaATG', 'aCbATG', 'bCaATG', 'bCbATG']],
#  ['ATCAAT', ['AbCaAT', 'AaCbAT', 'AaCaAT', 'AbCbAT']],
#  ['TATCAA',
#   ['aAaCbA',
#    'bAaCbA',
#    'bAbCaA',
#    'aAbCbA',
#    'aAbCaA',
#    'aAaCaA',
#    'bAaCaA',
#    'bAbCbA']],
#  ['GTATCA',
#   ['cbAbCb',
#    'caAbCa',
#    'cbAbCa',
#    'caAaCb',
#    'cbAaCa',
#    'caAbCb',
#    'caAaCa',
#    'cbAaCb']],
#  ['TCAATG', ['aCaATG', 'aCbATG', 'bCaATG', 'bCbATG']],
#  ['ATCAAT', ['AbCaAT', 'AaCbAT', 'AaCaAT', 'AbCbAT']],
#  ['TATCAA',
#   ['aAaCbA',
#    'bAaCbA',
#    'bAbCaA',
#    'aAbCbA',
#    'aAbCaA',
#    'aAaCaA',
#    'bAaCaA',
#    'bAbCbA']],
#  ['GTATCA',
#   ['cbAbCb',
#    'caAbCa',
#    'cbAbCa',
#    'caAaCb',
#    'cbAaCa',
#    'caAbCb',
#    'caAaCa',
#    'cbAaCb']],
#  ['AGTATC', ['AcbAbC', 'AcaAaC', 'AcaAbC', 'AcbAaC']],
#  ['CAGTAT', ['CAcaAa', 'CAcaAb', 'CAcbAb', 'CAcbAa']],
#  ['TATCAA',
#   ['aAaCbA',
#    'bAaCbA',
#    'bAbCaA',
#    'aAbCbA',
#    'aAbCaA',
#    'aAaCaA',
#    'bAaCaA',
#    'bAbCbA']],
#  ['GTATCA',
#   ['cbAbCb',
#    'caAbCa',
#    'cbAbCa',
#    'caAaCb',
#    'cbAaCa',
#    'caAbCb',
#    'caAaCa',
#    'cbAaCb']],
#  ['AGTATC', ['AcbAbC', 'AcaAaC', 'AcaAbC', 'AcbAaC']],
#  ['CAGTAT', ['CAcaAa', 'CAcaAb', 'CAcbAb', 'CAcbAa']],
#  ['TCAGTA', ['bCAcbA', 'bCAcaA', 'aCAcaA', 'aCAcbA']],
#  ['CTCAGT', ['CbCAca', 'CaCAcb', 'CbCAcb', 'CaCAca']],
#  ['TCAGTA', ['bCAcbA', 'bCAcaA', 'aCAcaA', 'aCAcbA']],
#  ['CTCAGT', ['CbCAca', 'CaCAcb', 'CbCAcb', 'CaCAca']],
#  ['TCTCAG', ['aCaCAc', 'bCbCAc', 'bCaCAc', 'aCbCAc']],
#  ['CTCTCA', ['CaCaCA', 'CbCaCA', 'CbCbCA', 'CaCbCA']],
#  ['TCTCTC', ['TCaCaC', 'TCbCaC', 'TCbCbC', 'TCaCbC']],
#  ['TTCTCT', ['TTCbCa', 'TTCbCb', 'TTCaCb', 'TTCaCa']],
#  ['TCTCAG', ['aCaCAc', 'bCbCAc', 'bCaCAc', 'aCbCAc']],
#  ['CTCTCA', ['CaCaCA', 'CbCaCA', 'CbCbCA', 'CaCbCA']],
#  ['TCTCTC', ['TCaCaC', 'TCbCaC', 'TCbCbC', 'TCaCbC']],
#  ['TTCTCT', ['TTCbCa', 'TTCbCb', 'TTCaCb', 'TTCaCa']],
#  ['ATTCTC', ['ATTCbC', 'ATTCaC']],
#  ['AATTCT', ['AATTCa', 'AATTCb']],
#  ['CCGATG', ['aCGATG', 'bCGATG']],
#  ['ACCGAT', ['AaCGAT', 'AbCGAT']],
#  ['AACCGA', ['bAaCGA', 'aAaCGA', 'aAbCGA', 'bAbCGA']],
#  ['AAACCG',
#   ['abAbCG',
#    'baAaCG',
#    'baAbCG',
#    'bbAaCG',
#    'abAaCG',
#    'aaAaCG',
#    'aaAbCG',
#    'bbAbCG']],
#  ['TAAACC',
#   ['TaaAaC',
#    'TaaAbC',
#    'TabAbC',
#    'TbbAaC',
#    'TbaAaC',
#    'TbbAbC',
#    'TbaAbC',
#    'TabAaC']],
#  ['GTAAAC',
#   ['GTaaAb',
#    'GTbbAa',
#    'GTbaAb',
#    'GTbbAb',
#    'GTabAa',
#    'GTbaAa',
#    'GTaaAa',
#    'GTabAb']],
#  ['AACCGA', ['bAaCGA', 'aAaCGA', 'aAbCGA', 'bAbCGA']],
#  ['AAACCG',
#   ['abAbCG',
#    'baAaCG',
#    'baAbCG',
#    'bbAaCG',
#    'abAaCG',
#    'aaAaCG',
#    'aaAbCG',
#    'bbAbCG']],
#  ['TAAACC',
#   ['TaaAaC',
#    'TaaAbC',
#    'TabAbC',
#    'TbbAaC',
#    'TbaAaC',
#    'TbbAbC',
#    'TbaAbC',
#    'TabAaC']],
#  ['GTAAAC',
#   ['GTaaAb',
#    'GTbbAa',
#    'GTbaAb',
#    'GTbbAb',
#    'GTabAa',
#    'GTbaAa',
#    'GTaaAa',
#    'GTabAb']],
#  ['CGTAAA', ['CGTbbA', 'CGTabA', 'CGTbaA', 'CGTaaA']],
#  ['CCGTAA', ['CCGTbb', 'CCGTab', 'CCGTaa', 'CCGTba']],
#  ['AAACCG',
#   ['abAbCG',
#    'baAaCG',
#    'baAbCG',
#    'bbAaCG',
#    'abAaCG',
#    'aaAaCG',
#    'aaAbCG',
#    'bbAbCG']],
#  ['TAAACC',
#   ['TaaAaC',
#    'TaaAbC',
#    'TabAbC',
#    'TbbAaC',
#    'TbaAaC',
#    'TbbAbC',
#    'TbaAbC',
#    'TabAaC']],
#  ['GTAAAC',
#   ['GTaaAb',
#    'GTbbAa',
#    'GTbaAb',
#    'GTbbAb',
#    'GTabAa',
#    'GTbaAa',
#    'GTaaAa',
#    'GTabAb']],
#  ['CGTAAA', ['CGTbbA', 'CGTabA', 'CGTbaA', 'CGTaaA']],
#  ['CCGTAA', ['CCGTbb', 'CCGTab', 'CCGTaa', 'CCGTba']],
#  ['TCCGTA', ['TCCGTb', 'TCCGTa']],
#  ['GCTCCG', ['bCTCCG', 'aCTCCG']],
#  ['TGCTCC', ['TbCTCC', 'TaCTCC']],
#  ['CTGCTC', ['CTbCTC', 'CTaCTC']],
#  ['ACTGCT', ['ACTbCT', 'ACTaCT']],
#  ['TACTGC', ['TACTbC', 'TACTaC']],
#  ['CTACTG', ['CTACTb', 'CTACTa']],
#  ['TAAGTA', ['aAAGTA', 'bAAGTA']],
#  ['GTAAGT', ['GbAAGT', 'GaAAGT']],
#  ['GGTAAG', ['GGaAAG', 'GGbAAG']],
#  ['AGGTAA', ['AGGbAA', 'AGGaAA']],
#  ['TAGGTA', ['TAGGbA', 'TAGGaA']],
#  ['TTAGGT', ['TTAGGb', 'TTAGGa']],
#  ['CTGTCA', ['bTGTCA', 'aTGTCA']],
#  ['CCTGTC', ['CaTGTC', 'CbTGTC']],
#  ['CCCTGT', ['CCbTGT', 'CCaTGT']],
#  ['TCCCTG', ['aCCaTG', 'aCCbTG', 'bCCaTG', 'bCCbTG']],
#  ['ATCCCT', ['AbCCbT', 'AaCCbT', 'AaCCaT', 'AbCCaT']],
#  ['TATCCC', ['TAaCCb', 'TAaCCa', 'TAbCCb', 'TAbCCa']],
#  ['TCCCTG', ['aCCaTG', 'aCCbTG', 'bCCaTG', 'bCCbTG']],
#  ['ATCCCT', ['AbCCbT', 'AaCCbT', 'AaCCaT', 'AbCCaT']],
#  ['TATCCC', ['TAaCCb', 'TAaCCa', 'TAbCCb', 'TAbCCa']],
#  ['CTATCC', ['CTAbCC', 'CTAaCC']],
#  ['TCTATC', ['TCTAbC', 'TCTAaC']],
#  ['ATCTAT', ['ATCTAb', 'ATCTAa']],
#  ['TCATCT', ['aCATCT', 'bCATCT']],
#  ['ATCATC', ['AaCATC', 'AbCATC']],
#  ['TATCAT', ['aAaCAT', 'bAaCAT', 'bAbCAT', 'aAbCAT']],
#  ['CTATCA', ['CaAbCA', 'CbAbCA', 'CbAaCA', 'CaAaCA']],
#  ['TCTATC',
#   ['aCbAaC',
#    'bCaAbC',
#    'bCaAaC',
#    'bCbAbC',
#    'aCaAbC',
#    'aCaAaC',
#    'bCbAaC',
#    'aCbAbC']],
#  ['ATCTAT',
#   ['AaCaAb',
#    'AaCaAa',
#    'AaCbAb',
#    'AbCbAb',
#    'AaCbAa',
#    'AbCaAa',
#    'AbCaAb',
#    'AbCbAa']],
#  ['TATCAT', ['aAaCAT', 'bAaCAT', 'bAbCAT', 'aAbCAT']],
#  ['CTATCA', ['CaAbCA', 'CbAbCA', 'CbAaCA', 'CaAaCA']],
#  ['TCTATC',
#   ['aCbAaC',
#    'bCaAbC',
#    'bCaAaC',
#    'bCbAbC',
#    'aCaAbC',
#    'aCaAaC',
#    'bCbAaC',
#    'aCbAbC']],
#  ['ATCTAT',
#   ['AaCaAb',
#    'AaCaAa',
#    'AaCbAb',
#    'AbCbAb',
#    'AaCbAa',
#    'AbCaAa',
#    'AbCaAb',
#    'AbCbAa']],
#  ['GATCTA', ['GAaCaA', 'GAbCaA', 'GAaCbA', 'GAbCbA']],
#  ['CGATCT', ['CGAbCb', 'CGAaCa', 'CGAaCb', 'CGAbCa']],
#  ['TCTATC',
#   ['aCbAaC',
#    'bCaAbC',
#    'bCaAaC',
#    'bCbAbC',
#    'aCaAbC',
#    'aCaAaC',
#    'bCbAaC',
#    'aCbAbC']],
#  ['ATCTAT',
#   ['AaCaAb',
#    'AaCaAa',
#    'AaCbAb',
#    'AbCbAb',
#    'AaCbAa',
#    'AbCaAa',
#    'AbCaAb',
#    'AbCbAa']],
#  ['GATCTA', ['GAaCaA', 'GAbCaA', 'GAaCbA', 'GAbCbA']],
#  ['CGATCT', ['CGAbCb', 'CGAaCa', 'CGAaCb', 'CGAbCa']],
#  ['GCGATC', ['GCGAbC', 'GCGAaC']],
#  ['AGCGAT', ['AGCGAa', 'AGCGAb']],
#  ['TCGAGT', ['aCGAGT', 'bCGAGT']],
#  ['TTCGAG', ['baCGAG', 'bbCGAG', 'abCGAG', 'aaCGAG']],
#  ['GTTCGA', ['cbbCGA', 'caaCGA', 'cabCGA', 'cbaCGA']],
#  ['AGTTCG', ['ccbaCG', 'ccbbCG', 'ccaaCG', 'ccabCG']],
#  ['CAGTTC', ['CccabC', 'CccbaC', 'CccaaC', 'CccbbC']],
#  ['TCAGTT',
#   ['aCccaa',
#    'aCccbb',
#    'bCccaa',
#    'bCccbb',
#    'bCccab',
#    'aCccab',
#    'aCccba',
#    'bCccba']],
#  ['TTCGAG', ['baCGAG', 'bbCGAG', 'abCGAG', 'aaCGAG']],
#  ['GTTCGA', ['cbbCGA', 'caaCGA', 'cabCGA', 'cbaCGA']],
#  ['AGTTCG', ['ccbaCG', 'ccbbCG', 'ccaaCG', 'ccabCG']],
#  ['CAGTTC', ['CccabC', 'CccbaC', 'CccaaC', 'CccbbC']],
#  ['TCAGTT',
#   ['aCccaa',
#    'aCccbb',
#    'bCccaa',
#    'bCccbb',
#    'bCccab',
#    'aCccab',
#    'aCccba',
#    'bCccba']],
#  ['CTCAGT', ['CbCccb', 'CaCccb', 'CbCcca', 'CaCcca']],
#  ['TCAGTT',
#   ['aCccaa',
#    'aCccbb',
#    'bCccaa',
#    'bCccbb',
#    'bCccab',
#    'aCccab',
#    'aCccba',
#    'bCccba']],
#  ['CTCAGT', ['CbCccb', 'CaCccb', 'CbCcca', 'CaCcca']],
#  ['TCTCAG', ['TCbCcc', 'TCaCcc']],
#  ['ATCTCA', ['ATCaCc', 'ATCbCc']],
#  ['GATCTC', ['GATCaC', 'GATCbC']],
#  ['TGATCT', ['TGATCa', 'TGATCb']],
#  ['GGTCGG', ['acTCGG', 'bcTCGG']],
#  ['GGGTCG', ['GacTCG', 'GbcTCG']],
#  ['GGGGTC', ['GGbcTC', 'GGacTC']],
#  ['CGGGGT', ['CGGacT', 'CGGbcT']],
#  ['GCGGGG', ['GCGGbc', 'GCGGac']],
#  ['GGCGGG', ['GGCGGb', 'GGCGGa']],
#  ['TTGTCT', ['bcGTCT', 'acGTCT']],
#  ['ATTGTC', ['cbcGTC', 'cacGTC']],
#  ['AATTGT', ['AcacGT', 'AcbcGT']],
#  ['AAATTG', ['AAcbcG', 'AAcacG']],
#  ['CAAATT', ['CAAcac', 'CAAcbc']],
#  ['GCAAAT', ['GCAAca', 'GCAAcb']],
#  ['AGCAAA', ['aGCAAc', 'bGCAAc']],
#  ['TAGCAA', ['TbGCAA', 'TaGCAA']],
#  ['ATAGCA', ['cTaGCA', 'cTbGCA']],
#  ['AATAGC', ['AcTaGC', 'AcTbGC']],
#  ['CAATAG', ['CAcTaG', 'CAcTbG']],
#  ['GCAATA', ['GCAcTb', 'GCAcTa']],
#  ['TTTAGT', ['bTTAcT', 'aTTAcT']],
#  ['TTTTAG', ['TbTTAc', 'TaTTAc']],
#  ['CTTTTA', ['CTaTTA', 'CTbTTA']],
#  ['ACTTTT', ['ACTaTT', 'ACTbTT']],
#  ['GACTTT', ['GACTaT', 'GACTbT']],
#  ['TGACTT', ['aGACTa', 'bGACTb', 'bGACTa', 'aGACTb']],
#  ['TGACTT', ['aGACTa', 'bGACTb', 'bGACTa', 'aGACTb']],
#  ['GTGACT', ['GbGACT', 'GaGACT']],
#  ['TGTGAC', ['TGbGAC', 'TGaGAC']],
#  ['GTGTGA', ['GTGaGA', 'GTGbGA']],
#  ['AGTGTG', ['AGTGaG', 'AGTGbG']],
#  ['AAGTGT', ['AAGTGb', 'AAGTGa']],
#  ['TAAGTG', ['aAAGTG', 'bAAGTG']],
#  ['ATAAGT', ['AaAAGT', 'AbAAGT']],
#  ['CATAAG', ['CAaAAG', 'CAbAAG']],
#  ['ACATAA', ['ACAaAA', 'ACAbAA']],
#  ['AACATA', ['AACAbA', 'AACAaA']],
#  ['AAACAT', ['AAACAa', 'AAACAb']],
#  ['GATCGG', ['bATCGG', 'aATCGG']],
#  ['AGATCG', ['AaATCG', 'AbATCG']],
#  ['GAGATC', ['aAbATC', 'bAbATC', 'bAaATC', 'aAaATC']],
#  ['GGAGAT', ['GaAaAT', 'GbAaAT', 'GaAbAT', 'GbAbAT']],
#  ['TGGAGA', ['TGbAbA', 'TGbAaA', 'TGaAbA', 'TGaAaA']],
#  ['GTGGAG', ['GTGaAa', 'GTGbAa', 'GTGaAb', 'GTGbAb']],
#  ['GAGATC', ['aAbATC', 'bAbATC', 'bAaATC', 'aAaATC']],
#  ['GGAGAT', ['GaAaAT', 'GbAaAT', 'GaAbAT', 'GbAbAT']],
#  ['TGGAGA', ['TGbAbA', 'TGbAaA', 'TGaAbA', 'TGaAaA']],
#  ['GTGGAG', ['GTGaAa', 'GTGbAa', 'GTGaAb', 'GTGbAb']],
#  ['CGTGGA', ['CGTGaA', 'CGTGbA']],
#  ['CCGTGG', ['CCGTGa', 'CCGTGb']],
#  ['GGACAC', ['aGACAC', 'bGACAC']],
#  ['GGGACA', ['GaGACA', 'GbGACA']],
#  ['AGGGAC', ['AGbGAC', 'AGaGAC']],
#  ['TAGGGA', ['TAGaGA', 'TAGbGA']],
#  ['ATAGGG', ['ATAGaG', 'ATAGbG']],
#  ['AATAGG', ['AATAGa', 'AATAGb']],
#  ['TCGGTC', ['bCGGTC', 'aCGGTC']],
#  ['TTCGGT', ['TaCGGT', 'TbCGGT']],
#  ['GTTCGG', ['GTbCGG', 'GTaCGG']],
#  ['TGTTCG', ['TGTaCG', 'TGTbCG']],
#  ['GTGTTC', ['GTGTbC', 'GTGTaC']],
#  ['GGTGTT', ['GGTGTb', 'GGTGTa']],
#  ['TTGCGA', ['bTGCGA', 'aTGCGA']],
#  ['CTTGCG', ['CaTGCG', 'CbTGCG']],
#  ['ACTTGC', ['ACbTGC', 'ACaTGC']],
#  ['TACTTG', ['TACbTG', 'TACaTG']],
#  ['ATACTT', ['ATACbT', 'ATACaT']],
#  ['GATACT', ['GATACb', 'GATACa']],
#  ['TAGTTT', ['bAGTTT', 'aAGTTT']],
#  ['TTAGTT', ['TbAGTT', 'TaAGTT']],
#  ['CTTAGT', ['CTaAGT', 'CTbAGT']],
#  ['TCTTAG', ['TCTbAG', 'TCTaAG']],
#  ['TTCTTA', ['TTCTaA', 'TTCTbA']],
#  ['CTTCTT', ['bTTCTa', 'bTTCTb', 'aTTCTa', 'aTTCTb']],
#  ['CTTCTT', ['bTTCTa', 'bTTCTb', 'aTTCTa', 'aTTCTb']],
#  ['GCTTCT', ['GbTTCT', 'GaTTCT']],
#  ['AGCTTC', ['AGbTTC', 'AGaTTC']],
#  ['TAGCTT', ['TAGbTT', 'TAGaTT']],
#  ['GTAGCT', ['GTAGaT', 'GTAGbT']],
#  ['TGTAGC', ['TGTAGb', 'TGTAGa']],
#  ['TCGGCT', ['aCGGCT', 'bCGGCT']],
#  ['CTCGGC', ['CbCGGC', 'CaCGGC']],
#  ['TCTCGG', ['TCbCGG', 'TCaCGG']],
#  ['TTCTCG', ['TTCaCG', 'TTCbCG']],
#  ['CTTCTC', ['CTTCbC', 'CTTCaC']],
#  ['CCTTCT', ['CCTTCb', 'CCTTCa']],
#  ['TTAGGT', ['aTAGGT', 'bTAGGT']],
#  ['GTTAGG', ['bbTAGG', 'aaTAGG', 'baTAGG', 'abTAGG']],
#  ['TGTTAG',
#   ['bbbTAG',
#    'abaTAG',
#    'aabTAG',
#    'abbTAG',
#    'aaaTAG',
#    'babTAG',
#    'baaTAG',
#    'bbaTAG']],
#  ['TTGTTA',
#   ['TbbbTA',
#    'TabaTA',
#    'TaaaTA',
#    'TbabTA',
#    'TaabTA',
#    'TbaaTA',
#    'TbbaTA',
#    'TabbTA']],
#  ['CTTGTT',
#   ['CTabaT',
#    'CTbbaT',
#    'CTaaaT',
#    'CTbaaT',
#    'CTbbbT',
#    'CTbabT',
#    'CTaabT',
#    'CTabbT']],
#  ['ACTTGT',
#   ['ACTabb',
#    'ACTbaa',
#    'ACTbbb',
#    'ACTaba',
#    'ACTaab',
#    'ACTbab',
#    'ACTbba',
#    'ACTaaa']],
#  ['GTTAGG', ['bbTAGG', 'aaTAGG', 'baTAGG', 'abTAGG']],
#  ['TGTTAG',
#   ['bbbTAG',
#    'abaTAG',
#    'aabTAG',
#    'abbTAG',
#    'aaaTAG',
#    'babTAG',
#    'baaTAG',
#    'bbaTAG']],
#  ['TTGTTA',
#   ['TbbbTA',
#    'TabaTA',
#    'TaaaTA',
#    'TbabTA',
#    'TaabTA',
#    'TbaaTA',
#    'TbbaTA',
#    'TabbTA']],
#  ['CTTGTT',
#   ['CTabaT',
#    'CTbbaT',
#    'CTaaaT',
#    'CTbaaT',
#    'CTbbbT',
#    'CTbabT',
#    'CTaabT',
#    'CTabbT']],
#  ['ACTTGT',
#   ['ACTabb',
#    'ACTbaa',
#    'ACTbbb',
#    'ACTaba',
#    'ACTaab',
#    'ACTbab',
#    'ACTbba',
#    'ACTaaa']],
#  ['CACTTG', ['CACTaa', 'CACTba', 'CACTab', 'CACTbb']],
#  ['TGTTAG',
#   ['bbbTAG',
#    'abaTAG',
#    'aabTAG',
#    'abbTAG',
#    'aaaTAG',
#    'babTAG',
#    'baaTAG',
#    'bbaTAG']],
#  ['TTGTTA',
#   ['TbbbTA',
#    'TabaTA',
#    'TaaaTA',
#    'TbabTA',
#    'TaabTA',
#    'TbaaTA',
#    'TbbaTA',
#    'TabbTA']],
#  ['CTTGTT',
#   ['CTabaT',
#    'CTbbaT',
#    'CTaaaT',
#    'CTbaaT',
#    'CTbbbT',
#    'CTbabT',
#    'CTaabT',
#    'CTabbT']],
#  ['ACTTGT',
#   ['ACTabb',
#    'ACTbaa',
#    'ACTbbb',
#    'ACTaba',
#    'ACTaab',
#    'ACTbab',
#    'ACTbba',
#    'ACTaaa']],
#  ['CACTTG', ['CACTaa', 'CACTba', 'CACTab', 'CACTbb']],
#  ['CCACTT', ['CCACTa', 'CCACTb']],
#  ['TGCAAG', ['aGCAAG', 'bGCAAG']],
#  ['GTGCAA', ['caGCAA', 'cbGCAA']],
#  ['AGTGCA', ['acaGCA', 'bcbGCA', 'acbGCA', 'bcaGCA']],
#  ['GAGTGC', ['GbcaGC', 'GacbGC', 'GbcbGC', 'GacaGC']],
#  ['CGAGTG',
#   ['bGbcbG',
#    'aGbcaG',
#    'aGacaG',
#    'bGacbG',
#    'bGbcaG',
#    'bGacaG',
#    'aGacbG',
#    'aGbcbG']],
#  ['TCGAGT',
#   ['TbGbca',
#    'TbGbcb',
#    'TbGaca',
#    'TbGacb',
#    'TaGbcb',
#    'TaGacb',
#    'TaGbca',
#    'TaGaca']],
#  ['AGTGCA', ['acaGCA', 'bcbGCA', 'acbGCA', 'bcaGCA']],
#  ['GAGTGC', ['GbcaGC', 'GacbGC', 'GbcbGC', 'GacaGC']],
#  ['CGAGTG',
#   ['bGbcbG',
#    'aGbcaG',
#    'aGacaG',
#    'bGacbG',
#    'bGbcaG',
#    'bGacaG',
#    'aGacbG',
#    'aGbcbG']],
#  ['TCGAGT',
#   ['TbGbca',
#    'TbGbcb',
#    'TbGaca',
#    'TbGacb',
#    'TaGbcb',
#    'TaGacb',
#    'TaGbca',
#    'TaGaca']],
#  ['GTCGAG', ['cTaGbc', 'cTaGac', 'cTbGbc', 'cTbGac']],
#  ['GGTCGA', ['GcTaGa', 'GcTbGb', 'GcTaGb', 'GcTbGa']],
#  ['CGAGTG',
#   ['bGbcbG',
#    'aGbcaG',
#    'aGacaG',
#    'bGacbG',
#    'bGbcaG',
#    'bGacaG',
#    'aGacbG',
#    'aGbcbG']],
#  ['TCGAGT',
#   ['TbGbca',
#    'TbGbcb',
#    'TbGaca',
#    'TbGacb',
#    'TaGbcb',
#    'TaGacb',
#    'TaGbca',
#    'TaGaca']],
#  ['GTCGAG', ['cTaGbc', 'cTaGac', 'cTbGbc', 'cTbGac']],
#  ['GGTCGA', ['GcTaGa', 'GcTbGb', 'GcTaGb', 'GcTbGa']],
#  ['GGGTCG', ['GGcTaG', 'GGcTbG']],
#  ['TGGGTC', ['TGGcTb', 'TGGcTa']],
#  ['CAGATT', ['bAcATT', 'aAcATT']],
#  ['CCAGAT', ['CbAcAT', 'CaAcAT']],
#  ['GCCAGA', ['GCbAcA', 'GCaAcA']],
#  ['TGCCAG', ['TGCbAc', 'TGCaAc']],
#  ['CTGCCA', ['CTGCaA', 'CTGCbA']],
#  ['GCTGCC', ['GCTGCa', 'GCTGCb']],
#  ['TTGGAC', ['aTGGAC', 'bTGGAC']],
#  ['ATTGGA', ['AbTGGA', 'AaTGGA']],
#  ['GATTGG', ['GAbTGG', 'GAaTGG']],
#  ['TGATTG', ['TGAaTG', 'TGAbTG']],
#  ['TTGATT', ['TTGAaT', 'TTGAbT']],
#  ['TTTGAT', ['TTTGAa', 'TTTGAb']]]

# %%
mods_csv = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/mod_files/mod_file.csv"
reference = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/yeast_25S_18S.fa"
alt_c_positions = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/alt_canonical_distribution/yeast_18S_25S_variants.positions"
output_path = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/small_models/small_7mer/yeast_18S_25S_variants.positions"
k=7
rna=True
ambig_positions = alt_c_positions
kmer_mapping = create_efficient_positions_file(reference, ambig_positions, mods_csv, output_path, k=k, rna=rna)
rna_model = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/small_models/small_7mer/rna_r94_7mer_ACGTabc.model"
edit_model_with_kmer_mapping(rna_model, kmer_mapping, rna=rna)
# Out:
# ANOTHER ITER 2
# PASS RDN18-1+25 1573 0 0
# ANOTHER ITER 1
# PASS RDN18-1+25 1575 0 0
# DONE

# %%
kmer_mapping
# Out:
# [['ATACTGA', ['bTACTGA', 'aTACTGA']],
#  ['TATACTG', ['TbTACTG', 'TaTACTG']],
#  ['GTATACT', ['GTbTACT', 'GTaTACT']],
#  ['CGTATAC', ['CGTbTAC', 'CGTaTAC']],
#  ['TCGTATA', ['TCGTbTA', 'TCGTaTA']],
#  ['TTCGTAT', ['TTCGTbT', 'TTCGTaT']],
#  ['GTTCGTA', ['GTTCGTb', 'GTTCGTa']],
#  ['ACTCGGT', ['aCTCGGT', 'bCTCGGT']],
#  ['TACTCGG', ['TbCTCGG', 'TaCTCGG']],
#  ['TTACTCG', ['TTbCTCG', 'TTaCTCG']],
#  ['ATTACTC', ['ATTaCTC', 'ATTbCTC']],
#  ['AATTACT', ['AATTaCT', 'AATTbCT']],
#  ['AAATTAC', ['AAATTbC', 'AAATTaC']],
#  ['TAAATTA', ['aAAATTb', 'aAAATTa', 'bAAATTa', 'bAAATTb']],
#  ['TAAATTA', ['aAAATTb', 'aAAATTa', 'bAAATTa', 'bAAATTb']],
#  ['CTAAATT', ['CaAAATT', 'CbAAATT']],
#  ['ACTAAAT', ['ACaAAAT', 'ACbAAAT']],
#  ['GACTAAA', ['GACbAAA', 'GACaAAA']],
#  ['TGACTAA', ['TGACbAA', 'TGACaAA']],
#  ['TTGACTA', ['TTGACaA', 'TTGACbA']],
#  ['ATTGACT', ['ATTGACa', 'ATTGACb']],
#  ['TATTTGC', ['bATTTGC', 'aATTTGC']],
#  ['TTATTTG', ['TaATTTG', 'TbATTTG']],
#  ['TTTATTT', ['TTaATTT', 'TTbATTT']],
#  ['GTTTATT', ['GTTbATT', 'GTTaATT']],
#  ['AGTTTAT', ['AGTTaAT', 'AGTTbAT']],
#  ['TAGTTTA', ['TAGTTaA', 'TAGTTbA']],
#  ['ATAGTTT', ['ATAGTTb', 'ATAGTTa']],
#  ['TATTTAT', ['aATTTAT', 'bATTTAT']],
#  ['TTATTTA', ['TaATTTA', 'TbATTTA']],
#  ['ATTATTT', ['ATaATTT', 'ATbATTT']],
#  ['GATTATT', ['GATaATT', 'GATbATT']],
#  ['AGATTAT', ['AGATaAT', 'AGATbAT']],
#  ['TAGATTA', ['TAGATbA', 'TAGATaA']],
#  ['ATAGATT', ['ATAGATb', 'ATAGATa']],
#  ['TAAACTT', ['bAAACTT', 'aAAACTT']],
#  ['TTAAACT', ['TaAAACT', 'TbAAACT']],
#  ['TTTAAAC', ['TTbAAAC', 'TTaAAAC']],
#  ['CTTTAAA', ['CTTaAAA', 'CTTbAAA']],
#  ['TCTTTAA', ['TCTTaAA', 'TCTTbAA']],
#  ['GTCTTTA', ['GTCTTaA', 'GTCTTbA']],
#  ['CGTCTTT', ['CGTCTTa', 'CGTCTTb']],
#  ['CTACACC', ['aTACACC', 'bTACACC']],
#  ['CCTACAC', ['CbTACAC', 'CaTACAC']],
#  ['ACCTACA', ['ACbTACA', 'ACaTACA']],
#  ['AACCTAC', ['AACaTAC', 'AACbTAC']],
#  ['GAACCTA', ['GAACaTA', 'GAACbTA']],
#  ['GGAACCT', ['GGAACaT', 'GGAACbT']],
#  ['AGGAACC', ['bGGAACa', 'aGGAACb', 'bGGAACb', 'aGGAACa']],
#  ['AGGAACC', ['bGGAACa', 'aGGAACb', 'bGGAACb', 'aGGAACa']],
#  ['AAGGAAC', ['AbGGAAC', 'AaGGAAC']],
#  ['GAAGGAA', ['GAbGGAA', 'GAaGGAA']],
#  ['GGAAGGA', ['GGAaGGA', 'GGAbGGA']],
#  ['CGGAAGG', ['CGGAbGG', 'CGGAaGG']],
#  ['ACGGAAG', ['ACGGAbG', 'ACGGAaG']],
#  ['GACGGAA', ['GACGGAb', 'GACGGAa']],
#  ['ACGCGCG', ['aCGCGCG', 'bCGCGCG']],
#  ['AACGCGC', ['AaCGCGC', 'AbCGCGC']],
#  ['AAACGCG', ['AAbCGCG', 'AAaCGCG']],
#  ['TAAACGC', ['TAAbCGC', 'TAAaCGC']],
#  ['TTAAACG', ['TTAAaCG', 'TTAAbCG']],
#  ['ATTAAAC', ['ATTAAbC', 'ATTAAaC']],
#  ['CATTAAA', ['CATTAAa', 'CATTAAb']],
#  ['TGATGGA', ['bGATGGA', 'aGATGGA']],
#  ['GTGATGG', ['GbGATGG', 'GaGATGG']],
#  ['AGTGATG', ['AGbGATG', 'AGaGATG']],
#  ['CAGTGAT', ['CAGbGAT', 'CAGaGAT']],
#  ['ACAGTGA', ['ACAGaGA', 'ACAGbGA']],
#  ['AACAGTG', ['AACAGaG', 'AACAGbG']],
#  ['TAACAGT', ['TAACAGb', 'TAACAGa']],
#  ['AGGAGCA', ['aGGAGCA', 'bGGAGCA']],
#  ['AAGGAGC', ['AaGGAGC', 'AbGGAGC']],
#  ['CAAGGAG', ['CAaGGAG', 'CAbGGAG']],
#  ['ACAAGGA', ['ACAbGGA', 'ACAaGGA']],
#  ['AACAAGG', ['AACAbGG', 'AACAaGG']],
#  ['TAACAAG', ['TAACAbG', 'TAACAaG']],
#  ['TTAACAA', ['TTAACAa', 'TTAACAb']],
#  ['GGTCTGA', ['aGTCTGA', 'bGTCTGA']],
#  ['TGGTCTG', ['TbGTCTG', 'TaGTCTG']],
#  ['GTGGTCT', ['GTaGTCT', 'GTbGTCT']],
#  ['CGTGGTC', ['CGTbGTC', 'CGTaGTC']],
#  ['CCGTGGT', ['CCGTbGT', 'CCGTaGT']],
#  ['ACCGTGG', ['ACCGTbG', 'ACCGTaG']],
#  ['GACCGTG', ['GACCGTa', 'GACCGTb']],
#  ['TGGCGCC', ['aGGCGCC', 'bGGCGCC']],
#  ['ATGGCGC', ['AbGGCGC', 'AaGGCGC']],
#  ['AATGGCG', ['AAbGGCG', 'AAaGGCG']],
#  ['TAATGGC', ['TAAbGGC', 'TAAaGGC']],
#  ['TTAATGG', ['TTAAaGG', 'TTAAbGG']],
#  ['CTTAATG', ['CTTAAaG', 'CTTAAbG']],
#  ['CCTTAAT', ['CCTTAAa', 'CCTTAAb']],
#  ['ATTGACG', ['bTTGACG', 'aTTGACG']],
#  ['AATTGAC', ['AbTTGAC', 'AaTTGAC']],
#  ['AAATTGA', ['AAbTTGA', 'AAaTTGA']],
#  ['AAAATTG', ['AAAaTTG', 'AAAbTTG']],
#  ['AAAAATT', ['AAAAaTT', 'AAAAbTT']],
#  ['GAAAAAT', ['GAAAAbT', 'GAAAAaT']],
#  ['CGAAAAA', ['CGAAAAb', 'CGAAAAa']],
#  ['TGATGCT', ['aGATGCT', 'bGATGCT']],
#  ['TTGATGC', ['TaGATGC', 'TbGATGC']],
#  ['GTTGATG', ['GTbGATG', 'GTaGATG']],
#  ['AGTTGAT', ['AGTaGAT', 'AGTbGAT']],
#  ['AAGTTGA', ['AAGTbGA', 'AAGTaGA']],
#  ['CAAGTTG', ['CAAGTbG', 'CAAGTaG']],
#  ['TCAAGTT', ['TCAAGTa', 'TCAAGTb']],
#  ['TTAAAAA', ['aTAAAAA', 'bTAAAAA']],
#  ['ATTAAAA', ['AbTAAAA', 'AaTAAAA']],
#  ['GATTAAA', ['GAbTAAA', 'GAaTAAA']],
#  ['AGATTAA', ['AGAaTAA', 'AGAbTAA']],
#  ['GAGATTA', ['GAGAaTA', 'GAGAbTA']],
#  ['TGAGATT', ['TGAGAbT', 'TGAGAaT']],
#  ['GTGAGAT', ['GTGAGAb', 'GTGAGAa']],
#  ['TGTGAGA', ['bGTGAGA', 'aGTGAGA']],
#  ['TTGTGAG', ['TbGTGAG', 'TaGTGAG']],
#  ['CTTGTGA', ['CTbGTGA', 'CTaGTGA']],
#  ['ACTTGTG', ['ACTbGTG', 'ACTaGTG']],
#  ['AACTTGT', ['AACTaGT', 'AACTbGT']],
#  ['AAACTTG', ['AAACTaG', 'AAACTbG']],
#  ['GAAACTT', ['GAAACTa', 'GAAACTb']],
#  ['ATTATAT', ['bTTATAT', 'aTTATAT']],
#  ['GATTATA', ['GaTTATA', 'GbTTATA']],
#  ['CGATTAT', ['CGbTTAT', 'CGaTTAT']],
#  ['ACGATTA', ['ACGaTTA', 'ACGbTTA']],
#  ['TACGATT', ['TACGaTT', 'TACGbTT']],
#  ['GTACGAT', ['GTACGaT', 'GTACGbT']],
#  ['GGTACGA', ['GGTACGa', 'GGTACGb']],
#  ['AAGAACT', ['bAGAACT', 'aAGAACT']],
#  ['CAAGAAC', ['CbAGAAC', 'CaAGAAC']],
#  ['GCAAGAA', ['GCaAGAA', 'GCbAGAA']],
#  ['AGCAAGA', ['AGCaAGA', 'AGCbAGA']],
#  ['AAGCAAG', ['AAGCbAG', 'AAGCaAG']],
#  ['AAAGCAA', ['AAAGCaA', 'AAAGCbA']],
#  ['GAAAGCA', ['GAAAGCb', 'GAAAGCa']],
#  ['TAGTAGA', ['aAGTAGA', 'bAGTAGA']],
#  ['CTAGTAG', ['CaAGTAG', 'CbAGTAG']],
#  ['ACTAGTA', ['ACaAGTA', 'ACbAGTA']],
#  ['GACTAGT', ['GACaAGT', 'GACbAGT']],
#  ['AGACTAG', ['AGACaAG', 'AGACbAG']],
#  ['TAGACTA', ['TAGACaA', 'TAGACbA']],
#  ['ATAGACT', ['ATAGACb', 'ATAGACa']],
#  ['CCATAGA', ['bCATAGA', 'aCATAGA']],
#  ['GCCATAG', ['GaCATAG', 'GbCATAG']],
#  ['TGCCATA', ['TGaCATA', 'TGbCATA']],
#  ['CTGCCAT', ['CTGbCAT', 'CTGaCAT']],
#  ['GCTGCCA', ['GCTGbCA', 'GCTGaCA']],
#  ['TGCTGCC', ['TGCTGbC', 'TGCTGaC']],
#  ['ATGCTGC', ['ATGCTGb', 'ATGCTGa']],
#  ['GAACGCT', ['aAACGCT', 'bAACGCT']],
#  ['GGAACGC', ['GbAACGC', 'GaAACGC']],
#  ['CGGAACG', ['CGbAACG', 'CGaAACG']],
#  ['TCGGAAC', ['TCGbAAC', 'TCGaAAC']],
#  ['GTCGGAA', ['GTCGaAA', 'GTCGbAA']],
#  ['AGTCGGA', ['AGTCGaA', 'AGTCGbA']],
#  ['AAGTCGG', ['AAGTCGb', 'AAGTCGa']],
#  ['TCGGCGT', ['aCGGCGT', 'bCGGCGT']],
#  ['TTCGGCG', ['TbCGGCG', 'TaCGGCG']],
#  ['ATTCGGC', ['ATbCGGC', 'ATaCGGC']],
#  ['AATTCGG', ['AATbCGG', 'AATaCGG']],
#  ['TAATTCG', ['TAATbCG', 'TAATaCG']],
#  ['TTAATTC', ['TTAATaC', 'TTAATbC']],
#  ['TTTAATT', ['bTTAATb', 'bTTAATa', 'aTTAATb', 'aTTAATa']],
#  ['TTTAATT', ['bTTAATb', 'bTTAATa', 'aTTAATb', 'aTTAATa']],
#  ['GTTTAAT', ['GbTTAAT', 'GaTTAAT']],
#  ['AGTTTAA', ['AGbTTAA', 'AGaTTAA']],
#  ['CAGTTTA', ['CAGaTTA', 'CAGbTTA']],
#  ['TCAGTTT', ['aCAGbTT', 'aCAGaTT', 'bCAGbTT', 'bCAGaTT']],
#  ['CTCAGTT', ['CbCAGbT', 'CaCAGbT', 'CaCAGaT', 'CbCAGaT']],
#  ['ACTCAGT', ['ACbCAGb', 'ACaCAGa', 'ACaCAGb', 'ACbCAGa']],
#  ['TCAGTTT', ['aCAGbTT', 'aCAGaTT', 'bCAGbTT', 'bCAGaTT']],
#  ['CTCAGTT', ['CbCAGbT', 'CaCAGbT', 'CaCAGaT', 'CbCAGaT']],
#  ['ACTCAGT', ['ACbCAGb', 'ACaCAGa', 'ACaCAGb', 'ACbCAGa']],
#  ['AACTCAG', ['AACbCAG', 'AACaCAG']],
#  ['CAACTCA', ['CAACaCA', 'CAACbCA']],
#  ['ACAACTC', ['ACAACbC', 'ACAACaC']],
#  ['CACAACT', ['CACAACb', 'CACAACa']],
#  ['TGGTGGG', ['aGGTGGG', 'bGGTGGG']],
#  ['GTGGTGG', ['GaGGTGG', 'GbGGTGG']],
#  ['GGTGGTG', ['aGbGGTG', 'bGaGGTG', 'bGbGGTG', 'aGaGGTG']],
#  ['TGGTGGT', ['TbGbGGT', 'TaGaGGT', 'TaGbGGT', 'TbGaGGT']],
#  ['GTGGTGG', ['GTaGbGG', 'GTbGbGG', 'GTaGaGG', 'GTbGaGG']],
#  ['CGTGGTG', ['CGTaGbG', 'CGTbGbG', 'CGTbGaG', 'CGTaGaG']],
#  ['ACGTGGT', ['ACGTaGb', 'ACGTbGb', 'ACGTbGa', 'ACGTaGa']],
#  ['GGTGGTG', ['aGbGGTG', 'bGaGGTG', 'bGbGGTG', 'aGaGGTG']],
#  ['TGGTGGT', ['TbGbGGT', 'TaGaGGT', 'TaGbGGT', 'TbGaGGT']],
#  ['GTGGTGG', ['GTaGbGG', 'GTbGbGG', 'GTaGaGG', 'GTbGaGG']],
#  ['CGTGGTG', ['CGTaGbG', 'CGTbGbG', 'CGTbGaG', 'CGTaGaG']],
#  ['ACGTGGT', ['ACGTaGb', 'ACGTbGb', 'ACGTbGa', 'ACGTaGa']],
#  ['TACGTGG', ['TACGTbG', 'TACGTaG']],
#  ['GTACGTG', ['GTACGTa', 'GTACGTb']],
#  ['CCGGTAC', ['aCGGTAC', 'bCGGTAC']],
#  ['GCCGGTA', ['GbCGGTA', 'GaCGGTA']],
#  ['TGCCGGT', ['TGaCGGT', 'TGbCGGT']],
#  ['TTGCCGG', ['TTGaCGG', 'TTGbCGG']],
#  ['CTTGCCG', ['CTTGbCG', 'CTTGaCG']],
#  ['TCTTGCC', ['TCTTGbC', 'TCTTGaC']],
#  ['TTCTTGC', ['TTCTTGb', 'TTCTTGa']],
#  ['TTGATTC', ['aTGATTC', 'bTGATTC']],
#  ['GTTGATT', ['GaTGATT', 'GbTGATT']],
#  ['GGTTGAT', ['GGbTGAT', 'GGaTGAT']],
#  ['TGGTTGA', ['TGGbTGA', 'TGGaTGA']],
#  ['GTGGTTG', ['GTGGbTG', 'GTGGaTG']],
#  ['GGTGGTT', ['GGTGGaT', 'GGTGGbT']],
#  ['AGGTGGT', ['AGGTGGb', 'AGGTGGa']],
#  ['TTTGAAG', ['aTTGAAG', 'bTTGAAG']],
#  ['GTTTGAA', ['GaTTGAA', 'GbTTGAA']],
#  ['AGTTTGA', ['AGaTTGA', 'AGbTTGA']],
#  ['GAGTTTG', ['GAGaTTG', 'GAGbTTG']],
#  ['GGAGTTT', ['GGAGaTT', 'GGAGbTT']],
#  ['CGGAGTT', ['CGGAGbT', 'CGGAGaT']],
#  ['ACGGAGT', ['ACGGAGa', 'ACGGAGb']],
#  ['GACAATA', ['bACAATA', 'aACAATA']],
#  ['GGACAAT', ['GbACAAT', 'GaACAAT']],
#  ['TGGACAA', ['TGaACAA', 'TGbACAA']],
#  ['CTGGACA', ['CTGbACA', 'CTGaACA']],
#  ['TCTGGAC', ['TCTGaAC', 'TCTGbAC']],
#  ['GTCTGGA', ['GTCTGaA', 'GTCTGbA']],
#  ['TGTCTGG', ['TGTCTGb', 'TGTCTGa']],
#  ['GCAACTT', ['bCAACTT', 'aCAACTT']],
#  ['AGCAACT', ['AaCAACT', 'AbCAACT']],
#  ['GAGCAAC', ['cAaCAAC', 'cAbCAAC']],
#  ['GGAGCAA', ['acAaCAA', 'bcAbCAA', 'bcAaCAA', 'acAbCAA']],
#  ['AGGAGCA', ['cbcAbCA', 'cacAaCA', 'cacAbCA', 'cbcAaCA']],
#  ['AAGGAGC', ['AcbcAbC', 'AcacAbC', 'AcbcAaC', 'AcacAaC']],
#  ['TAAGGAG', ['TAcacAa', 'TAcacAb', 'TAcbcAb', 'TAcbcAa']],
#  ['GGAGCAA', ['acAaCAA', 'bcAbCAA', 'bcAaCAA', 'acAbCAA']],
#  ['AGGAGCA', ['cbcAbCA', 'cacAaCA', 'cacAbCA', 'cbcAaCA']],
#  ['AAGGAGC', ['AcbcAbC', 'AcacAbC', 'AcbcAaC', 'AcacAaC']],
#  ['TAAGGAG', ['TAcacAa', 'TAcacAb', 'TAcbcAb', 'TAcbcAa']],
#  ['TTAAGGA', ['TTAcbcA', 'TTAcacA']],
#  ['CTTAAGG', ['CTTAcbc', 'CTTAcac']],
#  ['CCTTAAG', ['CCTTAcb', 'CCTTAca']],
#  ['CGCCACA', ['aGCCACA', 'bGCCACA']],
#  ['CCGCCAC', ['CaGCCAC', 'CbGCCAC']],
#  ['CCCGCCA', ['CCaGCCA', 'CCbGCCA']],
#  ['GCCCGCC', ['GCCaGCC', 'GCCbGCC']],
#  ['TGCCCGC', ['TGCCaGC', 'TGCCbGC']],
#  ['CTGCCCG', ['CTGCCbG', 'CTGCCaG']],
#  ['GCTGCCC', ['GCTGCCb', 'GCTGCCa']],
#  ['CCTTTGG', ['bCTTTGG', 'aCTTTGG']],
#  ['GCCTTTG', ['GaCTTTG', 'GbCTTTG']],
#  ['TGCCTTT', ['TGaCTTT', 'TGbCTTT']],
#  ['ATGCCTT', ['ATGaCTT', 'ATGbCTT']],
#  ['GATGCCT', ['GATGbCT', 'GATGaCT']],
#  ['GGATGCC', ['GGATGbC', 'GGATGaC']],
#  ['TGGATGC', ['TGGATGa', 'TGGATGb']],
#  ['AGTGGAT', ['bGTGGAT', 'aGTGGAT']],
#  ['AAGTGGA', ['aaGTGGA', 'baGTGGA', 'abGTGGA', 'bbGTGGA']],
#  ['CAAGTGG', ['CabGTGG', 'CbbGTGG', 'CaaGTGG', 'CbaGTGG']],
#  ['CCAAGTG', ['CCaaGTG', 'CCbaGTG', 'CCbbGTG', 'CCabGTG']],
#  ['TCCAAGT', ['TCCaaGT', 'TCCabGT', 'TCCbaGT', 'TCCbbGT']],
#  ['GTCCAAG', ['GTCCaaG', 'GTCCabG', 'GTCCbbG', 'GTCCbaG']],
#  ['CGTCCAA', ['CGTCCab', 'CGTCCaa', 'CGTCCbb', 'CGTCCba']],
#  ['AAGTGGA', ['aaGTGGA', 'baGTGGA', 'abGTGGA', 'bbGTGGA']],
#  ['CAAGTGG', ['CabGTGG', 'CbbGTGG', 'CaaGTGG', 'CbaGTGG']],
#  ['CCAAGTG', ['CCaaGTG', 'CCbaGTG', 'CCbbGTG', 'CCabGTG']],
#  ['TCCAAGT', ['TCCaaGT', 'TCCabGT', 'TCCbaGT', 'TCCbbGT']],
#  ['GTCCAAG', ['GTCCaaG', 'GTCCabG', 'GTCCbbG', 'GTCCbaG']],
#  ['CGTCCAA', ['CGTCCab', 'CGTCCaa', 'CGTCCbb', 'CGTCCba']],
#  ['GCGTCCA', ['GCGTCCa', 'GCGTCCb']],
#  ['AGTTCTG', ['aGTTCTG', 'bGTTCTG']],
#  ['AAGTTCT', ['AaGTTCT', 'AbGTTCT']],
#  ['AAAGTTC', ['AAaGTTC', 'AAbGTTC']],
#  ['CAAAGTT', ['CAAaGTT', 'CAAbGTT']],
#  ['ACAAAGT', ['bCAAbGT', 'aCAAbGT', 'aCAAaGT', 'bCAAaGT']],
#  ['CACAAAG',
#   ['abCAAaG',
#    'baCAAbG',
#    'aaCAAaG',
#    'aaCAAbG',
#    'bbCAAaG',
#    'abCAAbG',
#    'bbCAAbG',
#    'baCAAaG']],
#  ['GCACAAA',
#   ['GbaCAAb',
#    'GbaCAAa',
#    'GbbCAAa',
#    'GaaCAAa',
#    'GabCAAb',
#    'GbbCAAb',
#    'GaaCAAb',
#    'GabCAAa']],
#  ['ACAAAGT', ['bCAAbGT', 'aCAAbGT', 'aCAAaGT', 'bCAAaGT']],
#  ['CACAAAG',
#   ['abCAAaG',
#    'baCAAbG',
#    'aaCAAaG',
#    'aaCAAbG',
#    'bbCAAaG',
#    'abCAAbG',
#    'bbCAAbG',
#    'baCAAaG']],
#  ['GCACAAA',
#   ['GbaCAAb',
#    'GbaCAAa',
#    'GbbCAAa',
#    'GaaCAAa',
#    'GabCAAb',
#    'GbbCAAb',
#    'GaaCAAb',
#    'GabCAAa']],
#  ['GGCACAA', ['GGabCAA', 'GGbaCAA', 'GGaaCAA', 'GGbbCAA']],
#  ['AGGCACA', ['AGGabCA', 'AGGbbCA', 'AGGbaCA', 'AGGaaCA']],
#  ['CAGGCAC', ['CAGGbbC', 'CAGGaaC', 'CAGGbaC', 'CAGGabC']],
#  ['CCAGGCA', ['CCAGGbb', 'CCAGGba', 'CCAGGab', 'CCAGGaa']],
#  ['CACAAAG',
#   ['abCAAaG',
#    'baCAAbG',
#    'aaCAAaG',
#    'aaCAAbG',
#    'bbCAAaG',
#    'abCAAbG',
#    'bbCAAbG',
#    'baCAAaG']],
#  ['GCACAAA',
#   ['GbaCAAb',
#    'GbaCAAa',
#    'GbbCAAa',
#    'GaaCAAa',
#    'GabCAAb',
#    'GbbCAAb',
#    'GaaCAAb',
#    'GabCAAa']],
#  ['GGCACAA', ['GGabCAA', 'GGbaCAA', 'GGaaCAA', 'GGbbCAA']],
#  ['AGGCACA', ['AGGabCA', 'AGGbbCA', 'AGGbaCA', 'AGGaaCA']],
#  ['CAGGCAC', ['CAGGbbC', 'CAGGaaC', 'CAGGbaC', 'CAGGabC']],
#  ['CCAGGCA', ['CCAGGbb', 'CCAGGba', 'CCAGGab', 'CCAGGaa']],
#  ['ACCAGGC', ['ACCAGGa', 'ACCAGGb']],
#  ['CTGAGGA', ['bTGAGGA', 'aTGAGGA']],
#  ['TCTGAGG', ['TbTGAGG', 'TaTGAGG']],
#  ['ATCTGAG', ['ATbTGAG', 'ATaTGAG']],
#  ['AATCTGA', ['AATaTGA', 'AATbTGA']],
#  ['CAATCTG', ['CAATaTG', 'CAATbTG']],
#  ['GCAATCT', ['GCAATbT', 'GCAATaT']],
#  ['TGCAATC', ['TGCAATa', 'TGCAATb']],
#  ['TAGGTAG', ['bAGGTAG', 'aAGGTAG']],
#  ['TTAGGTA', ['TbAGGTA', 'TaAGGTA']],
#  ['TTTAGGT', ['TTaAGGT', 'TTbAGGT']],
#  ['GTTTAGG', ['GTTbAGG', 'GTTaAGG']],
#  ['AGTTTAG', ['AGTTbAG', 'AGTTaAG']],
#  ['GAGTTTA', ['GAGTTaA', 'GAGTTbA']],
#  ['TGAGTTT', ['TGAGTTa', 'TGAGTTb']],
#  ['GCCCAGG', ['bCCCAGG', 'aCCCAGG']],
#  ['AGCCCAG', ['AaCCCAG', 'AbCCCAG']],
#  ['AAGCCCA', ['aAbCCCA', 'aAaCCCA', 'bAbCCCA', 'bAaCCCA']],
#  ['AAAGCCC', ['AbAaCCC', 'AaAaCCC', 'AaAbCCC', 'AbAbCCC']],
#  ['GAAAGCC', ['GAaAaCC', 'GAbAbCC', 'GAbAaCC', 'GAaAbCC']],
#  ['AGAAAGC', ['AGAaAaC', 'AGAbAbC', 'AGAaAbC', 'AGAbAaC']],
#  ['TAGAAAG', ['TAGAaAb', 'TAGAbAa', 'TAGAaAa', 'TAGAbAb']],
#  ['AAGCCCA', ['aAbCCCA', 'aAaCCCA', 'bAbCCCA', 'bAaCCCA']],
#  ['AAAGCCC', ['AbAaCCC', 'AaAaCCC', 'AaAbCCC', 'AbAbCCC']],
#  ['GAAAGCC', ['GAaAaCC', 'GAbAbCC', 'GAbAaCC', 'GAaAbCC']],
#  ['AGAAAGC', ['AGAaAaC', 'AGAbAbC', 'AGAaAbC', 'AGAbAaC']],
#  ['TAGAAAG', ['TAGAaAb', 'TAGAbAa', 'TAGAaAa', 'TAGAbAb']],
#  ['GTAGAAA', ['GTAGAaA', 'GTAGAbA']],
#  ['GGTAGAA', ['GGTAGAb', 'GGTAGAa']],
#  ['AAGTGGT', ['aAGTGGT', 'bAGTGGT']],
#  ['CAAGTGG', ['CaAGTGG', 'CbAGTGG']],
#  ['TCAAGTG', ['TCbAGTG', 'TCaAGTG']],
#  ['ATCAAGT', ['ATCbAGT', 'ATCaAGT']],
#  ['TATCAAG', ['TATCaAG', 'TATCbAG']],
#  ['GTATCAA', ['GTATCaA', 'GTATCbA']],
#  ['CGTATCA', ['CGTATCa', 'CGTATCb']],
#  ['GATGCTC', ['bATGCTC', 'aATGCTC']],
#  ['CGATGCT', ['CbATGCT', 'CaATGCT']],
#  ['GCGATGC', ['GCaATGC', 'GCbATGC']],
#  ['GGCGATG', ['GGCaATG', 'GGCbATG']],
#  ['TGGCGAT', ['TGGCaAT', 'TGGCbAT']],
#  ['TTGGCGA', ['TTGGCaA', 'TTGGCbA']],
#  ['CTTGGCG', ['CTTGGCb', 'CTTGGCa']],
#  ['AGTCTTG', ['bGTCTTG', 'aGTCTTG']],
#  ['CAGTCTT', ['CbGTCTT', 'CaGTCTT']],
#  ['GCAGTCT', ['GCaGTCT', 'GCbGTCT']],
#  ['TGCAGTC', ['TGCbGTC', 'TGCaGTC']],
#  ['GTGCAGT', ['GTGCbGT', 'GTGCaGT']],
#  ['CGTGCAG', ['CGTGCbG', 'CGTGCaG']],
#  ['ACGTGCA', ['ACGTGCa', 'ACGTGCb']],
#  ['TTAAGCT', ['bTAAGCT', 'aTAAGCT']],
#  ['TTTAAGC', ['TaTAAGC', 'TbTAAGC']],
#  ['GTTTAAG', ['GTaTAAG', 'GTbTAAG']],
#  ['GGTTTAA', ['GGTaTAA', 'GGTbTAA']],
#  ['GGGTTTA', ['GGGTaTA', 'GGGTbTA']],
#  ['TGGGTTT', ['TGGGTaT', 'TGGGTbT']],
#  ['ATGGGTT', ['ATGGGTa', 'ATGGGTb']],
#  ['GGATATG', ['aGATATG', 'bGATATG']],
#  ['GGGATAT', ['GbGATAT', 'GaGATAT']],
#  ['GGGGATA', ['GGbGATA', 'GGaGATA']],
#  ['CGGGGAT', ['CGGaGAT', 'CGGbGAT']],
#  ['GCGGGGA', ['GCGGaGA', 'GCGGbGA']],
#  ['AGCGGGG', ['AGCGGaG', 'AGCGGbG']],
#  ['AAGCGGG', ['AAGCGGb', 'AAGCGGa']],
#  ['TCCCTTT', ['bCCCTTT', 'aCCCTTT']],
#  ['CTCCCTT', ['CaCCCTT', 'CbCCCTT']],
#  ['ACTCCCT', ['ACbCCCT', 'ACaCCCT']],
#  ['GACTCCC', ['GACbCCC', 'GACaCCC']],
#  ['GGACTCC', ['GGACaCC', 'GGACbCC']],
#  ['AGGACTC', ['AGGACaC', 'AGGACbC']],
#  ['TAGGACT', ['bAGGACa', 'aAGGACa', 'aAGGACb', 'bAGGACb']],
#  ['TAGGACT', ['bAGGACa', 'aAGGACa', 'aAGGACb', 'bAGGACb']],
#  ['ATAGGAC', ['AaAGGAC', 'AbAGGAC']],
#  ['GATAGGA', ['GAaAGGA', 'GAbAGGA']],
#  ['CGATAGG', ['CGAaAGG', 'CGAbAGG']],
#  ['ACGATAG', ['ACGAbAG', 'ACGAaAG']],
#  ['GACGATA', ['GACGAaA', 'GACGAbA']],
#  ['AGACGAT', ['AGACGAb', 'AGACGAa']],
#  ['TTGACTA', ['aTGACTA', 'bTGACTA']],
#  ['TTTGACT', ['TbTGACT', 'TaTGACT']],
#  ['TTTTGAC', ['TTbTGAC', 'TTaTGAC']],
#  ['ATTTTGA', ['ATTaTGA', 'ATTbTGA']],
#  ['TATTTTG', ['aATTaTG', 'aATTbTG', 'bATTbTG', 'bATTaTG']],
#  ['GTATTTT', ['GaATTaT', 'GbATTaT', 'GaATTbT', 'GbATTbT']],
#  ['AGTATTT', ['AGbATTa', 'AGbATTb', 'AGaATTb', 'AGaATTa']],
#  ['TATTTTG', ['aATTaTG', 'aATTbTG', 'bATTbTG', 'bATTaTG']],
#  ['GTATTTT', ['GaATTaT', 'GbATTaT', 'GaATTbT', 'GbATTbT']],
#  ['AGTATTT', ['AGbATTa', 'AGbATTb', 'AGaATTb', 'AGaATTa']],
#  ['GAGTATT', ['GAGaATT', 'GAGbATT']],
#  ['GGAGTAT', ['GGAGbAT', 'GGAGaAT']],
#  ['TGGAGTA', ['TGGAGbA', 'TGGAGaA']],
#  ['ATGGAGT', ['ATGGAGb', 'ATGGAGa']],
#  ['TAAGCGA', ['aAAGCGA', 'bAAGCGA']],
#  ['GTAAGCG', ['GaAAGCG', 'GbAAGCG']],
#  ['AGTAAGC', ['AGbAAGC', 'AGaAAGC']],
#  ['TAGTAAG', ['TAGaAAG', 'TAGbAAG']],
#  ['TTAGTAA', ['TTAGaAA', 'TTAGbAA']],
#  ['ATTAGTA', ['ATTAGaA', 'ATTAGbA']],
#  ['GATTAGT', ['GATTAGb', 'GATTAGa']],
#  ['TTATCCA', ['aTATCCA', 'bTATCCA']],
#  ['CTTATCC', ['CbTATCC', 'CaTATCC']],
#  ['TCTTATC', ['TCaTATC', 'TCbTATC']],
#  ['CTCTTAT', ['CTCbTAT', 'CTCaTAT']],
#  ['ACTCTTA', ['ACTCaTA', 'ACTCbTA']],
#  ['AACTCTT', ['AACTCbT', 'AACTCaT']],
#  ['AAACTCT', ['AAACTCb', 'AAACTCa']],
#  ['TTTCAAA', ['bTTCAAA', 'aTTCAAA']],
#  ['ATTTCAA', ['AbTTCAA', 'AaTTCAA']],
#  ['AATTTCA', ['AAaTTCA', 'AAbTTCA']],
#  ['AAATTTC', ['AAAaTTC', 'AAAbTTC']],
#  ['TAAATTT', ['bAAAbTT', 'aAAAbTT', 'aAAAaTT', 'bAAAaTT']],
#  ['ATAAATT', ['AbAAAbT', 'AaAAAbT', 'AaAAAaT', 'AbAAAaT']],
#  ['TATAAAT', ['TAbAAAa', 'TAbAAAb', 'TAaAAAa', 'TAaAAAb']],
#  ['TAAATTT', ['bAAAbTT', 'aAAAbTT', 'aAAAaTT', 'bAAAaTT']],
#  ['ATAAATT', ['AbAAAbT', 'AaAAAbT', 'AaAAAaT', 'AbAAAaT']],
#  ['TATAAAT', ['TAbAAAa', 'TAbAAAb', 'TAaAAAa', 'TAaAAAb']],
#  ['GTATAAA', ['GTAaAAA', 'GTAbAAA']],
#  ['TGTATAA', ['TGTAaAA', 'TGTAbAA']],
#  ['ATGTATA', ['ATGTAbA', 'ATGTAaA']],
#  ['AATGTAT', ['AATGTAa', 'AATGTAb']],
#  ['TTTCGAG', ['bTTCGAG', 'aTTCGAG']],
#  ['TTTTCGA', ['TbTTCGA', 'TaTTCGA']],
#  ['ATTTTCG', ['ATaTTCG', 'ATbTTCG']],
#  ['GATTTTC', ['GATbTTC', 'GATaTTC']],
#  ['TGATTTT', ['TGATaTT', 'TGATbTT']],
#  ['GTGATTT', ['GTGATaT', 'GTGATbT']],
#  ['GGTGATT', ['GGTGATb', 'GGTGATa']],
#  ['TTTTACC', ['bTTTACC', 'aTTTACC']],
#  ['TTTTTAC', ['TbTTTAC', 'TaTTTAC']],
#  ['GTTTTTA', ['GTaTTTA', 'GTbTTTA']],
#  ['GGTTTTT', ['GGTaTTT', 'GGTbTTT']],
#  ['TGGTTTT', ['TGGTbTT', 'TGGTaTT']],
#  ['ATGGTTT', ['ATGGTbT', 'ATGGTaT']],
#  ['AATGGTT', ['AATGGTa', 'AATGGTb']],
#  ['ACGAATG', ['aCGAATG', 'bCGAATG']],
#  ['GACGAAT', ['GaCGAAT', 'GbCGAAT']],
#  ['AGACGAA', ['AGaCGAA', 'AGbCGAA']],
#  ['AAGACGA', ['AAGaCGA', 'AAGbCGA']],
#  ['CAAGACG', ['CAAGbCG', 'CAAGaCG']],
#  ['TCAAGAC', ['TCAAGbC', 'TCAAGaC']],
#  ['GTCAAGA', ['GTCAAGa', 'GTCAAGb']],
#  ['CTAGACG', ['aTAGACG', 'bTAGACG']],
#  ['TCTAGAC', ['TaTAGAC', 'TbTAGAC']],
#  ['TTCTAGA', ['TTbTAGA', 'TTaTAGA']],
#  ['GTTCTAG', ['GTTaTAG', 'GTTbTAG']],
#  ['GGTTCTA', ['GGTTaTA', 'GGTTbTA']],
#  ['TGGTTCT', ['TGGTTaT', 'TGGTTbT']],
#  ['GTGGTTC', ['GTGGTTb', 'GTGGTTa']],
#  ['ATGATGG', ['aTGATGG', 'bTGATGG']],
#  ['GATGATG', ['baTGATG', 'bbTGATG', 'abTGATG', 'aaTGATG']],
#  ['CGATGAT', ['CabTGAT', 'CbaTGAT', 'CbbTGAT', 'CaaTGAT']],
#  ['ACGATGA', ['ACbaTGA', 'ACaaTGA', 'ACabTGA', 'ACbbTGA']],
#  ['AACGATG', ['AACbbTG', 'AACabTG', 'AACbaTG', 'AACaaTG']],
#  ['AAACGAT', ['AAACbaT', 'AAACbbT', 'AAACaaT', 'AAACabT']],
#  ['TAAACGA', ['TAAACbb', 'TAAACaa', 'TAAACba', 'TAAACab']],
#  ['GATGATG', ['baTGATG', 'bbTGATG', 'abTGATG', 'aaTGATG']],
#  ['CGATGAT', ['CabTGAT', 'CbaTGAT', 'CbbTGAT', 'CaaTGAT']],
#  ['ACGATGA', ['ACbaTGA', 'ACaaTGA', 'ACabTGA', 'ACbbTGA']],
#  ['AACGATG', ['AACbbTG', 'AACabTG', 'AACbaTG', 'AACaaTG']],
#  ['AAACGAT', ['AAACbaT', 'AAACbbT', 'AAACaaT', 'AAACabT']],
#  ['TAAACGA', ['TAAACbb', 'TAAACaa', 'TAAACba', 'TAAACab']],
#  ['ATAAACG', ['ATAAACa', 'ATAAACb']],
#  ['TAATAAG', ['aAATAAG', 'bAATAAG']],
#  ['GTAATAA', ['GbAATAA', 'GaAATAA']],
#  ['TGTAATA', ['TGbAATA', 'TGaAATA']],
#  ['ATGTAAT', ['ATGbAAT', 'ATGaAAT']],
#  ['GATGTAA', ['GATGaAA', 'GATGbAA']],
#  ['AGATGTA', ['AGATGbA', 'AGATGaA']],
#  ['TAGATGT', ['TAGATGa', 'TAGATGb']],
#  ['TCTAAGG', ['aCTAAGG', 'bCTAAGG']],
#  ['GTCTAAG', ['GbCTAAG', 'GaCTAAG']],
#  ['AGTCTAA', ['AGaCTAA', 'AGbCTAA']],
#  ['CAGTCTA', ['CAGbCTA', 'CAGaCTA']],
#  ['TCAGTCT', ['aCAGaCT', 'bCAGaCT', 'bCAGbCT', 'aCAGbCT']],
#  ['GTCAGTC', ['GaCAGaC', 'GbCAGaC', 'GbCAGbC', 'GaCAGbC']],
#  ['TGTCAGT', ['TGbCAGb', 'TGaCAGb', 'TGbCAGa', 'TGaCAGa']],
#  ['TCAGTCT', ['aCAGaCT', 'bCAGaCT', 'bCAGbCT', 'aCAGbCT']],
#  ['GTCAGTC', ['GaCAGaC', 'GbCAGaC', 'GbCAGbC', 'GaCAGbC']],
#  ['TGTCAGT', ['TGbCAGb', 'TGaCAGb', 'TGbCAGa', 'TGaCAGa']],
#  ['CTGTCAG', ['CTGbCAG', 'CTGaCAG']],
#  ['TCTGTCA', ['TCTGaCA', 'TCTGbCA']],
#  ['ATCTGTC', ['ATCTGbC', 'ATCTGaC']],
#  ['AATCTGT', ['AATCTGa', 'AATCTGb']],
#  ['ATTAATC', ['bTTAATC', 'aTTAATC']],
#  ['AATTAAT', ['AaTTAAT', 'AbTTAAT']],
#  ['AAATTAA', ['AAbTTAA', 'AAaTTAA']],
#  ['AAAATTA', ['AAAbTTA', 'AAAaTTA']],
#  ['CAAAATT', ['CAAAaTT', 'CAAAbTT']],
#  ['ACAAAAT', ['ACAAAaT', 'ACAAAbT']],
#  ['TACAAAA', ['TACAAAb', 'TACAAAa']],
#  ['TTTAGTG', ['aTTAGTG', 'bTTAGTG']],
#  ['CTTTAGT', ['CaTTAGT', 'CbTTAGT']],
#  ['TCTTTAG', ['TCbTTAG', 'TCaTTAG']],
#  ['GTCTTTA', ['GTCaTTA', 'GTCbTTA']],
#  ['CGTCTTT', ['CGTCaTT', 'CGTCbTT']],
#  ['CCGTCTT', ['CCGTCaT', 'CCGTCbT']],
#  ['CCCGTCT', ['aCCGTCa', 'bCCGTCa', 'bCCGTCb', 'aCCGTCb']],
#  ['CCCGTCT', ['aCCGTCa', 'bCCGTCa', 'bCCGTCb', 'aCCGTCb']],
#  ['ACCCGTC', ['AbCCGTC', 'AaCCGTC']],
#  ['GACCCGT', ['GAbCCGT', 'GAaCCGT']],
#  ['TGACCCG', ['TGAbCCG', 'TGAaCCG']],
#  ['GTGACCC', ['GTGAbCC', 'GTGAaCC']],
#  ['CGTGACC', ['CGTGAbC', 'CGTGAaC']],
#  ['TCGTGAC', ['TCGTGAa', 'TCGTGAb']],
#  ['AAGTGAA', ['aAGTGAA', 'bAGTGAA']],
#  ['GAAGTGA', ['GaAGTGA', 'GbAGTGA']],
#  ['AGAAGTG', ['AGbAGTG', 'AGaAGTG']],
#  ['AAGAAGT', ['AAGbAGT', 'AAGaAGT']],
#  ['AAAGAAG', ['AAAGaAG', 'AAAGbAG']],
#  ['TAAAGAA', ['TAAAGbA', 'TAAAGaA']],
#  ['TTAAAGA', ['TTAAAGa', 'TTAAAGb']],
#  ['AATGAGG', ['aATGAGG', 'bATGAGG']],
#  ['CAATGAG', ['CbATGAG', 'CaATGAG']],
#  ['TCAATGA', ['aCbATGA', 'aCaATGA', 'bCbATGA', 'bCaATGA']],
#  ['ATCAATG', ['AbCaATG', 'AaCbATG', 'AbCbATG', 'AaCaATG']],
#  ['TATCAAT',
#   ['bAaCaAT',
#    'aAbCaAT',
#    'aAaCbAT',
#    'bAbCbAT',
#    'bAaCbAT',
#    'aAbCbAT',
#    'aAaCaAT',
#    'bAbCaAT']],
#  ['GTATCAA',
#   ['GaAbCbA',
#    'GbAaCbA',
#    'GaAaCbA',
#    'GbAbCbA',
#    'GaAaCaA',
#    'GbAbCaA',
#    'GaAbCaA',
#    'GbAaCaA']],
#  ['AGTATCA',
#   ['AGaAbCa',
#    'AGaAaCb',
#    'AGaAaCa',
#    'AGbAaCa',
#    'AGaAbCb',
#    'AGbAaCb',
#    'AGbAbCa',
#    'AGbAbCb']],
#  ['TCAATGA', ['aCbATGA', 'aCaATGA', 'bCbATGA', 'bCaATGA']],
#  ['ATCAATG', ['AbCaATG', 'AaCbATG', 'AbCbATG', 'AaCaATG']],
#  ['TATCAAT',
#   ['bAaCaAT',
#    'aAbCaAT',
#    'aAaCbAT',
#    'bAbCbAT',
#    'bAaCbAT',
#    'aAbCbAT',
#    'aAaCaAT',
#    'bAbCaAT']],
#  ['GTATCAA',
#   ['GaAbCbA',
#    'GbAaCbA',
#    'GaAaCbA',
#    'GbAbCbA',
#    'GaAaCaA',
#    'GbAbCaA',
#    'GaAbCaA',
#    'GbAaCaA']],
#  ['AGTATCA',
#   ['AGaAbCa',
#    'AGaAaCb',
#    'AGaAaCa',
#    'AGbAaCa',
#    'AGaAbCb',
#    'AGbAaCb',
#    'AGbAbCa',
#    'AGbAbCb']],
#  ['CAGTATC', ['CAGaAbC', 'CAGbAbC', 'CAGaAaC', 'CAGbAaC']],
#  ['TCAGTAT',
#   ['aCAGbAb',
#    'aCAGaAb',
#    'aCAGaAa',
#    'bCAGbAa',
#    'bCAGaAa',
#    'bCAGaAb',
#    'aCAGbAa',
#    'bCAGbAb']],
#  ['TATCAAT',
#   ['bAaCaAT',
#    'aAbCaAT',
#    'aAaCbAT',
#    'bAbCbAT',
#    'bAaCbAT',
#    'aAbCbAT',
#    'aAaCaAT',
#    'bAbCaAT']],
#  ['GTATCAA',
#   ['GaAbCbA',
#    'GbAaCbA',
#    'GaAaCbA',
#    'GbAbCbA',
#    'GaAaCaA',
#    'GbAbCaA',
#    'GaAbCaA',
#    'GbAaCaA']],
#  ['AGTATCA',
#   ['AGaAbCa',
#    'AGaAaCb',
#    'AGaAaCa',
#    'AGbAaCa',
#    'AGaAbCb',
#    'AGbAaCb',
#    'AGbAbCa',
#    'AGbAbCb']],
#  ['CAGTATC', ['CAGaAbC', 'CAGbAbC', 'CAGaAaC', 'CAGbAaC']],
#  ['TCAGTAT',
#   ['aCAGbAb',
#    'aCAGaAb',
#    'aCAGaAa',
#    'bCAGbAa',
#    'bCAGaAa',
#    'bCAGaAb',
#    'aCAGbAa',
#    'bCAGbAb']],
#  ['CTCAGTA', ['CbCAGaA', 'CaCAGbA', 'CaCAGaA', 'CbCAGbA']],
#  ['TCTCAGT',
#   ['bCbCAGa',
#    'bCaCAGa',
#    'bCbCAGb',
#    'aCbCAGb',
#    'aCbCAGa',
#    'aCaCAGb',
#    'bCaCAGb',
#    'aCaCAGa']],
#  ['TCAGTAT',
#   ['aCAGbAb',
#    'aCAGaAb',
#    'aCAGaAa',
#    'bCAGbAa',
#    'bCAGaAa',
#    'bCAGaAb',
#    'aCAGbAa',
#    'bCAGbAb']],
#  ['CTCAGTA', ['CbCAGaA', 'CaCAGbA', 'CaCAGaA', 'CbCAGbA']],
#  ['TCTCAGT',
#   ['bCbCAGa',
#    'bCaCAGa',
#    'bCbCAGb',
#    'aCbCAGb',
#    'aCbCAGa',
#    'aCaCAGb',
#    'bCaCAGb',
#    'aCaCAGa']],
#  ['CTCTCAG', ['CaCaCAG', 'CaCbCAG', 'CbCaCAG', 'CbCbCAG']],
#  ['TCTCTCA', ['TCaCaCA', 'TCbCbCA', 'TCbCaCA', 'TCaCbCA']],
#  ['TTCTCTC', ['TTCaCaC', 'TTCaCbC', 'TTCbCaC', 'TTCbCbC']],
#  ['ATTCTCT', ['ATTCbCa', 'ATTCaCb', 'ATTCbCb', 'ATTCaCa']],
#  ['TCTCAGT',
#   ['bCbCAGa',
#    'bCaCAGa',
#    'bCbCAGb',
#    'aCbCAGb',
#    'aCbCAGa',
#    'aCaCAGb',
#    'bCaCAGb',
#    'aCaCAGa']],
#  ['CTCTCAG', ['CaCaCAG', 'CaCbCAG', 'CbCaCAG', 'CbCbCAG']],
#  ['TCTCTCA', ['TCaCaCA', 'TCbCbCA', 'TCbCaCA', 'TCaCbCA']],
#  ['TTCTCTC', ['TTCaCaC', 'TTCaCbC', 'TTCbCaC', 'TTCbCbC']],
#  ['ATTCTCT', ['ATTCbCa', 'ATTCaCb', 'ATTCbCb', 'ATTCaCa']],
#  ['AATTCTC', ['AATTCbC', 'AATTCaC']],
#  ['GAATTCT', ['GAATTCa', 'GAATTCb']],
#  ['CCGATGG', ['aCGATGG', 'bCGATGG']],
#  ['ACCGATG', ['AbCGATG', 'AaCGATG']],
#  ['AACCGAT', ['aAaCGAT', 'bAbCGAT', 'bAaCGAT', 'aAbCGAT']],
#  ['AAACCGA',
#   ['bbAaCGA',
#    'baAaCGA',
#    'aaAaCGA',
#    'abAbCGA',
#    'abAaCGA',
#    'baAbCGA',
#    'bbAbCGA',
#    'aaAbCGA']],
#  ['TAAACCG',
#   ['TabAbCG',
#    'TaaAaCG',
#    'TbaAaCG',
#    'TbbAbCG',
#    'TbbAaCG',
#    'TabAaCG',
#    'TaaAbCG',
#    'TbaAbCG']],
#  ['GTAAACC',
#   ['GTbbAbC',
#    'GTbaAbC',
#    'GTaaAbC',
#    'GTaaAaC',
#    'GTabAaC',
#    'GTbbAaC',
#    'GTabAbC',
#    'GTbaAaC']],
#  ['CGTAAAC',
#   ['CGTaaAb',
#    'CGTbaAa',
#    'CGTbbAb',
#    'CGTabAb',
#    'CGTbaAb',
#    'CGTabAa',
#    'CGTaaAa',
#    'CGTbbAa']],
#  ['AACCGAT', ['aAaCGAT', 'bAbCGAT', 'bAaCGAT', 'aAbCGAT']],
#  ['AAACCGA',
#   ['bbAaCGA',
#    'baAaCGA',
#    'aaAaCGA',
#    'abAbCGA',
#    'abAaCGA',
#    'baAbCGA',
#    'bbAbCGA',
#    'aaAbCGA']],
#  ['TAAACCG',
#   ['TabAbCG',
#    'TaaAaCG',
#    'TbaAaCG',
#    'TbbAbCG',
#    'TbbAaCG',
#    'TabAaCG',
#    'TaaAbCG',
#    'TbaAbCG']],
#  ['GTAAACC',
#   ['GTbbAbC',
#    'GTbaAbC',
#    'GTaaAbC',
#    'GTaaAaC',
#    'GTabAaC',
#    'GTbbAaC',
#    'GTabAbC',
#    'GTbaAaC']],
#  ['CGTAAAC',
#   ['CGTaaAb',
#    'CGTbaAa',
#    'CGTbbAb',
#    'CGTabAb',
#    'CGTbaAb',
#    'CGTabAa',
#    'CGTaaAa',
#    'CGTbbAa']],
#  ['CCGTAAA', ['CCGTaaA', 'CCGTabA', 'CCGTbaA', 'CCGTbbA']],
#  ['TCCGTAA', ['TCCGTba', 'TCCGTaa', 'TCCGTab', 'TCCGTbb']],
#  ['AAACCGA',
#   ['bbAaCGA',
#    'baAaCGA',
#    'aaAaCGA',
#    'abAbCGA',
#    'abAaCGA',
#    'baAbCGA',
#    'bbAbCGA',
#    'aaAbCGA']],
#  ['TAAACCG',
#   ['TabAbCG',
#    'TaaAaCG',
#    'TbaAaCG',
#    'TbbAbCG',
#    'TbbAaCG',
#    'TabAaCG',
#    'TaaAbCG',
#    'TbaAbCG']],
#  ['GTAAACC',
#   ['GTbbAbC',
#    'GTbaAbC',
#    'GTaaAbC',
#    'GTaaAaC',
#    'GTabAaC',
#    'GTbbAaC',
#    'GTabAbC',
#    'GTbaAaC']],
#  ['CGTAAAC',
#   ['CGTaaAb',
#    'CGTbaAa',
#    'CGTbbAb',
#    'CGTabAb',
#    'CGTbaAb',
#    'CGTabAa',
#    'CGTaaAa',
#    'CGTbbAa']],
#  ['CCGTAAA', ['CCGTaaA', 'CCGTabA', 'CCGTbaA', 'CCGTbbA']],
#  ['TCCGTAA', ['TCCGTba', 'TCCGTaa', 'TCCGTab', 'TCCGTbb']],
#  ['CTCCGTA', ['CTCCGTb', 'CTCCGTa']],
#  ['GCTCCGT', ['bCTCCGT', 'aCTCCGT']],
#  ['TGCTCCG', ['TbCTCCG', 'TaCTCCG']],
#  ['CTGCTCC', ['CTaCTCC', 'CTbCTCC']],
#  ['ACTGCTC', ['ACTbCTC', 'ACTaCTC']],
#  ['TACTGCT', ['TACTbCT', 'TACTaCT']],
#  ['CTACTGC', ['CTACTbC', 'CTACTaC']],
#  ['TCTACTG', ['TCTACTb', 'TCTACTa']],
#  ['TAAGTAC', ['aAAGTAC', 'bAAGTAC']],
#  ['GTAAGTA', ['GbAAGTA', 'GaAAGTA']],
#  ['GGTAAGT', ['GGaAAGT', 'GGbAAGT']],
#  ['AGGTAAG', ['AGGaAAG', 'AGGbAAG']],
#  ['TAGGTAA', ['TAGGaAA', 'TAGGbAA']],
#  ['TTAGGTA', ['TTAGGaA', 'TTAGGbA']],
#  ['ATTAGGT', ['ATTAGGb', 'ATTAGGa']],
#  ['CTGTCAC', ['bTGTCAC', 'aTGTCAC']],
#  ['CCTGTCA', ['CbTGTCA', 'CaTGTCA']],
#  ['CCCTGTC', ['CCaTGTC', 'CCbTGTC']],
#  ['TCCCTGT', ['aCCbTGT', 'aCCaTGT', 'bCCaTGT', 'bCCbTGT']],
#  ['ATCCCTG', ['AbCCaTG', 'AbCCbTG', 'AaCCaTG', 'AaCCbTG']],
#  ['TATCCCT', ['TAaCCbT', 'TAbCCbT', 'TAaCCaT', 'TAbCCaT']],
#  ['CTATCCC', ['CTAaCCa', 'CTAbCCa', 'CTAaCCb', 'CTAbCCb']],
#  ['TCCCTGT', ['aCCbTGT', 'aCCaTGT', 'bCCaTGT', 'bCCbTGT']],
#  ['ATCCCTG', ['AbCCaTG', 'AbCCbTG', 'AaCCaTG', 'AaCCbTG']],
#  ['TATCCCT', ['TAaCCbT', 'TAbCCbT', 'TAaCCaT', 'TAbCCaT']],
#  ['CTATCCC', ['CTAaCCa', 'CTAbCCa', 'CTAaCCb', 'CTAbCCb']],
#  ['TCTATCC', ['TCTAaCC', 'TCTAbCC']],
#  ['ATCTATC', ['ATCTAbC', 'ATCTAaC']],
#  ['CATCTAT', ['CATCTAb', 'CATCTAa']],
#  ['TCATCTA', ['aCATCTA', 'bCATCTA']],
#  ['ATCATCT', ['AbCATCT', 'AaCATCT']],
#  ['TATCATC', ['aAbCATC', 'bAbCATC', 'aAaCATC', 'bAaCATC']],
#  ['CTATCAT', ['CaAaCAT', 'CaAbCAT', 'CbAaCAT', 'CbAbCAT']],
#  ['TCTATCA',
#   ['bCaAaCA',
#    'bCbAaCA',
#    'aCbAaCA',
#    'bCbAbCA',
#    'aCaAbCA',
#    'bCaAbCA',
#    'aCbAbCA',
#    'aCaAaCA']],
#  ['ATCTATC',
#   ['AaCaAaC',
#    'AbCaAaC',
#    'AbCaAbC',
#    'AbCbAbC',
#    'AaCbAbC',
#    'AbCbAaC',
#    'AaCbAaC',
#    'AaCaAbC']],
#  ['GATCTAT',
#   ['GAbCbAa',
#    'GAbCaAa',
#    'GAaCaAb',
#    'GAaCbAa',
#    'GAbCbAb',
#    'GAaCaAa',
#    'GAbCaAb',
#    'GAaCbAb']],
#  ['TATCATC', ['aAbCATC', 'bAbCATC', 'aAaCATC', 'bAaCATC']],
#  ['CTATCAT', ['CaAaCAT', 'CaAbCAT', 'CbAaCAT', 'CbAbCAT']],
#  ['TCTATCA',
#   ['bCaAaCA',
#    'bCbAaCA',
#    'aCbAaCA',
#    'bCbAbCA',
#    'aCaAbCA',
#    'bCaAbCA',
#    'aCbAbCA',
#    'aCaAaCA']],
#  ['ATCTATC',
#   ['AaCaAaC',
#    'AbCaAaC',
#    'AbCaAbC',
#    'AbCbAbC',
#    'AaCbAbC',
#    'AbCbAaC',
#    'AaCbAaC',
#    'AaCaAbC']],
#  ['GATCTAT',
#   ['GAbCbAa',
#    'GAbCaAa',
#    'GAaCaAb',
#    'GAaCbAa',
#    'GAbCbAb',
#    'GAaCaAa',
#    'GAbCaAb',
#    'GAaCbAb']],
#  ['CGATCTA', ['CGAbCbA', 'CGAaCbA', 'CGAaCaA', 'CGAbCaA']],
#  ['GCGATCT', ['GCGAbCb', 'GCGAaCb', 'GCGAaCa', 'GCGAbCa']],
#  ['TCTATCA',
#   ['bCaAaCA',
#    'bCbAaCA',
#    'aCbAaCA',
#    'bCbAbCA',
#    'aCaAbCA',
#    'bCaAbCA',
#    'aCbAbCA',
#    'aCaAaCA']],
#  ['ATCTATC',
#   ['AaCaAaC',
#    'AbCaAaC',
#    'AbCaAbC',
#    'AbCbAbC',
#    'AaCbAbC',
#    'AbCbAaC',
#    'AaCbAaC',
#    'AaCaAbC']],
#  ['GATCTAT',
#   ['GAbCbAa',
#    'GAbCaAa',
#    'GAaCaAb',
#    'GAaCbAa',
#    'GAbCbAb',
#    'GAaCaAa',
#    'GAbCaAb',
#    'GAaCbAb']],
#  ['CGATCTA', ['CGAbCbA', 'CGAaCbA', 'CGAaCaA', 'CGAbCaA']],
#  ['GCGATCT', ['GCGAbCb', 'GCGAaCb', 'GCGAaCa', 'GCGAbCa']],
#  ['AGCGATC', ['AGCGAbC', 'AGCGAaC']],
#  ['AAGCGAT', ['AAGCGAa', 'AAGCGAb']],
#  ['TCGAGTT', ['bCGAGTT', 'aCGAGTT']],
#  ['TTCGAGT', ['baCGAGT', 'abCGAGT', 'bbCGAGT', 'aaCGAGT']],
#  ['GTTCGAG', ['GbaCGAG', 'GbbCGAG', 'GaaCGAG', 'GabCGAG']],
#  ['AGTTCGA', ['AGbaCGA', 'AGabCGA', 'AGbbCGA', 'AGaaCGA']],
#  ['CAGTTCG', ['CAGabCG', 'CAGbbCG', 'CAGbaCG', 'CAGaaCG']],
#  ['TCAGTTC',
#   ['aCAGaaC',
#    'bCAGabC',
#    'aCAGbbC',
#    'bCAGaaC',
#    'aCAGbaC',
#    'aCAGabC',
#    'bCAGbbC',
#    'bCAGbaC']],
#  ['CTCAGTT',
#   ['CaCAGab',
#    'CbCAGab',
#    'CaCAGaa',
#    'CbCAGbb',
#    'CbCAGba',
#    'CaCAGbb',
#    'CaCAGba',
#    'CbCAGaa']],
#  ['TTCGAGT', ['baCGAGT', 'abCGAGT', 'bbCGAGT', 'aaCGAGT']],
#  ['GTTCGAG', ['GbaCGAG', 'GbbCGAG', 'GaaCGAG', 'GabCGAG']],
#  ['AGTTCGA', ['AGbaCGA', 'AGabCGA', 'AGbbCGA', 'AGaaCGA']],
#  ['CAGTTCG', ['CAGabCG', 'CAGbbCG', 'CAGbaCG', 'CAGaaCG']],
#  ['TCAGTTC',
#   ['aCAGaaC',
#    'bCAGabC',
#    'aCAGbbC',
#    'bCAGaaC',
#    'aCAGbaC',
#    'aCAGabC',
#    'bCAGbbC',
#    'bCAGbaC']],
#  ['CTCAGTT',
#   ['CaCAGab',
#    'CbCAGab',
#    'CaCAGaa',
#    'CbCAGbb',
#    'CbCAGba',
#    'CaCAGbb',
#    'CaCAGba',
#    'CbCAGaa']],
#  ['TCTCAGT', ['TCaCAGa', 'TCbCAGa', 'TCbCAGb', 'TCaCAGb']],
#  ['TCAGTTC',
#   ['aCAGaaC',
#    'bCAGabC',
#    'aCAGbbC',
#    'bCAGaaC',
#    'aCAGbaC',
#    'aCAGabC',
#    'bCAGbbC',
#    'bCAGbaC']],
#  ['CTCAGTT',
#   ['CaCAGab',
#    'CbCAGab',
#    'CaCAGaa',
#    'CbCAGbb',
#    'CbCAGba',
#    'CaCAGbb',
#    'CaCAGba',
#    'CbCAGaa']],
#  ['TCTCAGT', ['TCaCAGa', 'TCbCAGa', 'TCbCAGb', 'TCaCAGb']],
#  ['ATCTCAG', ['ATCbCAG', 'ATCaCAG']],
#  ['GATCTCA', ['GATCbCA', 'GATCaCA']],
#  ['TGATCTC', ['TGATCbC', 'TGATCaC']],
#  ['TTGATCT', ['TTGATCa', 'TTGATCb']],
#  ['GGTCGGT', ['aGTCGGT', 'bGTCGGT']],
#  ['GGGTCGG', ['GaGTCGG', 'GbGTCGG']],
#  ['GGGGTCG', ['GGaGTCG', 'GGbGTCG']],
#  ['CGGGGTC', ['CGGaGTC', 'CGGbGTC']],
#  ['GCGGGGT', ['GCGGbGT', 'GCGGaGT']],
#  ['GGCGGGG', ['GGCGGaG', 'GGCGGbG']],
#  ['CGGCGGG', ['CGGCGGb', 'CGGCGGa']],
#  ['TTGTCTA', ['aTGTCTA', 'bTGTCTA']],
#  ['ATTGTCT', ['AbTGTCT', 'AaTGTCT']],
#  ['AATTGTC', ['AAbTGTC', 'AAaTGTC']],
#  ['AAATTGT', ['AAAaTGT', 'AAAbTGT']],
#  ['CAAATTG', ['CAAAaTG', 'CAAAbTG']],
#  ['GCAAATT', ['GCAAAaT', 'GCAAAbT']],
#  ['AGCAAAT', ['aGCAAAa', 'aGCAAAb', 'bGCAAAa', 'bGCAAAb']],
#  ['AGCAAAT', ['aGCAAAa', 'aGCAAAb', 'bGCAAAa', 'bGCAAAb']],
#  ['TAGCAAA', ['TbGCAAA', 'TaGCAAA']],
#  ['ATAGCAA', ['ATbGCAA', 'ATaGCAA']],
#  ['AATAGCA', ['AATbGCA', 'AATaGCA']],
#  ['CAATAGC', ['CAATbGC', 'CAATaGC']],
#  ['GCAATAG', ['GCAATbG', 'GCAATaG']],
#  ['CGCAATA', ['CGCAATa', 'CGCAATb']],
#  ['TTTAGTT', ['bTTAGTT', 'aTTAGTT']],
#  ['TTTTAGT', ['TbTTAGT', 'TaTTAGT']],
#  ['CTTTTAG', ['CTbTTAG', 'CTaTTAG']],
#  ['ACTTTTA', ['ACTaTTA', 'ACTbTTA']],
#  ['GACTTTT', ['GACTbTT', 'GACTaTT']],
#  ['TGACTTT', ['aGACTaT', 'bGACTaT', 'aGACTbT', 'bGACTbT']],
#  ['GTGACTT', ['GbGACTa', 'GaGACTb', 'GbGACTb', 'GaGACTa']],
#  ['TGACTTT', ['aGACTaT', 'bGACTaT', 'aGACTbT', 'bGACTbT']],
#  ['GTGACTT', ['GbGACTa', 'GaGACTb', 'GbGACTb', 'GaGACTa']],
#  ['TGTGACT', ['TGaGACT', 'TGbGACT']],
#  ['GTGTGAC', ['GTGaGAC', 'GTGbGAC']],
#  ['AGTGTGA', ['AGTGbGA', 'AGTGaGA']],
#  ['AAGTGTG', ['AAGTGaG', 'AAGTGbG']],
#  ['TAAGTGT', ['bAAGTGb', 'bAAGTGa', 'aAAGTGb', 'aAAGTGa']],
#  ['TAAGTGT', ['bAAGTGb', 'bAAGTGa', 'aAAGTGb', 'aAAGTGa']],
#  ['ATAAGTG', ['AaAAGTG', 'AbAAGTG']],
#  ['CATAAGT', ['CAaAAGT', 'CAbAAGT']],
#  ['ACATAAG', ['ACAaAAG', 'ACAbAAG']],
#  ['AACATAA', ['AACAaAA', 'AACAbAA']],
#  ['AAACATA', ['AAACAaA', 'AAACAbA']],
#  ['CAAACAT', ['CAAACAb', 'CAAACAa']],
#  ['GATCGGA', ['bATCGGA', 'aATCGGA']],
#  ['AGATCGG', ['AbATCGG', 'AaATCGG']],
#  ['GAGATCG', ['bAaATCG', 'aAbATCG', 'bAbATCG', 'aAaATCG']],
#  ['GGAGATC', ['GbAbATC', 'GaAaATC', 'GbAaATC', 'GaAbATC']],
#  ['TGGAGAT', ['TGbAaAT', 'TGaAbAT', 'TGaAaAT', 'TGbAbAT']],
#  ['GTGGAGA', ['GTGaAaA', 'GTGbAaA', 'GTGaAbA', 'GTGbAbA']],
#  ['CGTGGAG', ['CGTGbAa', 'CGTGbAb', 'CGTGaAb', 'CGTGaAa']],
#  ['GAGATCG', ['bAaATCG', 'aAbATCG', 'bAbATCG', 'aAaATCG']],
#  ['GGAGATC', ['GbAbATC', 'GaAaATC', 'GbAaATC', 'GaAbATC']],
#  ['TGGAGAT', ['TGbAaAT', 'TGaAbAT', 'TGaAaAT', 'TGbAbAT']],
#  ['GTGGAGA', ['GTGaAaA', 'GTGbAaA', 'GTGaAbA', 'GTGbAbA']],
#  ['CGTGGAG', ['CGTGbAa', 'CGTGbAb', 'CGTGaAb', 'CGTGaAa']],
#  ['CCGTGGA', ['CCGTGaA', 'CCGTGbA']],
#  ['ACCGTGG', ['ACCGTGb', 'ACCGTGa']],
#  ['GGACACC', ['aGACACC', 'bGACACC']],
#  ['GGGACAC', ['GaGACAC', 'GbGACAC']],
#  ['AGGGACA', ['AGaGACA', 'AGbGACA']],
#  ['TAGGGAC', ['TAGaGAC', 'TAGbGAC']],
#  ['ATAGGGA', ['ATAGbGA', 'ATAGaGA']],
#  ['AATAGGG', ['AATAGaG', 'AATAGbG']],
#  ['CAATAGG', ['CAATAGb', 'CAATAGa']],
#  ['TCGGTCA', ['aCGGTCA', 'bCGGTCA']],
#  ['TTCGGTC', ['TaCGGTC', 'TbCGGTC']],
#  ['GTTCGGT', ['GTbCGGT', 'GTaCGGT']],
#  ['TGTTCGG', ['TGTaCGG', 'TGTbCGG']],
#  ['GTGTTCG', ['GTGTbCG', 'GTGTaCG']],
#  ['GGTGTTC', ['GGTGTaC', 'GGTGTbC']],
#  ['CGGTGTT', ['CGGTGTb', 'CGGTGTa']],
#  ['TTGCGAA', ['aTGCGAA', 'bTGCGAA']],
#  ['CTTGCGA', ['CaTGCGA', 'CbTGCGA']],
#  ['ACTTGCG', ['ACaTGCG', 'ACbTGCG']],
#  ['TACTTGC', ['TACaTGC', 'TACbTGC']],
#  ['ATACTTG', ['ATACbTG', 'ATACaTG']],
#  ['GATACTT', ['GATACbT', 'GATACaT']],
#  ['CGATACT', ['CGATACb', 'CGATACa']],
#  ['TAGTTTT', ['bAGTTTT', 'aAGTTTT']],
#  ['TTAGTTT', ['TbAGTTT', 'TaAGTTT']],
#  ['CTTAGTT', ['CTbAGTT', 'CTaAGTT']],
#  ['TCTTAGT', ['TCTaAGT', 'TCTbAGT']],
#  ['TTCTTAG', ['TTCTbAG', 'TTCTaAG']],
#  ['CTTCTTA', ['bTTCTbA', 'aTTCTbA', 'bTTCTaA', 'aTTCTaA']],
#  ['GCTTCTT', ['GbTTCTa', 'GaTTCTb', 'GaTTCTa', 'GbTTCTb']],
#  ['CTTCTTA', ['bTTCTbA', 'aTTCTbA', 'bTTCTaA', 'aTTCTaA']],
#  ['GCTTCTT', ['GbTTCTa', 'GaTTCTb', 'GaTTCTa', 'GbTTCTb']],
#  ['AGCTTCT', ['AGbTTCT', 'AGaTTCT']],
#  ['TAGCTTC', ['TAGaTTC', 'TAGbTTC']],
#  ['GTAGCTT', ['GTAGbTT', 'GTAGaTT']],
#  ['TGTAGCT', ['TGTAGaT', 'TGTAGbT']],
#  ['CTGTAGC', ['CTGTAGa', 'CTGTAGb']],
#  ['TCGGCTG', ['aCGGCTG', 'bCGGCTG']],
#  ['CTCGGCT', ['CbCGGCT', 'CaCGGCT']],
#  ['TCTCGGC', ['TCbCGGC', 'TCaCGGC']],
#  ['TTCTCGG', ['TTCaCGG', 'TTCbCGG']],
#  ['CTTCTCG', ['CTTCaCG', 'CTTCbCG']],
#  ['CCTTCTC', ['CCTTCbC', 'CCTTCaC']],
#  ['TCCTTCT', ['TCCTTCa', 'TCCTTCb']],
#  ['TTAGGTT', ['aTAGGTT', 'bTAGGTT']],
#  ['GTTAGGT', ['bbTAGGT', 'baTAGGT', 'aaTAGGT', 'abTAGGT']],
#  ['TGTTAGG',
#   ['baaTAGG',
#    'bbbTAGG',
#    'babTAGG',
#    'aaaTAGG',
#    'abaTAGG',
#    'bbaTAGG',
#    'abbTAGG',
#    'aabTAGG']],
#  ['TTGTTAG',
#   ['TabbTAG',
#    'TabaTAG',
#    'TaabTAG',
#    'TaaaTAG',
#    'TbbaTAG',
#    'TbbbTAG',
#    'TbabTAG',
#    'TbaaTAG']],
#  ['CTTGTTA',
#   ['CTabbTA',
#    'CTaabTA',
#    'CTabaTA',
#    'CTbaaTA',
#    'CTbabTA',
#    'CTaaaTA',
#    'CTbbaTA',
#    'CTbbbTA']],
#  ['ACTTGTT',
#   ['ACTbbbT',
#    'ACTbaaT',
#    'ACTabaT',
#    'ACTabbT',
#    'ACTbabT',
#    'ACTaaaT',
#    'ACTaabT',
#    'ACTbbaT']],
#  ['CACTTGT',
#   ['CACTbbb',
#    'CACTabb',
#    'CACTbba',
#    'CACTaaa',
#    'CACTaba',
#    'CACTaab',
#    'CACTbab',
#    'CACTbaa']],
#  ['GTTAGGT', ['bbTAGGT', 'baTAGGT', 'aaTAGGT', 'abTAGGT']],
#  ['TGTTAGG',
#   ['baaTAGG',
#    'bbbTAGG',
#    'babTAGG',
#    'aaaTAGG',
#    'abaTAGG',
#    'bbaTAGG',
#    'abbTAGG',
#    'aabTAGG']],
#  ['TTGTTAG',
#   ['TabbTAG',
#    'TabaTAG',
#    'TaabTAG',
#    'TaaaTAG',
#    'TbbaTAG',
#    'TbbbTAG',
#    'TbabTAG',
#    'TbaaTAG']],
#  ['CTTGTTA',
#   ['CTabbTA',
#    'CTaabTA',
#    'CTabaTA',
#    'CTbaaTA',
#    'CTbabTA',
#    'CTaaaTA',
#    'CTbbaTA',
#    'CTbbbTA']],
#  ['ACTTGTT',
#   ['ACTbbbT',
#    'ACTbaaT',
#    'ACTabaT',
#    'ACTabbT',
#    'ACTbabT',
#    'ACTaaaT',
#    'ACTaabT',
#    'ACTbbaT']],
#  ['CACTTGT',
#   ['CACTbbb',
#    'CACTabb',
#    'CACTbba',
#    'CACTaaa',
#    'CACTaba',
#    'CACTaab',
#    'CACTbab',
#    'CACTbaa']],
#  ['CCACTTG', ['CCACTba', 'CCACTbb', 'CCACTab', 'CCACTaa']],
#  ['TGTTAGG',
#   ['baaTAGG',
#    'bbbTAGG',
#    'babTAGG',
#    'aaaTAGG',
#    'abaTAGG',
#    'bbaTAGG',
#    'abbTAGG',
#    'aabTAGG']],
#  ['TTGTTAG',
#   ['TabbTAG',
#    'TabaTAG',
#    'TaabTAG',
#    'TaaaTAG',
#    'TbbaTAG',
#    'TbbbTAG',
#    'TbabTAG',
#    'TbaaTAG']],
#  ['CTTGTTA',
#   ['CTabbTA',
#    'CTaabTA',
#    'CTabaTA',
#    'CTbaaTA',
#    'CTbabTA',
#    'CTaaaTA',
#    'CTbbaTA',
#    'CTbbbTA']],
#  ['ACTTGTT',
#   ['ACTbbbT',
#    'ACTbaaT',
#    'ACTabaT',
#    'ACTabbT',
#    'ACTbabT',
#    'ACTaaaT',
#    'ACTaabT',
#    'ACTbbaT']],
#  ['CACTTGT',
#   ['CACTbbb',
#    'CACTabb',
#    'CACTbba',
#    'CACTaaa',
#    'CACTaba',
#    'CACTaab',
#    'CACTbab',
#    'CACTbaa']],
#  ['CCACTTG', ['CCACTba', 'CCACTbb', 'CCACTab', 'CCACTaa']],
#  ['CCCACTT', ['CCCACTa', 'CCCACTb']],
#  ['TGCAAGG', ['bGCAAGG', 'aGCAAGG']],
#  ['GTGCAAG', ['GbGCAAG', 'GaGCAAG']],
#  ['AGTGCAA', ['aGaGCAA', 'aGbGCAA', 'bGbGCAA', 'bGaGCAA']],
#  ['GAGTGCA', ['GaGaGCA', 'GbGaGCA', 'GbGbGCA', 'GaGbGCA']],
#  ['CGAGTGC',
#   ['aGaGaGC',
#    'bGaGbGC',
#    'aGbGbGC',
#    'bGbGaGC',
#    'aGaGbGC',
#    'aGbGaGC',
#    'bGbGbGC',
#    'bGaGaGC']],
#  ['TCGAGTG',
#   ['TaGaGaG',
#    'TbGaGaG',
#    'TbGbGaG',
#    'TbGbGbG',
#    'TaGaGbG',
#    'TbGaGbG',
#    'TaGbGbG',
#    'TaGbGaG']],
#  ['GTCGAGT',
#   ['GTbGbGa',
#    'GTaGbGa',
#    'GTbGaGb',
#    'GTaGbGb',
#    'GTaGaGa',
#    'GTbGaGa',
#    'GTaGaGb',
#    'GTbGbGb']],
#  ['AGTGCAA', ['aGaGCAA', 'aGbGCAA', 'bGbGCAA', 'bGaGCAA']],
#  ['GAGTGCA', ['GaGaGCA', 'GbGaGCA', 'GbGbGCA', 'GaGbGCA']],
#  ['CGAGTGC',
#   ['aGaGaGC',
#    'bGaGbGC',
#    'aGbGbGC',
#    'bGbGaGC',
#    'aGaGbGC',
#    'aGbGaGC',
#    'bGbGbGC',
#    'bGaGaGC']],
#  ['TCGAGTG',
#   ['TaGaGaG',
#    'TbGaGaG',
#    'TbGbGaG',
#    'TbGbGbG',
#    'TaGaGbG',
#    'TbGaGbG',
#    'TaGbGbG',
#    'TaGbGaG']],
#  ['GTCGAGT',
#   ['GTbGbGa',
#    'GTaGbGa',
#    'GTbGaGb',
#    'GTaGbGb',
#    'GTaGaGa',
#    'GTbGaGa',
#    'GTaGaGb',
#    'GTbGbGb']],
#  ['GGTCGAG', ['GGTaGaG', 'GGTaGbG', 'GGTbGaG', 'GGTbGbG']],
#  ['GGGTCGA', ['GGGTbGa', 'GGGTaGa', 'GGGTbGb', 'GGGTaGb']],
#  ['CGAGTGC',
#   ['aGaGaGC',
#    'bGaGbGC',
#    'aGbGbGC',
#    'bGbGaGC',
#    'aGaGbGC',
#    'aGbGaGC',
#    'bGbGbGC',
#    'bGaGaGC']],
#  ['TCGAGTG',
#   ['TaGaGaG',
#    'TbGaGaG',
#    'TbGbGaG',
#    'TbGbGbG',
#    'TaGaGbG',
#    'TbGaGbG',
#    'TaGbGbG',
#    'TaGbGaG']],
#  ['GTCGAGT',
#   ['GTbGbGa',
#    'GTaGbGa',
#    'GTbGaGb',
#    'GTaGbGb',
#    'GTaGaGa',
#    'GTbGaGa',
#    'GTaGaGb',
#    'GTbGbGb']],
#  ['GGTCGAG', ['GGTaGaG', 'GGTaGbG', 'GGTbGaG', 'GGTbGbG']],
#  ['GGGTCGA', ['GGGTbGa', 'GGGTaGa', 'GGGTbGb', 'GGGTaGb']],
#  ['TGGGTCG', ['TGGGTbG', 'TGGGTaG']],
#  ['TTGGGTC', ['TTGGGTa', 'TTGGGTb']],
#  ['CAGATTT', ['bAGATTT', 'aAGATTT']],
#  ['CCAGATT', ['CbAGATT', 'CaAGATT']],
#  ['GCCAGAT', ['GCaAGAT', 'GCbAGAT']],
#  ['TGCCAGA', ['TGCaAGA', 'TGCbAGA']],
#  ['CTGCCAG', ['CTGCbAG', 'CTGCaAG']],
#  ['GCTGCCA', ['GCTGCaA', 'GCTGCbA']],
#  ['TGCTGCC', ['TGCTGCb', 'TGCTGCa']],
#  ['TTGGACA', ['bTGGACA', 'aTGGACA']],
#  ['ATTGGAC', ['AbTGGAC', 'AaTGGAC']],
#  ['GATTGGA', ['GAaTGGA', 'GAbTGGA']],
#  ['TGATTGG', ['TGAbTGG', 'TGAaTGG']],
#  ['TTGATTG', ['TTGAaTG', 'TTGAbTG']],
#  ['TTTGATT', ['TTTGAaT', 'TTTGAbT']],
#  ['TTTTGAT', ['TTTTGAa', 'TTTTGAb']]]
