# %% [markdown]
# ### Gaussian distribution testing
#
#
# #### Med vs mean kmer analysis
# * See how accuracy changes using mean vs median for kmer distributions
#
# #### min SD model analysis
# * see if having a minimum SD of 2 alters or improves accuracy

# %%
from rrna_analysis.multiple_model_accuracy import plot_accuracy_vs_delta_and_accuracy_over_time, preprocess_accuracy_csv, sort_dir             
from rrna_analysis.kmer_pos_mapping import KmerPosMapping
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os
from py3helpers.utils import list_dir
from signalalign.hiddenMarkovModel import HmmModel


mods_csv = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/mod_files/mod_file.csv"
reference = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/yeast_25S_18S.fa"
positions = "/Users/andrewbailey/CLionProjects/rrna_analysis/reference/mod_files/yeast_18S_25S_variants.positions"
kpm = KmerPosMapping(reference, positions, mods_csv)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
from py3helpers.utils import list_dir
mean_0 = "/Users/andrewbailey/CLionProjects/rrna_analysis/notebooks/rrna_data/rrna_kube_testing/supervised/gaussian_distribution_testing/train_500_test_500_prob_0.5_em_iterations_30_USE_MEDIAN_false_MIN_SD_0/testing_accuracy_csvs"    
mean_2 = "/Users/andrewbailey/CLionProjects/rrna_analysis/notebooks/rrna_data/rrna_kube_testing/supervised/gaussian_distribution_testing/train_500_test_500_prob_0.5_em_iterations_30_USE_MEDIAN_false_MIN_SD_2/testing_accuracy_csvs"    
med_0 = "/Users/andrewbailey/CLionProjects/rrna_analysis/notebooks/rrna_data/rrna_kube_testing/supervised/gaussian_distribution_testing/train_500_test_500_prob_0.5_em_iterations_30_USE_MEDIAN_true_MIN_SD_0/testing_accuracy_csvs"    
med_2 = "/Users/andrewbailey/CLionProjects/rrna_analysis/notebooks/rrna_data/rrna_kube_testing/supervised/gaussian_distribution_testing/train_500_test_500_prob_0.5_em_iterations_30_USE_MEDIAN_true_MIN_SD_2/testing_accuracy_csvs"    

mean_0 = [preprocess_accuracy_csv(x, kpm.subset_mod_data) for x in sort_dir(mean_0, "csv")]
mean_2 = [preprocess_accuracy_csv(x, kpm.subset_mod_data) for x in sort_dir(mean_2, "csv")]
med_0 = [preprocess_accuracy_csv(x, kpm.subset_mod_data) for x in sort_dir(med_0, "csv")]
med_2 = [preprocess_accuracy_csv(x, kpm.subset_mod_data) for x in sort_dir(med_2, "csv")]

# %%
# %matplotlib notebook
# 1000 - 500
deltas = [mean_0[i].accuracy - med_2[i].accuracy  for i in range(len(mean_2))]
fig = plt.figure(figsize =(8, 7)) 
  
# Creating plot 
plt.boxplot(deltas) 
  
# show plot 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
mean_0[2]["accuracy"] - mean_0[2]["accuracy"] -

# %%
mean_2[0]

# %%
t = np.array(m30_1.event_model["means"]) - np.array(m30_25.event_model["means"])
df = pd.DataFrame(data=t, index=m30_1.sorted_kmer_tuple, columns=["1-25"])
t2 = np.array(m30_1.event_model["means"]) - np.array(m30_5.event_model["means"])
df['1-5'] = t2
